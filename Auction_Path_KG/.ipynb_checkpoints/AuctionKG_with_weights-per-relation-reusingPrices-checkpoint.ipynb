# %%
import networkx as nx
import pandas as pd
import numpy as np
import pylab as p
import matplotlib.pyplot as plt
import os

# %%
path = os.getcwd()

# %%
path
# Out:
# '/Users/garima/KG/Graphs/scholarKG'

# %%
# write all data in a new folderr KG20C
DATASET_PATH = path + '/KG20C'

# %%
# get the KG dataset and prepare the data in form of triples 
def prepare_graphdata(path):
    files = ['train.txt', 'valid.txt', 'test.txt']
    #files=['valid.txt']
    entities, relations = set(), set()
    edges = []
    triples=[]
    for f in files:
        file_path = os.path.join(path, f)
        to_read = open(file_path, 'r')
        for line in to_read.readlines():
            head, rel, tail = line.strip().split('\t')
            entities.add(head)
            entities.add(tail)
            relations.add(rel)
            edge=(head,tail)
            edges.append(edge)
            triples.append((head,rel,tail))
        to_read.close()
    return entities,relations,edges, triples

# %%
# get all the entities and relations 
entities, relations, edges, triples= prepare_graphdata(DATASET_PATH)

# %%
# print relations
relations
# Out:
# {'author_in_affiliation',
#  'author_write_paper',
#  'paper_cite_paper',
#  'paper_in_domain',
#  'paper_in_venue'}

# %%
# no of entities
len(entities)
# Out:
# 16362

# %%
# no of edges
len(edges)
# Out:
# 55607

# %%
# map the entities and relations to ids
entities_to_id = {x: i for (i, x) in enumerate(sorted(entities))}
relations_to_id = {x: i for (i, x) in enumerate(sorted(relations))}

# %%
# write the entity and relatiion id mapping to a dictionary
for (dic, f) in zip([entities_to_id, relations_to_id], ['ent_id', 'rel_id']):
    ff = open(os.path.join(DATASET_PATH,'kg20', f), 'w+')
    for (x, i) in dic.items():
        ff.write("{}\t{}\n".format(x, i))
    ff.close()

# %%
# create triples with id
triplesWithID=[]
edgesWithID=[]
files = ['train.txt', 'valid.txt', 'test.txt']
for f in files:
    file_path = os.path.join(DATASET_PATH, f)
    to_read = open(file_path, 'r')
    for line in to_read.readlines():
        head, rel, tail = line.strip().split('\t')    
        edge=(entities_to_id[head],entities_to_id[tail])
        edgesWithID.append(edge)
        triplesWithID.append((entities_to_id[head],rel,entities_to_id[tail]))
    to_read.close()

# %%
# create a dataframe to keep the triples
triplesDf = pd.DataFrame(triplesWithID)
triplesDf.columns = ['e1', 'r', 'e2']

# %%
# create the Knowledge graph from triples
G = nx.DiGraph(directed=True)
# extract head
head = [i[0] for i in triplesWithID]

#extract relation
relations = [i[1] for i in triplesWithID]

# extract tail
tail = [i[2] for i in triplesWithID]


for i in range(len(relations)):
         G.add_weighted_edges_from([(head[i], tail[i], i)])
edge_labels= dict([((u,v), relations[d['weight']]) for u,v, d in G.edges(data=True)])

# %%
# the metadata about each entity is given in a file called all_entity_info in KG20C dataset
# map the entities to the attribute information
entity_info= pd.read_csv(DATASET_PATH +'/all_entity_info.txt', sep='\t')
entity_info.columns=['entity', 'name', 'type']

# %%
# create a mapping with entity information
entityId = pd.DataFrame(entities_to_id.items(), columns=['entity', 'entityID'])

# %%
entity_info.head()
# Out:
#      entity                                               name   type
# 0  7C7CAEED  On rank correlation in information retrieval e...  paper
# 1  7AEE29E3                 The Voting Model for People Search  paper
# 2  7D68490B                Document clustering with committees  paper
# 3  7A488256  A comparison of indexing techniques for Japane...  paper
# 4  7D5CD2DF                      Feature selection for ranking  paper

# %%
triplesDf.head()
# Out:
#       e1                      r     e2
# 0   3877  author_in_affiliation   1915
# 1   1603  author_in_affiliation    229
# 2  12953     author_write_paper  10004
# 3   7398     author_write_paper   5957
# 4  11891       paper_cite_paper   4979

# %%
currentNode=[11016, 6859, 1689, 13629,6685,7774, 16078,11699]
#cNode1= [8011,12346,12670,12919,12581,16178]
#cnode3= [6738,12557,5881, 13325,7669,1602, 10537, 9726]

# %%
def create_subgraph(currentNode):
    sub_edges=[]
    sub_nodes=[]

    sub_nodes.append(currentNode)
    edgeList=list(G.edges(currentNode))
    for i in range(len(edgeList)):           
        sub_edges.append(edgeList[i])
    idx=0
    while idx<=11:
        # list the immediate nodes at distance of 1
        availablePath= list(G.successors(currentNode))
    
        
        # get the possible next nodes from the current nodes
        for i in range(len(availablePath)):
            if availablePath[i] not in sub_nodes:
                sub_nodes.append(int(availablePath[i]))
        
            if len(G.edges(int(availablePath[i])))!=0:
                edgeList=list(G.edges(int(availablePath[i])))
                for i in range(len(edgeList)):  
                    if edgeList[i] not in sub_edges:
                        sub_edges.append(edgeList[i])  
    
        if sub_nodes[idx]!=currentNode:
            currentNode = sub_nodes[idx]
        idx = (idx + 1) 
    return sub_edges, sub_nodes

# %%
subE=[]
subN=[]
for i in range(len(currentNode)):
    e1, n1 = create_subgraph(currentNode[i])
    if e1 not in subE:
        subE.append(e1)
    if n1 not in subN:
        subN.append(n1)

# %%
flat_nodes = [x for xs in subN for x in xs]
flat_edges = [x for xs in subE for x in xs]

# %%
def check_dup():
    if len(flat_edges) == len(set(flat_edges)):
        return False
    else:
        return True

# %%
check_dup()
# Out:
# True

# %%
sub_nodes = []
[sub_nodes.append(x) for x in flat_nodes if x not in sub_nodes]
sub_nodes
# Out:
# [11016,
#  12254,
#  9890,
#  9726,
#  10922,
#  1831,
#  8656,
#  11065,
#  9377,
#  10720,
#  14844,
#  11989,
#  323,
#  7944,
#  15227,
#  8284,
#  13777,
#  8167,
#  9199,
#  351,
#  8134,
#  11332,
#  9189,
#  8543,
#  4225,
#  7483,
#  387,
#  4097,
#  2456,
#  6680,
#  730,
#  1639,
#  7535,
#  12310,
#  4906,
#  7519,
#  7458,
#  1325,
#  11031,
#  4093,
#  1709,
#  13258,
#  1090,
#  2087,
#  2978,
#  12801,
#  774,
#  717,
#  13914,
#  5201,
#  8043,
#  389,
#  8680,
#  1483,
#  3778,
#  9409,
#  2502,
#  7421,
#  3787,
#  12700,
#  1930,
#  4107,
#  11173,
#  1220,
#  9256,
#  2270,
#  4963,
#  4579,
#  193,
#  2110,
#  8214,
#  2099,
#  1256,
#  11939,
#  9758,
#  6510,
#  11747,
#  10214,
#  1856,
#  9944,
#  1755,
#  1286,
#  10344,
#  6038,
#  10896,
#  4523,
#  587,
#  2343,
#  9101,
#  1939,
#  1259,
#  6655,
#  8419,
#  5470,
#  6859,
#  6172,
#  14376,
#  1302,
#  5686,
#  4126,
#  4124,
#  1655,
#  4119,
#  5737,
#  1689,
#  5874,
#  5705,
#  8804,
#  2707,
#  14689,
#  2415,
#  4421,
#  4447,
#  9005,
#  2094,
#  5886,
#  4326,
#  4450,
#  472,
#  4445,
#  13247,
#  6131,
#  1667,
#  12066,
#  2322,
#  7833,
#  10968,
#  7707,
#  1493,
#  11615,
#  9635,
#  12240,
#  10060,
#  13752,
#  5295,
#  11517,
#  14353,
#  12028,
#  4358,
#  807,
#  6391,
#  4483,
#  4337,
#  8061,
#  2500,
#  14131,
#  6588,
#  4835,
#  364,
#  1839,
#  5778,
#  655,
#  2714,
#  1548,
#  203,
#  13629,
#  1119,
#  467,
#  1546,
#  4425,
#  11757,
#  10790,
#  6206,
#  1499,
#  2961,
#  166,
#  6685,
#  3043,
#  4408,
#  4411,
#  4744,
#  448,
#  2281,
#  4132,
#  1030,
#  14172,
#  755,
#  624,
#  7774,
#  16078,
#  12257,
#  10322,
#  4958,
#  8073,
#  11057,
#  6203,
#  4227,
#  12802,
#  5562,
#  11174,
#  8697,
#  1474,
#  2980,
#  4272,
#  6098,
#  2440,
#  7952,
#  5594,
#  2975,
#  4088,
#  2561,
#  539,
#  770,
#  4134,
#  2769,
#  1433,
#  4536,
#  2404,
#  8926,
#  10037,
#  10621,
#  4109,
#  13813,
#  584,
#  2574,
#  508,
#  994,
#  27,
#  2116,
#  129,
#  8495,
#  1896,
#  4707,
#  7364,
#  5696,
#  1078,
#  9427,
#  2795,
#  12782,
#  2370,
#  11848,
#  11699,
#  7000,
#  9478,
#  2003,
#  2636,
#  11213,
#  358,
#  309,
#  2498,
#  2315,
#  1485,
#  1212,
#  1964,
#  12416,
#  1010,
#  656,
#  2399,
#  2826,
#  1716,
#  5500,
#  1107,
#  1190,
#  104,
#  12606,
#  206,
#  2382,
#  332,
#  3153]

# %%
sub_edges = []
[sub_edges.append(x) for x in flat_edges if x not in sub_edges]
sub_edges
# Out:
# [(11016, 12254),
#  (11016, 9890),
#  (11016, 9726),
#  (11016, 10922),
#  (11016, 1831),
#  (11016, 8656),
#  (11016, 11065),
#  (11016, 9377),
#  (11016, 10720),
#  (11016, 14844),
#  (11016, 11989),
#  (11016, 323),
#  (11016, 7944),
#  (11016, 15227),
#  (11016, 8284),
#  (11016, 13777),
#  (11016, 8167),
#  (11016, 9199),
#  (11016, 351),
#  (11016, 8134),
#  (11016, 11332),
#  (11016, 9189),
#  (11016, 8543),
#  (11016, 4225),
#  (12254, 7483),
#  (12254, 387),
#  (12254, 10720),
#  (12254, 4097),
#  (12254, 2456),
#  (12254, 6680),
#  (12254, 730),
#  (12254, 1639),
#  (12254, 7535),
#  (12254, 12310),
#  (12254, 4906),
#  (12254, 7519),
#  (12254, 7458),
#  (12254, 1325),
#  (12254, 11031),
#  (9890, 4093),
#  (9890, 387),
#  (9890, 1709),
#  (9890, 13258),
#  (9890, 1090),
#  (9890, 2087),
#  (9890, 2978),
#  (9726, 12801),
#  (9726, 774),
#  (9726, 717),
#  (9726, 13914),
#  (9726, 5201),
#  (9726, 8043),
#  (9726, 389),
#  (9726, 8680),
#  (9726, 1483),
#  (9726, 3778),
#  (9726, 9409),
#  (9726, 2502),
#  (9726, 7421),
#  (9726, 3787),
#  (9726, 12700),
#  (9726, 1930),
#  (9726, 4107),
#  (10922, 11173),
#  (10922, 8043),
#  (10922, 12254),
#  (10922, 389),
#  (10922, 1220),
#  (10922, 12801),
#  (10922, 4093),
#  (10922, 9256),
#  (8656, 1325),
#  (8656, 2270),
#  (8656, 12310),
#  (8656, 4963),
#  (8656, 1639),
#  (8656, 7458),
#  (8656, 4579),
#  (8656, 193),
#  (8656, 2110),
#  (8656, 8214),
#  (8656, 387),
#  (8656, 7483),
#  (8656, 7535),
#  (8656, 4097),
#  (8656, 10720),
#  (11065, 8543),
#  (11065, 2099),
#  (11065, 1256),
#  (11065, 9890),
#  (11065, 7458),
#  (11065, 387),
#  (11065, 11939),
#  (11065, 9758),
#  (11065, 4097),
#  (11065, 6510),
#  (11065, 12254),
#  (11065, 1325),
#  (11065, 8656),
#  (11065, 10720),
#  (11065, 7535),
#  (11065, 12310),
#  (11065, 11747),
#  (11065, 10214),
#  (11065, 1856),
#  (9377, 9944),
#  (9377, 1755),
#  (9377, 12310),
#  (9377, 1286),
#  (9377, 10344),
#  (9377, 4097),
#  (9377, 6038),
#  (9377, 10896),
#  (9377, 1856),
#  (9377, 9189),
#  (9377, 7458),
#  (9377, 11065),
#  (9377, 4523),
#  (9377, 7483),
#  (9377, 12254),
#  (9377, 587),
#  (10720, 2343),
#  (10720, 7483),
#  (10720, 9101),
#  (10720, 2456),
#  (10720, 4097),
#  (10720, 1939),
#  (10720, 12310),
#  (10720, 1259),
#  (10720, 1325),
#  (10720, 7535),
#  (10720, 6510),
#  (10720, 10214),
#  (10720, 1639),
#  (10720, 6655),
#  (10720, 7458),
#  (10720, 387),
#  (14844, 12254),
#  (14844, 8543),
#  (14844, 11939),
#  (14844, 10720),
#  (14844, 4097),
#  (14844, 8419),
#  (14844, 11031),
#  (14844, 11065),
#  (14844, 5470),
#  (14844, 12310),
#  (14844, 7483),
#  (14844, 10896),
#  (14844, 387),
#  (14844, 9189),
#  (14844, 1639),
#  (14844, 1325),
#  (14844, 193),
#  (14844, 4906),
#  (11989, 4097),
#  (11989, 1325),
#  (11989, 12801),
#  (11989, 10922),
#  (11989, 1483),
#  (7944, 11065),
#  (7944, 10896),
#  (7944, 12310),
#  (7944, 9189),
#  (7944, 2563),
#  (7944, 7458),
#  (7944, 4906),
#  (7944, 4119),
#  (7944, 1325),
#  (7944, 12254),
#  (7944, 1639),
#  (15227, 1344),
#  (15227, 4126),
#  (8284, 11076),
#  (8284, 2087),
#  (8284, 6396),
#  (8284, 9065),
#  (8284, 6038),
#  (8284, 2616),
#  (8284, 138),
#  (8284, 7563),
#  (8284, 4097),
#  (8284, 3736),
#  (8284, 8303),
#  (13777, 2333),
#  (13777, 4088),
#  (13777, 9199),
#  (13777, 387),
#  (13777, 1325),
#  (13777, 9189),
#  (13777, 7117),
#  (13777, 11065),
#  (13777, 13280),
#  (8167, 810),
#  (8167, 1939),
#  (8167, 12310),
#  (8167, 1325),
#  (8167, 12254),
#  (8167, 10720),
#  (8167, 4097),
#  (8167, 9189),
#  (9199, 13280),
#  (9199, 7535),
#  (9199, 8543),
#  (9199, 12310),
#  (9199, 2110),
#  (9199, 4093),
#  (9199, 10720),
#  (9199, 1325),
#  (9199, 8656),
#  (9199, 9189),
#  (9199, 10896),
#  (9199, 14327),
#  (9199, 1483),
#  (9199, 9246),
#  (9199, 11065),
#  (9199, 7117),
#  (9199, 12254),
#  (8134, 4097),
#  (8134, 2333),
#  (8134, 1597),
#  (8134, 5777),
#  (8134, 8213),
#  (8134, 1484),
#  (8134, 12700),
#  (8134, 13674),
#  (11332, 2110),
#  (11332, 2415),
#  (11332, 4093),
#  (11332, 2087),
#  (11332, 7792),
#  (11332, 8193),
#  (11332, 138),
#  (11332, 12239),
#  (11332, 7458),
#  (9189, 2456),
#  (9189, 12310),
#  (9189, 356),
#  (9189, 1325),
#  (9189, 2343),
#  (9189, 1639),
#  (9189, 4119),
#  (9189, 11939),
#  (9189, 790),
#  (9189, 4583),
#  (9189, 7458),
#  (9189, 10720),
#  (9189, 8543),
#  (9189, 7535),
#  (8543, 6510),
#  (8543, 7458),
#  (8543, 387),
#  (8543, 7535),
#  (8543, 9758),
#  (8543, 4396),
#  (8543, 12310),
#  (8543, 1286),
#  (8543, 1325),
#  (8543, 10720),
#  (8543, 4097),
#  (8543, 1092),
#  (8543, 12239),
#  (8543, 1939),
#  (8543, 10214),
#  (7483, 1520),
#  (7483, 21),
#  (7483, 1036),
#  (7483, 2905),
#  (7483, 1372),
#  (7483, 4097),
#  (7483, 1155),
#  (7483, 2099),
#  (7483, 387),
#  (6680, 1302),
#  (6680, 1924),
#  (6680, 4639),
#  (6680, 5324),
#  (6680, 4117),
#  (6680, 4703),
#  (7535, 1372),
#  (7535, 4097),
#  (7535, 387),
#  (12310, 1483),
#  (12310, 2343),
#  (12310, 790),
#  (12310, 431),
#  (12310, 9128),
#  (12310, 10214),
#  (12310, 4119),
#  (12310, 1639),
#  (12310, 12802),
#  (12310, 1325),
#  (4906, 9025),
#  (4906, 12310),
#  (4906, 6317),
#  (4906, 1015),
#  (4906, 4117),
#  (7519, 4390),
#  (7519, 8618),
#  (7519, 4),
#  (7519, 1408),
#  (7519, 7786),
#  (7519, 10183),
#  (7519, 7868),
#  (7519, 4119),
#  (7458, 2099),
#  (7458, 1856),
#  (7458, 4097),
#  (7458, 6178),
#  (7458, 203),
#  (7458, 1484),
#  (7458, 7782),
#  (7458, 166),
#  (7458, 11747),
#  (7458, 387),
#  (7458, 6854),
#  (11031, 1639),
#  (11031, 11026),
#  (11031, 8618),
#  (11031, 12310),
#  (11031, 790),
#  (11031, 7519),
#  (11031, 11130),
#  (11031, 387),
#  (11031, 4088),
#  (11031, 1325),
#  (13258, 938),
#  (13258, 4126),
#  (12801, 4097),
#  (12801, 1220),
#  (12801, 1546),
#  (12801, 4425),
#  (12801, 11757),
#  (13914, 10790),
#  (13914, 1493),
#  (13914, 6206),
#  (13914, 387),
#  (13914, 4093),
#  (13914, 1483),
#  (5201, 2502),
#  (5201, 4119),
#  (5201, 1499),
#  (5201, 2961),
#  (5201, 166),
#  (5201, 389),
#  (8043, 7490),
#  (8043, 2094),
#  (8043, 4093),
#  (8043, 9319),
#  (8043, 356),
#  (8043, 1483),
#  (8043, 1220),
#  (8043, 10639),
#  (8043, 7831),
#  (8043, 387),
#  (8043, 3757),
#  (8043, 10578),
#  (8043, 9652),
#  (8043, 1030),
#  (8680, 387),
#  (8680, 4097),
#  (8680, 1302),
#  (8680, 2456),
#  (8680, 2406),
#  (8680, 5777),
#  (9409, 7421),
#  (9409, 4126),
#  (9409, 14376),
#  (9409, 2502),
#  (9409, 13525),
#  (7421, 459),
#  (7421, 389),
#  (7421, 2560),
#  (7421, 4117),
#  (7421, 2668),
#  (7421, 13525),
#  (7421, 4),
#  (12700, 389),
#  (12700, 4119),
#  (12700, 2234),
#  (12700, 2379),
#  (12700, 166),
#  (12700, 2502),
#  (12700, 2561),
#  (12700, 2333),
#  (11173, 387),
#  (11173, 14040),
#  (11173, 8017),
#  (11173, 1420),
#  (11173, 4097),
#  (11173, 65),
#  (11173, 2099),
#  (11173, 2616),
#  (11173, 5644),
#  (11173, 7598),
#  (9256, 4088),
#  (9256, 10011),
#  (9256, 1856),
#  (9256, 4470),
#  (9256, 4839),
#  (9256, 810),
#  (9256, 3160),
#  (9256, 2365),
#  (9256, 764),
#  (9256, 1063),
#  (4963, 4119),
#  (4963, 2617),
#  (4963, 2330),
#  (4963, 1755),
#  (4963, 2270),
#  (4579, 1856),
#  (4579, 810),
#  (4579, 2270),
#  (4579, 4119),
#  (8214, 500),
#  (8214, 1179),
#  (8214, 2270),
#  (8214, 4462),
#  (8214, 203),
#  (8214, 2343),
#  (8214, 9815),
#  (8214, 4932),
#  (8214, 4088),
#  (11939, 4097),
#  (11939, 1856),
#  (11939, 387),
#  (11939, 1639),
#  (11939, 7458),
#  (11939, 10720),
#  (11939, 1325),
#  (11939, 12310),
#  (11939, 3757),
#  (11939, 6327),
#  (11939, 2947),
#  (9758, 1856),
#  (9758, 387),
#  (9758, 1012),
#  (9758, 10903),
#  (9758, 193),
#  (9758, 824),
#  (9758, 4093),
#  (6510, 2110),
#  (6510, 1709),
#  (6510, 203),
#  (6510, 4119),
#  (6510, 10586),
#  (11747, 8017),
#  (11747, 4097),
#  (11747, 7483),
#  (11747, 770),
#  (11747, 387),
#  (11747, 2099),
#  (11747, 459),
#  (11747, 1664),
#  (10214, 356),
#  (10214, 4119),
#  (9944, 12914),
#  (9944, 2415),
#  (9944, 3160),
#  (9944, 4088),
#  (9944, 11517),
#  (10344, 12310),
#  (10344, 1483),
#  (10344, 11541),
#  (10344, 215),
#  (10344, 364),
#  (10344, 4093),
#  (10344, 1856),
#  (10344, 12802),
#  (10344, 11966),
#  (6038, 1840),
#  (6038, 4097),
#  (6038, 2087),
#  (10896, 1856),
#  (10896, 4097),
#  (10896, 7786),
#  (10896, 2990),
#  (10896, 10720),
#  (10896, 387),
#  (10896, 5521),
#  (10896, 12310),
#  (10896, 2512),
#  (10896, 7483),
#  (10896, 203),
#  (10896, 7519),
#  (4523, 4117),
#  (4523, 1856),
#  (4523, 1246),
#  (4523, 4909),
#  (9101, 4119),
#  (9101, 1709),
#  (9101, 12310),
#  (9101, 12757),
#  (9101, 9120),
#  (9101, 5523),
#  (9101, 5311),
#  (9101, 2446),
#  (6655, 4097),
#  (6655, 12587),
#  (6655, 387),
#  (6655, 945),
#  (6655, 1951),
#  (6655, 7458),
#  (6655, 14040),
#  (6655, 7483),
#  (6655, 6327),
#  (6655, 1484),
#  (6655, 389),
#  (6655, 2836),
#  (6655, 2099),
#  (8419, 4088),
#  (8419, 1856),
#  (8419, 1483),
#  (8419, 10203),
#  (8419, 12310),
#  (8419, 9025),
#  (8419, 1639),
#  (8419, 1302),
#  (5470, 1856),
#  (5470, 1710),
#  (5470, 5700),
#  (5470, 1256),
#  (5470, 4097),
#  (5470, 387),
#  (6859, 6172),
#  (6172, 2087),
#  (6172, 14376),
#  (6172, 1302),
#  (6172, 5686),
#  (6172, 4126),
#  (14376, 4124),
#  (14376, 389),
#  (5686, 1655),
#  (5686, 4119),
#  (5686, 5737),
#  (5686, 2087),
#  (5737, 2322),
#  (5737, 6680),
#  (5737, 4117),
#  (5737, 1639),
#  (5737, 9484),
#  (5737, 3076),
#  (1689, 5874),
#  (1689, 5705),
#  (1689, 8804),
#  (1689, 9726),
#  (1689, 2707),
#  (5874, 14689),
#  (5874, 2415),
#  (5874, 4421),
#  (5874, 4447),
#  (5874, 193),
#  (5874, 9005),
#  (5874, 2094),
#  (5874, 5886),
#  (5874, 4326),
#  (5874, 4450),
#  (5874, 472),
#  (5874, 4445),
#  (5874, 13247),
#  (5874, 6131),
#  (5874, 1667),
#  (5874, 12066),
#  (5874, 2322),
#  (5874, 7833),
#  (5874, 4093),
#  (5874, 10968),
#  (5874, 4963),
#  (5874, 7707),
#  (5705, 1493),
#  (5705, 11615),
#  (5705, 9635),
#  (5705, 4119),
#  (5705, 9944),
#  (5705, 12240),
#  (5705, 10060),
#  (5705, 13752),
#  (5705, 5295),
#  (5705, 11517),
#  (5705, 14353),
#  (5705, 12028),
#  (5705, 4358),
#  (8804, 4450),
#  (8804, 472),
#  (8804, 807),
#  (8804, 4326),
#  (8804, 4447),
#  (8804, 4445),
#  (8804, 4119),
#  (8804, 7707),
#  (14689, 6391),
#  (14689, 4483),
#  (14689, 4337),
#  (14689, 8061),
#  (14689, 2500),
#  (14689, 14131),
#  (14689, 6588),
#  (14689, 4835),
#  (14689, 364),
#  (14689, 1856),
#  (14689, 4093),
#  (14689, 1839),
#  (14689, 5778),
#  (4421, 655),
#  (4421, 2270),
#  (4421, 2714),
#  (4421, 1548),
#  (4421, 4119),
#  (4447, 4119),
#  (4447, 203),
#  (9005, 203),
#  (9005, 4119),
#  (5886, 1755),
#  (5886, 3091),
#  (5886, 4097),
#  (4326, 203),
#  (4326, 4119),
#  (4450, 4119),
#  (4450, 203),
#  (4450, 1856),
#  (4445, 2769),
#  (4445, 4119),
#  (13247, 4093),
#  (13247, 203),
#  (6131, 203),
#  (6131, 810),
#  (6131, 790),
#  (6131, 1755),
#  (6131, 4097),
#  (1667, 7833),
#  (1667, 2087),
#  (1667, 4124),
#  (12066, 13518),
#  (12066, 2322),
#  (12066, 14543),
#  (12066, 4119),
#  (12066, 9484),
#  (12066, 6131),
#  (7833, 1856),
#  (7833, 4097),
#  (7833, 3096),
#  (7833, 6178),
#  (7833, 387),
#  (7833, 4442),
#  (7833, 7707),
#  (10968, 438),
#  (10968, 235),
#  (10968, 4088),
#  (10968, 1820),
#  (10968, 7707),
#  (7707, 1820),
#  (7707, 4117),
#  (7707, 2617),
#  (11615, 4088),
#  (11615, 2769),
#  (11615, 12739),
#  (11615, 2336),
#  (11615, 2343),
#  (11615, 2617),
#  (9635, 4088),
#  (9635, 14384),
#  (9635, 13796),
#  (9635, 915),
#  (9635, 14318),
#  (9635, 12001),
#  (9635, 9005),
#  (9635, 10485),
#  (12240, 4088),
#  (12240, 163),
#  (12240, 1493),
#  (12240, 4586),
#  (12240, 1856),
#  (12240, 1433),
#  (10060, 915),
#  (10060, 4088),
#  (10060, 9635),
#  (10060, 203),
#  (10060, 4953),
#  (10060, 999),
#  (10060, 12240),
#  (10060, 2415),
#  (10060, 672),
#  (13752, 8869),
#  (13752, 1856),
#  (13752, 5008),
#  (13752, 4119),
#  (13752, 6388),
#  (5295, 1896),
#  (5295, 1433),
#  (5295, 2415),
#  (5295, 4119),
#  (5295, 2827),
#  (5295, 203),
#  (5295, 1856),
#  (11517, 3160),
#  (11517, 4119),
#  (11517, 2679),
#  (14353, 14318),
#  (14353, 4088),
#  (14353, 915),
#  (14353, 672),
#  (14353, 13280),
#  (14353, 9635),
#  (14353, 12028),
#  (12028, 2270),
#  (12028, 915),
#  (12028, 5594),
#  (12028, 4119),
#  (12028, 14318),
#  (12028, 9635),
#  (12028, 2087),
#  (4358, 2733),
#  (4358, 9356),
#  (4358, 4953),
#  (4358, 9635),
#  (4358, 387),
#  (4358, 12028),
#  (4358, 915),
#  (4358, 4117),
#  (4358, 13280),
#  (4358, 9005),
#  (4358, 1820),
#  (6391, 4093),
#  (6391, 2500),
#  (6391, 4337),
#  (6391, 1478),
#  (6391, 2574),
#  (6391, 1220),
#  (6391, 2115),
#  (6391, 9805),
#  (4483, 4119),
#  (4483, 2099),
#  (4483, 459),
#  (4483, 364),
#  (4483, 2561),
#  (4483, 810),
#  (4337, 1856),
#  (4337, 810),
#  (4337, 2129),
#  (4337, 1483),
#  (4337, 1478),
#  (4337, 235),
#  (4337, 73),
#  (4337, 4119),
#  (8061, 1893),
#  (8061, 1187),
#  (8061, 810),
#  (8061, 770),
#  (8061, 387),
#  (8061, 397),
#  (8061, 4119),
#  (8061, 1190),
#  (8061, 2282),
#  (8061, 1618),
#  (8061, 1793),
#  (8061, 1977),
#  (8061, 193),
#  (8061, 2733),
#  (8061, 3146),
#  (14131, 4088),
#  (14131, 2967),
#  (14131, 2322),
#  (14131, 810),
#  (6588, 4093),
#  (6588, 7364),
#  (6588, 1930),
#  (6588, 810),
#  (4835, 99),
#  (4835, 2270),
#  (4835, 3749),
#  (4835, 4119),
#  (4835, 387),
#  (5778, 6928),
#  (5778, 1030),
#  (5778, 4093),
#  (5778, 2779),
#  (13629, 4093),
#  (13629, 1119),
#  (13629, 467),
#  (13629, 9726),
#  (13629, 1483),
#  (4425, 717),
#  (4425, 4132),
#  (11757, 949),
#  (11757, 4132),
#  (11757, 951),
#  (11757, 1370),
#  (11757, 717),
#  (11757, 4408),
#  (11757, 5419),
#  (11757, 1227),
#  (11757, 2502),
#  (10790, 220),
#  (10790, 2007),
#  (10790, 4088),
#  (10790, 1493),
#  (6206, 2905),
#  (6206, 4097),
#  (6206, 387),
#  (6206, 1119),
#  (6685, 14376),
#  (6685, 3043),
#  (6685, 4408),
#  (6685, 4411),
#  (6685, 4744),
#  (6685, 448),
#  (4408, 2281),
#  (4408, 1856),
#  (4408, 4132),
#  (4408, 1030),
#  (4411, 14172),
#  (4411, 755),
#  (4411, 4408),
#  (4411, 2281),
#  (4411, 624),
#  (4411, 4132),
#  (4744, 1548),
#  (4744, 4132),
#  (4744, 1856),
#  (14172, 4124),
#  (14172, 1930),
#  (14172, 364),
#  (14172, 1876),
#  (14172, 2281),
#  (14172, 1370),
#  (14172, 2045),
#  (14172, 1856),
#  (14172, 4408),
#  (7774, 6172),
#  (16078, 12257),
#  (16078, 10322),
#  (16078, 4958),
#  (16078, 8073),
#  (16078, 11057),
#  (16078, 6203),
#  (16078, 4227),
#  (16078, 12802),
#  (16078, 5562),
#  (16078, 11174),
#  (16078, 6680),
#  (16078, 8697),
#  (16078, 1474),
#  (16078, 9409),
#  (16078, 2980),
#  (16078, 4272),
#  (16078, 6098),
#  (12257, 2343),
#  (12257, 203),
#  (12257, 4119),
#  (12257, 2440),
#  (12257, 7952),
#  (12257, 5594),
#  (10322, 2975),
#  (10322, 4088),
#  (10322, 1493),
#  (4958, 2561),
#  (4958, 539),
#  (4958, 770),
#  (4958, 4134),
#  (4958, 2769),
#  (4958, 1433),
#  (4958, 4536),
#  (8073, 2404),
#  (8073, 8926),
#  (8073, 4119),
#  (8073, 730),
#  (11057, 9944),
#  (11057, 10037),
#  (11057, 10621),
#  (11057, 6098),
#  (11057, 1286),
#  (11057, 4109),
#  (11057, 13813),
#  (11057, 584),
#  (11057, 2574),
#  (11057, 1856),
#  (11057, 508),
#  (11057, 994),
#  (11057, 27),
#  (11057, 2116),
#  (11057, 129),
#  (11057, 8495),
#  (6203, 4835),
#  (6203, 1896),
#  (6203, 4119),
#  (6203, 2110),
#  (6203, 4707),
#  (6203, 7364),
#  (6203, 4483),
#  (6203, 2975),
#  (12802, 5696),
#  (12802, 1078),
#  (12802, 9427),
#  (12802, 4088),
#  (5562, 2795),
#  (5562, 12257),
#  (5562, 4119),
#  (5562, 12782),
#  (5562, 2370),
#  (5562, 1286),
#  (11174, 4119),
#  (11174, 11848),
#  (11174, 1639),
#  (11174, 2769),
#  (8697, 4088),
#  (8697, 2975),
#  (6098, 4707),
#  (6098, 2087),
#  (6098, 9944),
#  (6098, 1036),
#  (6098, 4119),
#  (6098, 4492),
#  (6098, 2975),
#  (6098, 1478),
#  (7952, 4119),
#  (7952, 2975),
#  (7952, 1856),
#  (7952, 5594),
#  (7952, 2683),
#  (7952, 898),
#  (7952, 2322),
#  (7952, 203),
#  (7952, 3131),
#  (7952, 9249),
#  (7952, 9972),
#  (7952, 1380),
#  (5594, 7868),
#  (5594, 4117),
#  (5594, 1493),
#  (4536, 4678),
#  (4536, 2364),
#  (4536, 1893),
#  (4536, 243),
#  (4536, 4132),
#  (4536, 790),
#  (4536, 4638),
#  (8926, 1929),
#  (8926, 807),
#  (8926, 4088),
#  (10037, 203),
#  (10037, 9944),
#  (10037, 11517),
#  (10037, 4088),
#  (10037, 14438),
#  (10621, 466),
#  (10621, 656),
#  (10621, 1755),
#  (10621, 4109),
#  (10621, 2551),
#  (10621, 1524),
#  (10621, 129),
#  (10621, 508),
#  (10621, 3739),
#  (10621, 3770),
#  (10621, 994),
#  (10621, 824),
#  (13813, 994),
#  (13813, 13749),
#  (13813, 95),
#  (13813, 4109),
#  (13813, 14384),
#  (13813, 1158),
#  (13813, 15005),
#  (13813, 824),
#  (8495, 8814),
#  (8495, 4088),
#  (8495, 11290),
#  (8495, 994),
#  (8495, 4),
#  (8495, 1286),
#  (4707, 10547),
#  (4707, 3076),
#  (4707, 7868),
#  (4707, 1348),
#  (4707, 4935),
#  (4707, 5594),
#  (4707, 4117),
#  (4707, 8076),
#  (4707, 4383),
#  (4707, 6268),
#  (7364, 7598),
#  (7364, 1856),
#  (7364, 6131),
#  (7364, 2202),
#  (7364, 6928),
#  (7364, 7255),
#  (7364, 4963),
#  (7364, 4483),
#  (7364, 4769),
#  (7364, 203),
#  (7364, 4097),
#  (7364, 4835),
#  (7364, 7257),
#  (5696, 5594),
#  (5696, 4097),
#  (5696, 2975),
#  (5696, 945),
#  (9427, 4583),
#  (9427, 13518),
#  (9427, 4088),
#  ...]

# %%
len(sub_nodes)
# Out:
# 259

# %%
# create a dataframe from edges and keep the relations
subDf = pd.DataFrame(sub_edges)

# get entity information and map to each node in subG - sub_nodes
# get the relations from triples for edges in subG - sub_edges

triplesDf.columns = ['e1', 'r', 'e2']
subDf.columns = ['e1', 'e2']
subGraphDf=pd.DataFrame()

subGraphDf = pd.merge(subDf,triplesDf, on=['e1', 'e2'], how='inner' )

# similarly find all the information and type of the node
subNodesDf = pd.DataFrame(sub_nodes)
subNodesDf.columns = ['entityID']

# extract only the entity information of the entities in suub graph
nodesInfo = pd.merge(subNodesDf,entityId, on=['entityID'], how='inner' )

# convert intto string for all the values to be similar data type
nodesInfo['entityID']=nodesInfo['entityID'].astype(str)

# map the entity is to entity info (meta data)
nodesInfoG = pd.merge(nodesInfo,entity_info, on=['entity'], how='inner' )

# %%
subGraphDf.head()
# Out:
#       e1     e2                      r
# 0  11016  12254     author_write_paper
# 1  11016   9890     author_write_paper
# 2  11016   9726     author_write_paper
# 3  11016  10922     author_write_paper
# 4  11016   1831  author_in_affiliation

# %%
# plot the subgraph

# extract head
head = subGraphDf['e1']

#extract relation
relations = subGraphDf['r']

# extract tail
tail = subGraphDf['e2']

sG = nx.DiGraph(directed=True)  
for i in range(len(relations)):
    sG.add_weighted_edges_from([(head[i], tail[i], i)])
    
# print("\n Knowledge Graph generated")
# size =50
# if (len(relations)/2)>50:
#     size= len(edge)/2
# plt.figure(figsize=(size, size))
# edge_labels= dict([((u,v), relations[d['weight']]) for u,v, d in sG.edges(data=True)])
# pos=nx.spring_layout(sG,k=0.8)
# nx.draw(sG, with_labels=True, node_color='lightblue', node_size=5000, edge_color='r', edge_cmap=plt.cm.Blues, pos=pos, font_size=15)
# nx.draw_networkx_edge_labels(sG, pos, edge_labels= edge_labels, font_size=20)
# plt.savefig('subGraph.png')

# %% [markdown]
# ## Function to assign arc weights as per relations

# %%
def arc_weights_relation(strong, medium):
    c1=subGraphDf.e1
    c2=subGraphDf.e2
    r1=subGraphDf.r
    edgeWeight={}
    

    i=0
    while i<len(c1):
        for key in sub_edges: 
            if (c1.iloc[i],c2.iloc[i])==key:
               # print("the edges is:", key)
               # print("the triple edges is:", c1.iloc[i],c2.iloc[i])
               # print(i)
                if r1.iloc[i]==strong:
                    edgeWeight[key]=0
                elif r1.iloc[i]==medium:
                    edgeWeight[key]=3
                else:
                    edgeWeight[key]=6

        i=i+1
        
    return edgeWeight

# %% [markdown]
# ## Function to initialize Node Price

# %%
import random
def intial_price(initialVal):
    nodePrice={}
    
    for key in sub_nodes:
        if initialVal==0:
            # assign initial price as 0 for all the nodes
            nodePrice[key] =0
        else:
            # choose random
            nodePrice[key] = random.randrange(100, 1000, 10)
    return nodePrice

# %% [markdown]
# ## Function to initialize Arc Weights

# %%
import random
def arc_weights(initialVal):
    edgeWeight={}
    
    for key in sub_edges:
        if initialVal==0:
            # assign initial price as 0 for all the nodes
            edgeWeight[key] =0
        else:
            # choose random
            edgeWeight[key] = initialVal
    return edgeWeight

# %% [markdown]
# ## Function to add minimum price node to the Path

# %%
def getMinPriceSuccNode(kNode,Path):
     # list the immediate nodes at distance of 1
    
                
    availablePath = list(G.successors(int(kNode)))
    
    
    availablepathPrice = {}
        # get the price of all the nodes in available path 
    for (key, value) in nodePrice.items():
        for i in range(len(availablePath)):
            if key == availablePath[i]:
                availablepathPrice[key]= value
    
    print("the price of available nodes is:", availablepathPrice)

    availableWeights={}
    
    # get the weights of arcs from kNode to nodes in availablePath
    
    for (key, value) in edgeWeight.items():
        for i in range(len(availablePath)):
            if key == (kNode, availablePath[i]):
                availableWeights[key]=value
    
    print("the weights of available edges is:", availableWeights)
    
    

        # find the minimum price and the node
    
    choseNode = {k:v for k, v in availablepathPrice.items() if k not in highpriceNode }
    print("\nThe new nodes chosen are:",choseNode)  
    
    # get the corresponding weights for min price edge from kNode and add to prices of chosenNode
    
    chosenPriceWeights = {}
    for node in choseNode:
        weightkChose = [val for key, val in availableWeights.items() if int(node) in key]
        weight = [int(item) for item in weightkChose]
        choseNode[node] = choseNode[node] + weight[0]
    else:
        pass


    print("\nThe new prices of chosen are:",choseNode) 
    # find the node with minimum price
    if choseNode != {}:
        minPrice = min(choseNode.values()) 
        minNode = [k for k, v in choseNode.items() if v==minPrice]
        print("\nThe new min node chosen is:",minNode)  
        succNode = minNode[0]
        print("The successor node is:",succNode )
        
    else:
        if kNode==source:
            succNode=kNode
            print("reached source, no path available")
        else:
            nodePrice[kNode]= 1000000
            highpriceNode.append(kNode)
            Path=Path[:-1]
            pathLength=len(Path)
            kNode = Path[pathLength-1] 
            kNode, succNode,Path=getMinPriceSuccNode(kNode,Path)
                
    return kNode, succNode,Path

# %% [markdown]
# ## Function to construct forward path as per Price and Arc Weights for Single Destination

# %%
def update_price_single(Path):
    
    
    i=1
    while True:
        pathLength=len(Path)
        if pathLength!=0:
            kNode = Path[pathLength-1]
            
            kPath = list(G.successors(kNode))
            if len(kPath)==0 and kNode !=source:
                nodePrice[kNode]= 1000000
                highpriceNode.append(kNode)
                print("Terminal node reached, set the price to infinity and contract - remove the node")
                Path=Path[:-1]
                print("The new path is", Path)
                pathLength=len(Path)
                kNode = Path[pathLength-1]    
                
            
            kNode,succNode, Path = getMinPriceSuccNode(kNode, Path)
            if succNode==kNode and pathLength==1: 
                print("The final path is", Path)
                print("The number of steps", i)
                break
                
        print("The path is:", Path)
        print("The current K node is:", kNode)
        print("The succ node is:", succNode)
        
        pathLength=len(Path)
        
        
            
        if pathLength<2 and kNode==source:
            
            nodePrice[kNode]=max(nodePrice[kNode],edgeWeight[(kNode,succNode)]+nodePrice[succNode]+1)
            Path.append(succNode)
            print("Downhill Extend path to succ node and update the price of k")
            #print("\nThe latest price is:", nodePrice)  
            print("\nThe latest path is:", Path)
             #find target only on extension
            if succNode == target:
                print("Path to target is: {}".format(Path))
                print("The number of steps", i)
                break
            
            
        elif pathLength>=2:
            predNode = Path[pathLength-2]  
       
        
             # check prices
                                 
            # 1. downhill - Extend P to succ(k) and set price of k to price of pred(k)
            if nodePrice[succNode]<nodePrice[kNode]:
                print("Downhill Extend path to succ node and set the price of k to pred node")
                nodePrice[kNode]=nodePrice[predNode]-edgeWeight[(predNode,kNode)]
                Path.append(succNode)
                #print("\nThe latest price is:", nodePrice)  
                print("\nThe latest path is:", Path)
                 #find target only on extension
                if succNode == target:
                    print("Path to target is: {}".format(Path))
                    print("The number of steps", i)
                    break
               
                
            # 2. uphill - contract path and raise the price of k to the succ(k)+1
            elif nodePrice[succNode] > nodePrice[kNode]:
                print("\n Uphill- contract and update the price")
                nodePrice[kNode]=edgeWeight[(kNode,succNode)]+nodePrice[succNode]+1
                #print("\nThe updated price is:", nodePrice) 
                print("\nRemoving the high price node:", kNode)
                Path=Path[:-1]

        
             # 3. level - has 2 conditions to avoid the loop
            elif nodePrice[kNode] == nodePrice[succNode]:
             
                # 3.a if pred(k) has higher price than k - extend to succ(k) and raise price of k to pred(k)
                if nodePrice[predNode] > nodePrice[kNode] :
                    print("\nsame level Case 1 - Extend to succ node and update the price of k to pred node")
                    nodePrice[kNode]=nodePrice[predNode]- edgeWeight[(predNode,kNode)]
                    #print("\nThe updated price is:", nodePrice) 
                    Path.append(succNode)
                    print("The updated Path is:", Path)
                    
                    #find target only on extension
                    if succNode == target:
                        print("Path to target is: {}".format(Path))
                        print("The number of steps", i)
                        break
            
                # 3.b if price of pred(k) is same as k
                elif (nodePrice[predNode] == nodePrice[kNode]):
                    print("\nsame level Case 2- Contract, remove the node and update the price")
                    nodePrice[kNode]=nodePrice[kNode]+1
                    Path=Path[:-1]
                    #print("\nThe updated price is:", nodePrice) 

                    
                                        
                
        i=i+1  
        
    return Path

# %% [markdown]
# ## Function to Construct Forward Path for multiple destinations

# %%
def update_price_multiple(Path):
    reached_targets=[]
    j=0
    i=1
    while True:
        pathLength=len(Path)
        if pathLength!=0:
            kNode = Path[pathLength-1]
            
            kPath = list(G.successors(kNode))
            if len(kPath)==0 and kNode !=source:
                nodePrice[kNode]= 1000000
                highpriceNode.append(kNode)
                print("Terminal node reached, set the price to infinity and contract - remove the node")
                Path=Path[:-1]
                print("The new path is", Path)
                pathLength=len(Path)
                kNode = Path[pathLength-1]    
                
            
            kNode,succNode, Path = getMinPriceSuccNode(kNode, Path)
            if succNode==kNode and pathLength==1:
                print("The destination reached are", *reached_targets) 
                print("The number of steps", i)
                break
                
        print("The path is:", Path)
        print("The current K node is:", kNode)
        print("The succ node is:", succNode)
        
        pathLength=len(Path)
        
        
            
        if pathLength<2 and kNode==source:
            nodePrice[kNode]=max(nodePrice[kNode],edgeWeight[(kNode,succNode)]+ nodePrice[succNode]+1)
            Path.append(succNode)
            print("Downhill Extend path to succ node and update the price of k")
            #print("\nThe latest price is:", nodePrice)  
            print("\nThe latest path is:", Path)
            if succNode in target:
                reached_targets.append(succNode)
                j=j+1
                target.remove(succNode)
                print("Path to {} th target is: {}".format(j, Path))
                print("The destination reached are", *reached_targets) 
            #draw_color(Path)
            
        elif pathLength>=2:
            predNode = Path[pathLength-2]  
       
        
             # check prices
                                 
            # 1. downhill - Extend P to succ(k) and set price of k to price of pred(k)
            if nodePrice[succNode]<nodePrice[kNode]:
                print("Downhill Extend path to succ node and set the price of k to pred node")
                nodePrice[kNode]=nodePrice[predNode]-edgeWeight[(predNode,kNode)]
                Path.append(succNode)
                #print("\nThe latest price is:", nodePrice)  
                print("\nThe latest path is:", Path)
                 # find target only on extension
                if succNode in target:
                    reached_targets.append(succNode)
                    j=j+1
                    target.remove(succNode)
                    print("Path to {} th target is: {}".format(j, Path))
                print("The destination reached are", *reached_targets) 
                #draw_color(Path)
                
            # 2. uphill - contract path and raise the price of k to the succ(k)+1
            elif nodePrice[succNode] > nodePrice[kNode]:
                print("\n Uphill- contract and update the price")
                nodePrice[kNode]=edgeWeight[(kNode,succNode)]+ nodePrice[succNode]+1
                #print("\nThe updated price is:", nodePrice)  
                print("\nRemoving the high price node:", kNode)
                Path=Path[:-1]
                print("The updated Path is:", Path)
        
             # 3. level - has 2 conditions to avoid the loop
            elif nodePrice[kNode] == nodePrice[succNode]:
                if succNode==kNode:
                    break
                # 3.a if pred(k) has higher price than k - extend to succ(k) and raise price of k to pred(k)
                if nodePrice[predNode] > nodePrice[kNode] :
                    print("\nsame level Case 1 - Extend to succ node and update the price of k to pred node")
                    nodePrice[kNode]=nodePrice[predNode]- edgeWeight[(predNode,kNode)]
                    #print("\nThe updated price is:", nodePrice) 
                    Path.append(succNode)
                    print("The updated Path is:", Path)
                    
                    # find target only on extension
                    if succNode in target:
                        reached_targets.append(succNode)
                        j=j+1
                        target.remove(succNode)
                        print("Path to {} th target is: {}".format(j, Path))
                        print("The destination reached are", *reached_targets) 
                    #draw_color(Path)
            
                # 3.b if price of pred(k) is same as k
                elif (nodePrice[predNode] == nodePrice[kNode]):
                    print("\nsame level Case 2- Contract, remove the node and update the price")
                    nodePrice[kNode]=nodePrice[kNode]+1
                    print("\nRemoving the high price node:", kNode)
                    #print("\nThe updated price is:", nodePrice) 
                    Path=Path[:-1]
                    print("The updated Path is:", Path) 
                    
                
                
        i=i+1  
         
        
        if target == []:
            print("all destination reached")
            print("\nThe path is:", Path)
            #print("The price of each node is:", nodePrice)
            #print("The high price nodes:",highpriceNode )
            print("The number of steps", i)
            print("The destination reached are", *reached_targets)
           # draw_color(Path)
            break
    return Path

# %% [markdown]
# ## Experiment 7.b

# %% [markdown]
# ## Arc weights as per relation in query
# ### For strong relations, arc wt = 0, medium = 3, weak = 6
#
# ## reusing prices

# %%
{'author_in_affiliation',
 'author_write_paper',
 'paper_cite_paper',
 'paper_in_domain',
 'paper_in_venue'}
# Out:
# {'author_in_affiliation',
#  'author_write_paper',
#  'paper_cite_paper',
#  'paper_in_domain',
#  'paper_in_venue'}

# %% [markdown]
# ## Run 1

# %%
#query = " if author Hang Li cited work on Equations for part-of-speech tagging"

source = int("11016")
target= int("14376")


# keep a track of current nodes| Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]
# initialize zero price
nodePrice = intial_price(0)

# %%
strong = 'paper_cite_paper'
medium= 'author_write_paper'
edgeWeight= arc_weights_relation(strong, medium)

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {12254: 0, 9890: 0, 9726: 0, 10922: 0, 1831: 0, 8656: 0, 11065: 0, 9377: 0, 10720: 0, 14844: 0, 11989: 0, 323: 0, 7944: 0, 15227: 0, 8284: 0, 13777: 0, 8167: 0, 9199: 0, 351: 0, 8134: 0, 11332: 0, 9189: 0, 8543: 0, 4225: 0}
# the weights of available edges is: {(11016, 12254): 3, (11016, 9890): 3, (11016, 9726): 3, (11016, 10922): 3, (11016, 1831): 6, (11016, 8656): 3, (11016, 11065): 3, (11016, 9377): 3, (11016, 10720): 3, (11016, 14844): 3, (11016, 11989): 3, (11016, 323): 6, (11016, 7944): 3, (11016, 15227): 3, (11016, 8284): 3, (11016, 13777): 3, (11016, 8167): 3, (11016, 9199): 3, (11016, 351): 6, (11016, 8134): 3, (11016, 11332): 3, (11016, 9189): 3, (11016, 8543): 3, (11016, 4225): 6}
#
# The new nodes chosen are: {12254: 0, 9890: 0, 9726: 0, 10922: 0, 1831: 0, 8656: 0, 11065: 0, 9377: 0, 10720: 0, 14844: 0, 11989: 0, 323: 0, 7944: 0, 15227: 0, 8284: 0, 13777: 0, 8167: 0, 9199: 0, 351: 0, 8134: 0, 11332: 0, 9189: 0, 8543: 0, 4225: 0}
#
# The new prices of chosen are: {12254: 3, 9890: 3, 9726: 3, 10922: 3, 1831: 6, 8656: 3, 11065: 3, 9377: 3, 10720: 3, 14844: 3, 11989: 3, 323: 6, 7944: 3, 15227: 3, 8284: 3, 13777: 3, 8167: 3, 9199: 3, 351: 6, 8134: 3, 11332: 3, 9189: 3, 8543: 3, 4225: 6}
#
# The new min node chosen is: [12254, 9890, 9726, 10922, 8656, 11065, 9377, 10720, 14844, 11989, 7944, 15227, 8284, 13777, 8167, 9199, 8134, 11332, 9189, 8543]
# The successor node is: 12254
# The path is: [11016]
# The current K node is: 11016
# The succ node is: 12254
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11016, 12254]
# the price of available nodes is: {10720: 0, 7483: 0, 387: 0, 4097: 0, 2456: 0, 6680: 0, 730: 0, 1639: 0, 7535: 0, 12310: 0, 4906: 0, 7519: 0, 7458: 0, 1325: 0, 11031: 0}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {10720: 0, 7483: 0, 387: 0, 4097: 0, 2456: 0, 6680: 0, 730: 0, 1639: 0, 7535: 0, 12310: 0, 4906: 0, 7519: 0, 7458: 0, 1325: 0, 11031: 0}
#
# The new prices of chosen are: {10720: 0, 7483: 0, 387: 6, 4097: 6, 2456: 6, 6680: 0, 730: 6, 1639: 6, 7535: 0, 12310: 0, 4906: 0, 7519: 0, 7458: 0, 1325: 6, 11031: 0}
#
# The new min node chosen is: [10720, 7483, 6680, 7535, 12310, 4906, 7519, 7458, 11031]
# The successor node is: 10720
# The path is: [11016, 12254]
# The current K node is: 12254
# The succ node is: 10720
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720]
# the price of available nodes is: {7483: 0, 387: 0, 4097: 0, 2456: 0, 1639: 0, 7535: 0, 12310: 0, 7458: 0, 1325: 0, 6510: 0, 10214: 0, 2343: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {7483: 0, 387: 0, 4097: 0, 2456: 0, 1639: 0, 7535: 0, 12310: 0, 7458: 0, 1325: 0, 6510: 0, 10214: 0, 2343: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {7483: 0, 387: 6, 4097: 6, 2456: 6, 1639: 6, 7535: 0, 12310: 0, 7458: 0, 1325: 6, 6510: 0, 10214: 0, 2343: 6, 9101: 0, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [7483, 7535, 12310, 7458, 6510, 10214, 9101, 6655]
# The successor node is: 7483
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 7483
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 7483]
# the price of available nodes is: {387: 0, 4097: 0, 2099: 0}
# the weights of available edges is: {(7483, 1520): 6, (7483, 21): 6, (7483, 1036): 6, (7483, 2905): 6, (7483, 1372): 6, (7483, 4097): 6, (7483, 1155): 6, (7483, 2099): 6, (7483, 387): 6}
#
# The new nodes chosen are: {387: 0, 4097: 0, 2099: 0}
#
# The new prices of chosen are: {387: 6, 4097: 6, 2099: 6}
#
# The new min node chosen is: [387, 4097, 2099]
# The successor node is: 387
# The path is: [11016, 12254, 10720, 7483]
# The current K node is: 7483
# The succ node is: 387
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 7483, 387]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7483]
# the price of available nodes is: {387: 1000000, 4097: 0, 2099: 0}
# the weights of available edges is: {(7483, 1520): 6, (7483, 21): 6, (7483, 1036): 6, (7483, 2905): 6, (7483, 1372): 6, (7483, 4097): 6, (7483, 1155): 6, (7483, 2099): 6, (7483, 387): 6}
#
# The new nodes chosen are: {4097: 0, 2099: 0}
#
# The new prices of chosen are: {4097: 6, 2099: 6}
#
# The new min node chosen is: [4097, 2099]
# The successor node is: 4097
# The path is: [11016, 12254, 10720, 7483]
# The current K node is: 7483
# The succ node is: 4097
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7483, 4097]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7483]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 0}
# the weights of available edges is: {(7483, 1520): 6, (7483, 21): 6, (7483, 1036): 6, (7483, 2905): 6, (7483, 1372): 6, (7483, 4097): 6, (7483, 1155): 6, (7483, 2099): 6, (7483, 387): 6}
#
# The new nodes chosen are: {2099: 0}
#
# The new prices of chosen are: {2099: 6}
#
# The new min node chosen is: [2099]
# The successor node is: 2099
# The path is: [11016, 12254, 10720, 7483]
# The current K node is: 7483
# The succ node is: 2099
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7483, 2099]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7483]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 1000000}
# the weights of available edges is: {(7483, 1520): 6, (7483, 21): 6, (7483, 1036): 6, (7483, 2905): 6, (7483, 1372): 6, (7483, 4097): 6, (7483, 1155): 6, (7483, 2099): 6, (7483, 387): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 0, 7535: 0, 12310: 0, 7458: 0, 1325: 0, 6510: 0, 10214: 0, 2343: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 1639: 0, 7535: 0, 12310: 0, 7458: 0, 1325: 0, 6510: 0, 10214: 0, 2343: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {2456: 6, 1639: 6, 7535: 0, 12310: 0, 7458: 0, 1325: 6, 6510: 0, 10214: 0, 2343: 6, 9101: 0, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [7535, 12310, 7458, 6510, 10214, 9101, 6655]
# The successor node is: 7535
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 7535
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7535]
# the price of available nodes is: {387: 1000000, 4097: 1000000}
# the weights of available edges is: {(7535, 1372): 6, (7535, 4097): 6, (7535, 387): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 0, 7535: 1000000, 12310: 0, 7458: 0, 1325: 0, 6510: 0, 10214: 0, 2343: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 1639: 0, 12310: 0, 7458: 0, 1325: 0, 6510: 0, 10214: 0, 2343: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {2456: 6, 1639: 6, 12310: 0, 7458: 0, 1325: 6, 6510: 0, 10214: 0, 2343: 6, 9101: 0, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [12310, 7458, 6510, 10214, 9101, 6655]
# The successor node is: 12310
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 12310
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310]
# the price of available nodes is: {1639: 0, 1325: 0, 1483: 0, 10214: 0, 2343: 0, 4119: 0, 12802: 0}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {1639: 0, 1325: 0, 1483: 0, 10214: 0, 2343: 0, 4119: 0, 12802: 0}
#
# The new prices of chosen are: {1639: 6, 1325: 6, 1483: 6, 10214: 0, 2343: 6, 4119: 6, 12802: 0}
#
# The new min node chosen is: [10214, 12802]
# The successor node is: 10214
# The path is: [11016, 12254, 10720, 12310]
# The current K node is: 12310
# The succ node is: 10214
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 12310, 10214]
# the price of available nodes is: {4119: 0}
# the weights of available edges is: {(10214, 356): 6, (10214, 4119): 6}
#
# The new nodes chosen are: {4119: 0}
#
# The new prices of chosen are: {4119: 6}
#
# The new min node chosen is: [4119]
# The successor node is: 4119
# The path is: [11016, 12254, 10720, 12310, 10214]
# The current K node is: 10214
# The succ node is: 4119
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 12310, 10214, 4119]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310, 10214]
# the price of available nodes is: {4119: 1000000}
# the weights of available edges is: {(10214, 356): 6, (10214, 4119): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {1639: 0, 1325: 0, 1483: 0, 10214: 1000000, 2343: 0, 4119: 1000000, 12802: 0}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {1639: 0, 1325: 0, 1483: 0, 2343: 0, 12802: 0}
#
# The new prices of chosen are: {1639: 6, 1325: 6, 1483: 6, 2343: 6, 12802: 0}
#
# The new min node chosen is: [12802]
# The successor node is: 12802
# The path is: [11016, 12254, 10720, 12310]
# The current K node is: 12310
# The succ node is: 12802
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 12802]
# the price of available nodes is: {4088: 0, 5696: 0, 1078: 0, 9427: 0}
# the weights of available edges is: {(12802, 5696): 0, (12802, 1078): 6, (12802, 9427): 0, (12802, 4088): 6}
#
# The new nodes chosen are: {4088: 0, 5696: 0, 1078: 0, 9427: 0}
#
# The new prices of chosen are: {4088: 6, 5696: 0, 1078: 6, 9427: 0}
#
# The new min node chosen is: [5696, 9427]
# The successor node is: 5696
# The path is: [11016, 12254, 10720, 12310, 12802]
# The current K node is: 12802
# The succ node is: 5696
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 12310, 12802, 5696]
# the price of available nodes is: {4097: 1000000, 5594: 0, 2975: 0}
# the weights of available edges is: {(5696, 5594): 0, (5696, 4097): 6, (5696, 2975): 6, (5696, 945): 6}
#
# The new nodes chosen are: {5594: 0, 2975: 0}
#
# The new prices of chosen are: {5594: 0, 2975: 6}
#
# The new min node chosen is: [5594]
# The successor node is: 5594
# The path is: [11016, 12254, 10720, 12310, 12802, 5696]
# The current K node is: 5696
# The succ node is: 5594
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 12310, 12802, 5696, 5594]
# the price of available nodes is: {1493: 0}
# the weights of available edges is: {(5594, 7868): 0, (5594, 4117): 6, (5594, 1493): 6}
#
# The new nodes chosen are: {1493: 0}
#
# The new prices of chosen are: {1493: 6}
#
# The new min node chosen is: [1493]
# The successor node is: 1493
# The path is: [11016, 12254, 10720, 12310, 12802, 5696, 5594]
# The current K node is: 5594
# The succ node is: 1493
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 12310, 12802, 5696, 5594, 1493]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310, 12802, 5696, 5594]
# the price of available nodes is: {1493: 1000000}
# the weights of available edges is: {(5594, 7868): 0, (5594, 4117): 6, (5594, 1493): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {4097: 1000000, 5594: 1000000, 2975: 0}
# the weights of available edges is: {(5696, 5594): 0, (5696, 4097): 6, (5696, 2975): 6, (5696, 945): 6}
#
# The new nodes chosen are: {2975: 0}
#
# The new prices of chosen are: {2975: 6}
#
# The new min node chosen is: [2975]
# The successor node is: 2975
# The path is: [11016, 12254, 10720, 12310, 12802, 5696]
# The current K node is: 5696
# The succ node is: 2975
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 12802, 5696, 2975]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310, 12802, 5696]
# the price of available nodes is: {4097: 1000000, 5594: 1000000, 2975: 1000000}
# the weights of available edges is: {(5696, 5594): 0, (5696, 4097): 6, (5696, 2975): 6, (5696, 945): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {4088: 0, 5696: 1000000, 1078: 0, 9427: 0}
# the weights of available edges is: {(12802, 5696): 0, (12802, 1078): 6, (12802, 9427): 0, (12802, 4088): 6}
#
# The new nodes chosen are: {4088: 0, 1078: 0, 9427: 0}
#
# The new prices of chosen are: {4088: 6, 1078: 6, 9427: 0}
#
# The new min node chosen is: [9427]
# The successor node is: 9427
# The path is: [11016, 12254, 10720, 12310, 12802]
# The current K node is: 12802
# The succ node is: 9427
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 12802, 9427]
# the price of available nodes is: {2322: 0, 4088: 0}
# the weights of available edges is: {(9427, 4583): 0, (9427, 13518): 0, (9427, 4088): 6, (9427, 2322): 6, (9427, 721): 6, (9427, 9484): 0}
#
# The new nodes chosen are: {2322: 0, 4088: 0}
#
# The new prices of chosen are: {2322: 6, 4088: 6}
#
# The new min node chosen is: [2322, 4088]
# The successor node is: 2322
# The path is: [11016, 12254, 10720, 12310, 12802, 9427]
# The current K node is: 9427
# The succ node is: 2322
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 12310, 12802, 9427, 2322]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310, 12802, 9427]
# the price of available nodes is: {2322: 1000000, 4088: 0}
# the weights of available edges is: {(9427, 4583): 0, (9427, 13518): 0, (9427, 4088): 6, (9427, 2322): 6, (9427, 721): 6, (9427, 9484): 0}
#
# The new nodes chosen are: {4088: 0}
#
# The new prices of chosen are: {4088: 6}
#
# The new min node chosen is: [4088]
# The successor node is: 4088
# The path is: [11016, 12254, 10720, 12310, 12802, 9427]
# The current K node is: 9427
# The succ node is: 4088
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 12802, 9427, 4088]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310, 12802, 9427]
# the price of available nodes is: {2322: 1000000, 4088: 1000000}
# the weights of available edges is: {(9427, 4583): 0, (9427, 13518): 0, (9427, 4088): 6, (9427, 2322): 6, (9427, 721): 6, (9427, 9484): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {4088: 1000000, 5696: 1000000, 1078: 0, 9427: 1000000}
# the weights of available edges is: {(12802, 5696): 0, (12802, 1078): 6, (12802, 9427): 0, (12802, 4088): 6}
#
# The new nodes chosen are: {1078: 0}
#
# The new prices of chosen are: {1078: 6}
#
# The new min node chosen is: [1078]
# The successor node is: 1078
# The path is: [11016, 12254, 10720, 12310, 12802]
# The current K node is: 12802
# The succ node is: 1078
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 12802, 1078]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310, 12802]
# the price of available nodes is: {4088: 1000000, 5696: 1000000, 1078: 1000000, 9427: 1000000}
# the weights of available edges is: {(12802, 5696): 0, (12802, 1078): 6, (12802, 9427): 0, (12802, 4088): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {1639: 0, 1325: 0, 1483: 0, 10214: 1000000, 2343: 0, 4119: 1000000, 12802: 1000000}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {1639: 0, 1325: 0, 1483: 0, 2343: 0}
#
# The new prices of chosen are: {1639: 6, 1325: 6, 1483: 6, 2343: 6}
#
# The new min node chosen is: [1639, 1325, 1483, 2343]
# The successor node is: 1639
# The path is: [11016, 12254, 10720, 12310]
# The current K node is: 12310
# The succ node is: 1639
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 1639]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310]
# the price of available nodes is: {1639: 1000000, 1325: 0, 1483: 0, 10214: 1000000, 2343: 0, 4119: 1000000, 12802: 1000000}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {1325: 0, 1483: 0, 2343: 0}
#
# The new prices of chosen are: {1325: 6, 1483: 6, 2343: 6}
#
# The new min node chosen is: [1325, 1483, 2343]
# The successor node is: 1325
# The path is: [11016, 12254, 10720, 12310]
# The current K node is: 12310
# The succ node is: 1325
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 1325]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310]
# the price of available nodes is: {1639: 1000000, 1325: 1000000, 1483: 0, 10214: 1000000, 2343: 0, 4119: 1000000, 12802: 1000000}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {1483: 0, 2343: 0}
#
# The new prices of chosen are: {1483: 6, 2343: 6}
#
# The new min node chosen is: [1483, 2343]
# The successor node is: 1483
# The path is: [11016, 12254, 10720, 12310]
# The current K node is: 12310
# The succ node is: 1483
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 1483]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310]
# the price of available nodes is: {1639: 1000000, 1325: 1000000, 1483: 1000000, 10214: 1000000, 2343: 0, 4119: 1000000, 12802: 1000000}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {2343: 0}
#
# The new prices of chosen are: {2343: 6}
#
# The new min node chosen is: [2343]
# The successor node is: 2343
# The path is: [11016, 12254, 10720, 12310]
# The current K node is: 12310
# The succ node is: 2343
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 12310, 2343]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 12310]
# the price of available nodes is: {1639: 1000000, 1325: 1000000, 1483: 1000000, 10214: 1000000, 2343: 1000000, 4119: 1000000, 12802: 1000000}
# the weights of available edges is: {(12310, 1483): 6, (12310, 2343): 6, (12310, 790): 6, (12310, 431): 0, (12310, 9128): 0, (12310, 10214): 0, (12310, 4119): 6, (12310, 1639): 6, (12310, 12802): 0, (12310, 1325): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 0, 1325: 1000000, 6510: 0, 10214: 1000000, 2343: 1000000, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 7458: 0, 6510: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {2456: 6, 7458: 0, 6510: 0, 9101: 0, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [7458, 6510, 9101, 6655]
# The successor node is: 7458
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 7458
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7458]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 1000000, 11747: 0, 1856: 0, 203: 0, 166: 0}
# the weights of available edges is: {(7458, 2099): 6, (7458, 1856): 6, (7458, 4097): 6, (7458, 6178): 0, (7458, 203): 6, (7458, 1484): 6, (7458, 7782): 0, (7458, 166): 6, (7458, 11747): 0, (7458, 387): 6, (7458, 6854): 0}
#
# The new nodes chosen are: {11747: 0, 1856: 0, 203: 0, 166: 0}
#
# The new prices of chosen are: {11747: 0, 1856: 6, 203: 6, 166: 6}
#
# The new min node chosen is: [11747]
# The successor node is: 11747
# The path is: [11016, 12254, 10720, 7458]
# The current K node is: 7458
# The succ node is: 11747
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 7458, 11747]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2099: 1000000, 770: 0}
# the weights of available edges is: {(11747, 8017): 0, (11747, 4097): 6, (11747, 7483): 0, (11747, 770): 6, (11747, 387): 6, (11747, 2099): 6, (11747, 459): 6, (11747, 1664): 6}
#
# The new nodes chosen are: {770: 0}
#
# The new prices of chosen are: {770: 6}
#
# The new min node chosen is: [770]
# The successor node is: 770
# The path is: [11016, 12254, 10720, 7458, 11747]
# The current K node is: 11747
# The succ node is: 770
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 7458, 11747, 770]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7458, 11747]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2099: 1000000, 770: 1000000}
# the weights of available edges is: {(11747, 8017): 0, (11747, 4097): 6, (11747, 7483): 0, (11747, 770): 6, (11747, 387): 6, (11747, 2099): 6, (11747, 459): 6, (11747, 1664): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 1000000, 11747: 1000000, 1856: 0, 203: 0, 166: 0}
# the weights of available edges is: {(7458, 2099): 6, (7458, 1856): 6, (7458, 4097): 6, (7458, 6178): 0, (7458, 203): 6, (7458, 1484): 6, (7458, 7782): 0, (7458, 166): 6, (7458, 11747): 0, (7458, 387): 6, (7458, 6854): 0}
#
# The new nodes chosen are: {1856: 0, 203: 0, 166: 0}
#
# The new prices of chosen are: {1856: 6, 203: 6, 166: 6}
#
# The new min node chosen is: [1856, 203, 166]
# The successor node is: 1856
# The path is: [11016, 12254, 10720, 7458]
# The current K node is: 7458
# The succ node is: 1856
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7458, 1856]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7458]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 1000000, 11747: 1000000, 1856: 1000000, 203: 0, 166: 0}
# the weights of available edges is: {(7458, 2099): 6, (7458, 1856): 6, (7458, 4097): 6, (7458, 6178): 0, (7458, 203): 6, (7458, 1484): 6, (7458, 7782): 0, (7458, 166): 6, (7458, 11747): 0, (7458, 387): 6, (7458, 6854): 0}
#
# The new nodes chosen are: {203: 0, 166: 0}
#
# The new prices of chosen are: {203: 6, 166: 6}
#
# The new min node chosen is: [203, 166]
# The successor node is: 203
# The path is: [11016, 12254, 10720, 7458]
# The current K node is: 7458
# The succ node is: 203
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7458, 203]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7458]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 1000000, 11747: 1000000, 1856: 1000000, 203: 1000000, 166: 0}
# the weights of available edges is: {(7458, 2099): 6, (7458, 1856): 6, (7458, 4097): 6, (7458, 6178): 0, (7458, 203): 6, (7458, 1484): 6, (7458, 7782): 0, (7458, 166): 6, (7458, 11747): 0, (7458, 387): 6, (7458, 6854): 0}
#
# The new nodes chosen are: {166: 0}
#
# The new prices of chosen are: {166: 6}
#
# The new min node chosen is: [166]
# The successor node is: 166
# The path is: [11016, 12254, 10720, 7458]
# The current K node is: 7458
# The succ node is: 166
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 7458, 166]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 7458]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2099: 1000000, 11747: 1000000, 1856: 1000000, 203: 1000000, 166: 1000000}
# the weights of available edges is: {(7458, 2099): 6, (7458, 1856): 6, (7458, 4097): 6, (7458, 6178): 0, (7458, 203): 6, (7458, 1484): 6, (7458, 7782): 0, (7458, 166): 6, (7458, 11747): 0, (7458, 387): 6, (7458, 6854): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 0, 10214: 1000000, 2343: 1000000, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 6510: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {2456: 6, 6510: 0, 9101: 0, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [6510, 9101, 6655]
# The successor node is: 6510
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 6510
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 6510]
# the price of available nodes is: {1709: 0, 2110: 0, 4119: 1000000, 203: 1000000}
# the weights of available edges is: {(6510, 2110): 6, (6510, 1709): 6, (6510, 203): 6, (6510, 4119): 6, (6510, 10586): 0}
#
# The new nodes chosen are: {1709: 0, 2110: 0}
#
# The new prices of chosen are: {1709: 6, 2110: 6}
#
# The new min node chosen is: [1709, 2110]
# The successor node is: 1709
# The path is: [11016, 12254, 10720, 6510]
# The current K node is: 6510
# The succ node is: 1709
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 6510, 1709]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 6510]
# the price of available nodes is: {1709: 1000000, 2110: 0, 4119: 1000000, 203: 1000000}
# the weights of available edges is: {(6510, 2110): 6, (6510, 1709): 6, (6510, 203): 6, (6510, 4119): 6, (6510, 10586): 0}
#
# The new nodes chosen are: {2110: 0}
#
# The new prices of chosen are: {2110: 6}
#
# The new min node chosen is: [2110]
# The successor node is: 2110
# The path is: [11016, 12254, 10720, 6510]
# The current K node is: 6510
# The succ node is: 2110
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 6510, 2110]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 6510]
# the price of available nodes is: {1709: 1000000, 2110: 1000000, 4119: 1000000, 203: 1000000}
# the weights of available edges is: {(6510, 2110): 6, (6510, 1709): 6, (6510, 203): 6, (6510, 4119): 6, (6510, 10586): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 1000000, 10214: 1000000, 2343: 1000000, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 9101: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {2456: 6, 9101: 0, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [9101, 6655]
# The successor node is: 9101
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 9101
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 9101]
# the price of available nodes is: {12310: 1000000, 1709: 1000000, 4119: 1000000}
# the weights of available edges is: {(9101, 4119): 6, (9101, 1709): 6, (9101, 12310): 0, (9101, 12757): 0, (9101, 9120): 0, (9101, 5523): 0, (9101, 5311): 0, (9101, 2446): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 1000000, 10214: 1000000, 2343: 1000000, 9101: 1000000, 1939: 0, 1259: 0, 6655: 0}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 1939: 0, 1259: 0, 6655: 0}
#
# The new prices of chosen are: {2456: 6, 1939: 6, 1259: 6, 6655: 0}
#
# The new min node chosen is: [6655]
# The successor node is: 6655
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 6655
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 6655]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 7458: 1000000, 389: 0, 2099: 1000000}
# the weights of available edges is: {(6655, 4097): 6, (6655, 12587): 0, (6655, 387): 6, (6655, 945): 6, (6655, 1951): 6, (6655, 7458): 0, (6655, 14040): 0, (6655, 7483): 0, (6655, 6327): 0, (6655, 1484): 6, (6655, 389): 6, (6655, 2836): 6, (6655, 2099): 6}
#
# The new nodes chosen are: {389: 0}
#
# The new prices of chosen are: {389: 6}
#
# The new min node chosen is: [389]
# The successor node is: 389
# The path is: [11016, 12254, 10720, 6655]
# The current K node is: 6655
# The succ node is: 389
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 10720, 6655, 389]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720, 6655]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 7458: 1000000, 389: 1000000, 2099: 1000000}
# the weights of available edges is: {(6655, 4097): 6, (6655, 12587): 0, (6655, 387): 6, (6655, 945): 6, (6655, 1951): 6, (6655, 7458): 0, (6655, 14040): 0, (6655, 7483): 0, (6655, 6327): 0, (6655, 1484): 6, (6655, 389): 6, (6655, 2836): 6, (6655, 2099): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 1000000, 10214: 1000000, 2343: 1000000, 9101: 1000000, 1939: 0, 1259: 0, 6655: 1000000}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {2456: 0, 1939: 0, 1259: 0}
#
# The new prices of chosen are: {2456: 6, 1939: 6, 1259: 6}
#
# The new min node chosen is: [2456, 1939, 1259]
# The successor node is: 2456
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 2456
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 2456]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 1000000, 10214: 1000000, 2343: 1000000, 9101: 1000000, 1939: 0, 1259: 0, 6655: 1000000}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {1939: 0, 1259: 0}
#
# The new prices of chosen are: {1939: 6, 1259: 6}
#
# The new min node chosen is: [1939, 1259]
# The successor node is: 1939
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 1939
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 1939]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 1000000, 10214: 1000000, 2343: 1000000, 9101: 1000000, 1939: 1000000, 1259: 0, 6655: 1000000}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {1259: 0}
#
# The new prices of chosen are: {1259: 6}
#
# The new min node chosen is: [1259]
# The successor node is: 1259
# The path is: [11016, 12254, 10720]
# The current K node is: 10720
# The succ node is: 1259
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 10720, 1259]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 10720]
# the price of available nodes is: {7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 1639: 1000000, 7535: 1000000, 12310: 1000000, 7458: 1000000, 1325: 1000000, 6510: 1000000, 10214: 1000000, 2343: 1000000, 9101: 1000000, 1939: 1000000, 1259: 1000000, 6655: 1000000}
# the weights of available edges is: {(10720, 2343): 6, (10720, 7483): 0, (10720, 9101): 0, (10720, 2456): 6, (10720, 4097): 6, (10720, 1939): 6, (10720, 12310): 0, (10720, 1259): 6, (10720, 1325): 6, (10720, 7535): 0, (10720, 6510): 0, (10720, 10214): 0, (10720, 1639): 6, (10720, 6655): 0, (10720, 7458): 0, (10720, 387): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {10720: 1000000, 7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 6680: 0, 730: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 4906: 0, 7519: 0, 7458: 1000000, 1325: 1000000, 11031: 0}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {6680: 0, 730: 0, 4906: 0, 7519: 0, 11031: 0}
#
# The new prices of chosen are: {6680: 0, 730: 6, 4906: 0, 7519: 0, 11031: 0}
#
# The new min node chosen is: [6680, 4906, 7519, 11031]
# The successor node is: 6680
# The path is: [11016, 12254]
# The current K node is: 12254
# The succ node is: 6680
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 6680]
# the price of available nodes is: {1302: 0}
# the weights of available edges is: {(6680, 1302): 6, (6680, 1924): 6, (6680, 4639): 0, (6680, 5324): 0, (6680, 4117): 6, (6680, 4703): 0}
#
# The new nodes chosen are: {1302: 0}
#
# The new prices of chosen are: {1302: 6}
#
# The new min node chosen is: [1302]
# The successor node is: 1302
# The path is: [11016, 12254, 6680]
# The current K node is: 6680
# The succ node is: 1302
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 12254, 6680, 1302]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254, 6680]
# the price of available nodes is: {1302: 1000000}
# the weights of available edges is: {(6680, 1302): 6, (6680, 1924): 6, (6680, 4639): 0, (6680, 5324): 0, (6680, 4117): 6, (6680, 4703): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {10720: 1000000, 7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 6680: 1000000, 730: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 4906: 0, 7519: 0, 7458: 1000000, 1325: 1000000, 11031: 0}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {730: 0, 4906: 0, 7519: 0, 11031: 0}
#
# The new prices of chosen are: {730: 6, 4906: 0, 7519: 0, 11031: 0}
#
# The new min node chosen is: [4906, 7519, 11031]
# The successor node is: 4906
# The path is: [11016, 12254]
# The current K node is: 12254
# The succ node is: 4906
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 4906]
# the price of available nodes is: {12310: 1000000}
# the weights of available edges is: {(4906, 9025): 0, (4906, 12310): 0, (4906, 6317): 0, (4906, 1015): 6, (4906, 4117): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {10720: 1000000, 7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 6680: 1000000, 730: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 4906: 1000000, 7519: 0, 7458: 1000000, 1325: 1000000, 11031: 0}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {730: 0, 7519: 0, 11031: 0}
#
# The new prices of chosen are: {730: 6, 7519: 0, 11031: 0}
#
# The new min node chosen is: [7519, 11031]
# The successor node is: 7519
# The path is: [11016, 12254]
# The current K node is: 12254
# The succ node is: 7519
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 7519]
# the price of available nodes is: {4119: 1000000}
# the weights of available edges is: {(7519, 4390): 0, (7519, 8618): 0, (7519, 4): 6, (7519, 1408): 6, (7519, 7786): 0, (7519, 10183): 0, (7519, 7868): 0, (7519, 4119): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {10720: 1000000, 7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 6680: 1000000, 730: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 4906: 1000000, 7519: 1000000, 7458: 1000000, 1325: 1000000, 11031: 0}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {730: 0, 11031: 0}
#
# The new prices of chosen are: {730: 6, 11031: 0}
#
# The new min node chosen is: [11031]
# The successor node is: 11031
# The path is: [11016, 12254]
# The current K node is: 12254
# The succ node is: 11031
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 11031]
# the price of available nodes is: {387: 1000000, 1639: 1000000, 12310: 1000000, 7519: 1000000, 1325: 1000000, 4088: 1000000}
# the weights of available edges is: {(11031, 1639): 6, (11031, 11026): 0, (11031, 8618): 0, (11031, 12310): 0, (11031, 790): 6, (11031, 7519): 0, (11031, 11130): 0, (11031, 387): 6, (11031, 4088): 6, (11031, 1325): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {10720: 1000000, 7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 6680: 1000000, 730: 0, 1639: 1000000, 7535: 1000000, 12310: 1000000, 4906: 1000000, 7519: 1000000, 7458: 1000000, 1325: 1000000, 11031: 1000000}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {730: 0}
#
# The new prices of chosen are: {730: 6}
#
# The new min node chosen is: [730]
# The successor node is: 730
# The path is: [11016, 12254]
# The current K node is: 12254
# The succ node is: 730
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 12254, 730]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 12254]
# the price of available nodes is: {10720: 1000000, 7483: 1000000, 387: 1000000, 4097: 1000000, 2456: 1000000, 6680: 1000000, 730: 1000000, 1639: 1000000, 7535: 1000000, 12310: 1000000, 4906: 1000000, 7519: 1000000, 7458: 1000000, 1325: 1000000, 11031: 1000000}
# the weights of available edges is: {(12254, 7483): 0, (12254, 387): 6, (12254, 10720): 0, (12254, 4097): 6, (12254, 2456): 6, (12254, 6680): 0, (12254, 730): 6, (12254, 1639): 6, (12254, 7535): 0, (12254, 12310): 0, (12254, 4906): 0, (12254, 7519): 0, (12254, 7458): 0, (12254, 1325): 6, (12254, 11031): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {12254: 1000000, 9890: 0, 9726: 0, 10922: 0, 1831: 0, 8656: 0, 11065: 0, 9377: 0, 10720: 1000000, 14844: 0, 11989: 0, 323: 0, 7944: 0, 15227: 0, 8284: 0, 13777: 0, 8167: 0, 9199: 0, 351: 0, 8134: 0, 11332: 0, 9189: 0, 8543: 0, 4225: 0}
# the weights of available edges is: {(11016, 12254): 3, (11016, 9890): 3, (11016, 9726): 3, (11016, 10922): 3, (11016, 1831): 6, (11016, 8656): 3, (11016, 11065): 3, (11016, 9377): 3, (11016, 10720): 3, (11016, 14844): 3, (11016, 11989): 3, (11016, 323): 6, (11016, 7944): 3, (11016, 15227): 3, (11016, 8284): 3, (11016, 13777): 3, (11016, 8167): 3, (11016, 9199): 3, (11016, 351): 6, (11016, 8134): 3, (11016, 11332): 3, (11016, 9189): 3, (11016, 8543): 3, (11016, 4225): 6}
#
# The new nodes chosen are: {9890: 0, 9726: 0, 10922: 0, 1831: 0, 8656: 0, 11065: 0, 9377: 0, 14844: 0, 11989: 0, 323: 0, 7944: 0, 15227: 0, 8284: 0, 13777: 0, 8167: 0, 9199: 0, 351: 0, 8134: 0, 11332: 0, 9189: 0, 8543: 0, 4225: 0}
#
# The new prices of chosen are: {9890: 3, 9726: 3, 10922: 3, 1831: 6, 8656: 3, 11065: 3, 9377: 3, 14844: 3, 11989: 3, 323: 6, 7944: 3, 15227: 3, 8284: 3, 13777: 3, 8167: 3, 9199: 3, 351: 6, 8134: 3, 11332: 3, 9189: 3, 8543: 3, 4225: 6}
#
# The new min node chosen is: [9890, 9726, 10922, 8656, 11065, 9377, 14844, 11989, 7944, 15227, 8284, 13777, 8167, 9199, 8134, 11332, 9189, 8543]
# The successor node is: 9890
# The path is: [11016]
# The current K node is: 11016
# The succ node is: 9890
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11016, 9890]
# the price of available nodes is: {387: 1000000, 4093: 0, 1709: 1000000, 13258: 0, 1090: 0, 2087: 0, 2978: 0}
# the weights of available edges is: {(9890, 4093): 6, (9890, 387): 6, (9890, 1709): 6, (9890, 13258): 0, (9890, 1090): 6, (9890, 2087): 6, (9890, 2978): 6}
#
# The new nodes chosen are: {4093: 0, 13258: 0, 1090: 0, 2087: 0, 2978: 0}
#
# The new prices of chosen are: {4093: 6, 13258: 0, 1090: 6, 2087: 6, 2978: 6}
#
# The new min node chosen is: [13258]
# The successor node is: 13258
# The path is: [11016, 9890]
# The current K node is: 9890
# The succ node is: 13258
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9890, 13258]
# the price of available nodes is: {4126: 0}
# the weights of available edges is: {(13258, 938): 6, (13258, 4126): 6}
#
# The new nodes chosen are: {4126: 0}
#
# The new prices of chosen are: {4126: 6}
#
# The new min node chosen is: [4126]
# The successor node is: 4126
# The path is: [11016, 9890, 13258]
# The current K node is: 13258
# The succ node is: 4126
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9890, 13258, 4126]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9890, 13258]
# the price of available nodes is: {4126: 1000000}
# the weights of available edges is: {(13258, 938): 6, (13258, 4126): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {387: 1000000, 4093: 0, 1709: 1000000, 13258: 1000000, 1090: 0, 2087: 0, 2978: 0}
# ...
# the weights of available edges is: {(4408, 2281): 6, (4408, 1856): 6, (4408, 4132): 6, (4408, 1030): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {717: 1000000, 2502: 0, 4408: 1000000, 4132: 1000000}
# the weights of available edges is: {(11757, 949): 6, (11757, 4132): 6, (11757, 951): 6, (11757, 1370): 6, (11757, 717): 6, (11757, 4408): 0, (11757, 5419): 0, (11757, 1227): 6, (11757, 2502): 6}
#
# The new nodes chosen are: {2502: 0}
#
# The new prices of chosen are: {2502: 6}
#
# The new min node chosen is: [2502]
# The successor node is: 2502
# The path is: [11016, 9726, 12801, 11757]
# The current K node is: 11757
# The succ node is: 2502
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 12801, 11757, 2502]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 12801, 11757]
# the price of available nodes is: {717: 1000000, 2502: 1000000, 4408: 1000000, 4132: 1000000}
# the weights of available edges is: {(11757, 949): 6, (11757, 4132): 6, (11757, 951): 6, (11757, 1370): 6, (11757, 717): 6, (11757, 4408): 0, (11757, 5419): 0, (11757, 1227): 6, (11757, 2502): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {4097: 1000000, 1220: 0, 1546: 0, 4425: 1000000, 11757: 1000000}
# the weights of available edges is: {(12801, 4097): 6, (12801, 1220): 6, (12801, 1546): 6, (12801, 4425): 0, (12801, 11757): 0}
#
# The new nodes chosen are: {1220: 0, 1546: 0}
#
# The new prices of chosen are: {1220: 6, 1546: 6}
#
# The new min node chosen is: [1220, 1546]
# The successor node is: 1220
# The path is: [11016, 9726, 12801]
# The current K node is: 12801
# The succ node is: 1220
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 12801, 1220]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 12801]
# the price of available nodes is: {4097: 1000000, 1220: 1000000, 1546: 0, 4425: 1000000, 11757: 1000000}
# the weights of available edges is: {(12801, 4097): 6, (12801, 1220): 6, (12801, 1546): 6, (12801, 4425): 0, (12801, 11757): 0}
#
# The new nodes chosen are: {1546: 0}
#
# The new prices of chosen are: {1546: 6}
#
# The new min node chosen is: [1546]
# The successor node is: 1546
# The path is: [11016, 9726, 12801]
# The current K node is: 12801
# The succ node is: 1546
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 12801, 1546]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 12801]
# the price of available nodes is: {4097: 1000000, 1220: 1000000, 1546: 1000000, 4425: 1000000, 11757: 1000000}
# the weights of available edges is: {(12801, 4097): 6, (12801, 1220): 6, (12801, 1546): 6, (12801, 4425): 0, (12801, 11757): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 0, 5201: 0, 8043: 0, 389: 1000000, 8680: 0, 1483: 1000000, 3778: 0, 9409: 0, 2502: 1000000, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {774: 0, 13914: 0, 5201: 0, 8043: 0, 8680: 0, 3778: 0, 9409: 0, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
#
# The new prices of chosen are: {774: 6, 13914: 0, 5201: 0, 8043: 0, 8680: 0, 3778: 6, 9409: 0, 7421: 0, 3787: 6, 12700: 0, 1930: 6, 4107: 6}
#
# The new min node chosen is: [13914, 5201, 8043, 8680, 9409, 7421, 12700]
# The successor node is: 13914
# The path is: [11016, 9726]
# The current K node is: 9726
# The succ node is: 13914
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 13914]
# the price of available nodes is: {387: 1000000, 4093: 1000000, 1483: 1000000, 1493: 1000000, 10790: 0, 6206: 0}
# the weights of available edges is: {(13914, 10790): 0, (13914, 1493): 6, (13914, 6206): 0, (13914, 387): 6, (13914, 4093): 6, (13914, 1483): 6}
#
# The new nodes chosen are: {10790: 0, 6206: 0}
#
# The new prices of chosen are: {10790: 0, 6206: 0}
#
# The new min node chosen is: [10790, 6206]
# The successor node is: 10790
# The path is: [11016, 9726, 13914]
# The current K node is: 13914
# The succ node is: 10790
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9726, 13914, 10790]
# the price of available nodes is: {1493: 1000000, 4088: 1000000}
# the weights of available edges is: {(10790, 220): 6, (10790, 2007): 6, (10790, 4088): 6, (10790, 1493): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {387: 1000000, 4093: 1000000, 1483: 1000000, 1493: 1000000, 10790: 1000000, 6206: 0}
# the weights of available edges is: {(13914, 10790): 0, (13914, 1493): 6, (13914, 6206): 0, (13914, 387): 6, (13914, 4093): 6, (13914, 1483): 6}
#
# The new nodes chosen are: {6206: 0}
#
# The new prices of chosen are: {6206: 0}
#
# The new min node chosen is: [6206]
# The successor node is: 6206
# The path is: [11016, 9726, 13914]
# The current K node is: 13914
# The succ node is: 6206
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 13914, 6206]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 1119: 0}
# the weights of available edges is: {(6206, 2905): 6, (6206, 4097): 6, (6206, 387): 6, (6206, 1119): 6}
#
# The new nodes chosen are: {1119: 0}
#
# The new prices of chosen are: {1119: 6}
#
# The new min node chosen is: [1119]
# The successor node is: 1119
# The path is: [11016, 9726, 13914, 6206]
# The current K node is: 6206
# The succ node is: 1119
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9726, 13914, 6206, 1119]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 13914, 6206]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 1119: 1000000}
# the weights of available edges is: {(6206, 2905): 6, (6206, 4097): 6, (6206, 387): 6, (6206, 1119): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {387: 1000000, 4093: 1000000, 1483: 1000000, 1493: 1000000, 10790: 1000000, 6206: 1000000}
# the weights of available edges is: {(13914, 10790): 0, (13914, 1493): 6, (13914, 6206): 0, (13914, 387): 6, (13914, 4093): 6, (13914, 1483): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 0, 8043: 0, 389: 1000000, 8680: 0, 1483: 1000000, 3778: 0, 9409: 0, 2502: 1000000, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {774: 0, 5201: 0, 8043: 0, 8680: 0, 3778: 0, 9409: 0, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
#
# The new prices of chosen are: {774: 6, 5201: 0, 8043: 0, 8680: 0, 3778: 6, 9409: 0, 7421: 0, 3787: 6, 12700: 0, 1930: 6, 4107: 6}
#
# The new min node chosen is: [5201, 8043, 8680, 9409, 7421, 12700]
# The successor node is: 5201
# The path is: [11016, 9726]
# The current K node is: 9726
# The succ node is: 5201
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 5201]
# the price of available nodes is: {389: 1000000, 2502: 1000000, 4119: 1000000, 1499: 0, 2961: 0, 166: 1000000}
# the weights of available edges is: {(5201, 2502): 6, (5201, 4119): 6, (5201, 1499): 6, (5201, 2961): 6, (5201, 166): 6, (5201, 389): 6}
#
# The new nodes chosen are: {1499: 0, 2961: 0}
#
# The new prices of chosen are: {1499: 6, 2961: 6}
#
# The new min node chosen is: [1499, 2961]
# The successor node is: 1499
# The path is: [11016, 9726, 5201]
# The current K node is: 5201
# The succ node is: 1499
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9726, 5201, 1499]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 5201]
# the price of available nodes is: {389: 1000000, 2502: 1000000, 4119: 1000000, 1499: 1000000, 2961: 0, 166: 1000000}
# the weights of available edges is: {(5201, 2502): 6, (5201, 4119): 6, (5201, 1499): 6, (5201, 2961): 6, (5201, 166): 6, (5201, 389): 6}
#
# The new nodes chosen are: {2961: 0}
#
# The new prices of chosen are: {2961: 6}
#
# The new min node chosen is: [2961]
# The successor node is: 2961
# The path is: [11016, 9726, 5201]
# The current K node is: 5201
# The succ node is: 2961
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 5201, 2961]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 5201]
# the price of available nodes is: {389: 1000000, 2502: 1000000, 4119: 1000000, 1499: 1000000, 2961: 1000000, 166: 1000000}
# the weights of available edges is: {(5201, 2502): 6, (5201, 4119): 6, (5201, 1499): 6, (5201, 2961): 6, (5201, 166): 6, (5201, 389): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 0, 389: 1000000, 8680: 0, 1483: 1000000, 3778: 0, 9409: 0, 2502: 1000000, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {774: 0, 8043: 0, 8680: 0, 3778: 0, 9409: 0, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
#
# The new prices of chosen are: {774: 6, 8043: 0, 8680: 0, 3778: 6, 9409: 0, 7421: 0, 3787: 6, 12700: 0, 1930: 6, 4107: 6}
#
# The new min node chosen is: [8043, 8680, 9409, 7421, 12700]
# The successor node is: 8043
# The path is: [11016, 9726]
# The current K node is: 9726
# The succ node is: 8043
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 8043]
# the price of available nodes is: {387: 1000000, 4093: 1000000, 1483: 1000000, 1220: 1000000, 2094: 0, 1030: 1000000}
# the weights of available edges is: {(8043, 7490): 0, (8043, 2094): 6, (8043, 4093): 6, (8043, 9319): 0, (8043, 356): 6, (8043, 1483): 6, (8043, 1220): 6, (8043, 10639): 0, (8043, 7831): 0, (8043, 387): 6, (8043, 3757): 6, (8043, 10578): 0, (8043, 9652): 0, (8043, 1030): 6}
#
# The new nodes chosen are: {2094: 0}
#
# The new prices of chosen are: {2094: 6}
#
# The new min node chosen is: [2094]
# The successor node is: 2094
# The path is: [11016, 9726, 8043]
# The current K node is: 8043
# The succ node is: 2094
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9726, 8043, 2094]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11016, 9726, 8043]
# the price of available nodes is: {387: 1000000, 4093: 1000000, 1483: 1000000, 1220: 1000000, 2094: 1000000, 1030: 1000000}
# the weights of available edges is: {(8043, 7490): 0, (8043, 2094): 6, (8043, 4093): 6, (8043, 9319): 0, (8043, 356): 6, (8043, 1483): 6, (8043, 1220): 6, (8043, 10639): 0, (8043, 7831): 0, (8043, 387): 6, (8043, 3757): 6, (8043, 10578): 0, (8043, 9652): 0, (8043, 1030): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 0, 1483: 1000000, 3778: 0, 9409: 0, 2502: 1000000, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {774: 0, 8680: 0, 3778: 0, 9409: 0, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
#
# The new prices of chosen are: {774: 6, 8680: 0, 3778: 6, 9409: 0, 7421: 0, 3787: 6, 12700: 0, 1930: 6, 4107: 6}
#
# The new min node chosen is: [8680, 9409, 7421, 12700]
# The successor node is: 8680
# The path is: [11016, 9726]
# The current K node is: 9726
# The succ node is: 8680
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 8680]
# the price of available nodes is: {387: 1000000, 4097: 1000000, 2456: 1000000, 1302: 1000000}
# the weights of available edges is: {(8680, 387): 6, (8680, 4097): 6, (8680, 1302): 6, (8680, 2456): 6, (8680, 2406): 6, (8680, 5777): 0}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 0, 2502: 1000000, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {774: 0, 3778: 0, 9409: 0, 7421: 0, 3787: 0, 12700: 0, 1930: 0, 4107: 0}
#
# The new prices of chosen are: {774: 6, 3778: 6, 9409: 0, 7421: 0, 3787: 6, 12700: 0, 1930: 6, 4107: 6}
#
# The new min node chosen is: [9409, 7421, 12700]
# The successor node is: 9409
# The path is: [11016, 9726]
# The current K node is: 9726
# The succ node is: 9409
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 9409]
# the price of available nodes is: {2502: 1000000, 7421: 0, 14376: 0, 4126: 1000000}
# the weights of available edges is: {(9409, 7421): 0, (9409, 4126): 6, (9409, 14376): 0, (9409, 2502): 6, (9409, 13525): 0}
#
# The new nodes chosen are: {7421: 0, 14376: 0}
#
# The new prices of chosen are: {7421: 0, 14376: 0}
#
# The new min node chosen is: [7421, 14376]
# The successor node is: 7421
# The path is: [11016, 9726, 9409]
# The current K node is: 9409
# The succ node is: 7421
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11016, 9726, 9409, 7421]
# the price of available nodes is: {389: 1000000}
# the weights of available edges is: {(7421, 459): 6, (7421, 389): 6, (7421, 2560): 6, (7421, 4117): 6, (7421, 2668): 6, (7421, 13525): 0, (7421, 4): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
# the weights of available edges is: {(9409, 7421): 0, (9409, 4126): 6, (9409, 14376): 0, (9409, 2502): 6, (9409, 13525): 0}
#
# The new nodes chosen are: {14376: 0}
#
# The new prices of chosen are: {14376: 0}
#
# The new min node chosen is: [14376]
# The successor node is: 14376
# The path is: [11016, 9726, 9409]
# The current K node is: 9409
# The succ node is: 14376
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11016, 9726, 9409, 14376]
# Path to target is: [11016, 9726, 9409, 14376]
# The number of steps 76

# %% [markdown]
# ## Run 2

# %%
# query = " if author frederic bechet cited work on Equations for part-of-speech tagging"
source = int("6859")
target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# reuse price

# arc weights do not change as strength of relations is same

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {6172: 0}
# the weights of available edges is: {(6859, 6172): 3}
#
# The new nodes chosen are: {6172: 0}
#
# The new prices of chosen are: {6172: 3}
#
# The new min node chosen is: [6172]
# The successor node is: 6172
# The path is: [6859]
# The current K node is: 6859
# The succ node is: 6172
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [6859, 6172]
# the price of available nodes is: {2087: 1000000, 14376: 0, 1302: 1000000, 5686: 0, 4126: 1000000}
# the weights of available edges is: {(6172, 2087): 6, (6172, 14376): 0, (6172, 1302): 6, (6172, 5686): 0, (6172, 4126): 6}
#
# The new nodes chosen are: {2087: 1000000, 14376: 0, 1302: 1000000, 5686: 0, 4126: 1000000}
#
# The new prices of chosen are: {2087: 1000006, 14376: 0, 1302: 1000006, 5686: 0, 4126: 1000006}
#
# The new min node chosen is: [14376, 5686]
# The successor node is: 14376
# The path is: [6859, 6172]
# The current K node is: 6172
# The succ node is: 14376
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [6859, 6172, 14376]
# Path to target is: [6859, 6172, 14376]
# The number of steps 2

# %% [markdown]
# ## Run 3

# %%
# query = " if author 'steven c h hoi' cited work on Equations for part-of-speech tagging"
source = int("1689")
target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# reuse price
# arc weights do not change as strength of relations is same

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {9726: 1, 5874: 0, 5705: 0, 8804: 0, 2707: 0}
# the weights of available edges is: {(1689, 5874): 3, (1689, 5705): 3, (1689, 8804): 3, (1689, 9726): 3, (1689, 2707): 6}
#
# The new nodes chosen are: {9726: 1, 5874: 0, 5705: 0, 8804: 0, 2707: 0}
#
# The new prices of chosen are: {9726: 4, 5874: 3, 5705: 3, 8804: 3, 2707: 6}
#
# The new min node chosen is: [5874, 5705, 8804]
# The successor node is: 5874
# The path is: [1689]
# The current K node is: 1689
# The succ node is: 5874
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [1689, 5874]
# the price of available nodes is: {4093: 1000000, 4963: 0, 193: 0, 14689: 0, 2415: 0, 4421: 0, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 0, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 0, 193: 0, 14689: 0, 2415: 0, 4421: 0, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 0, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 0, 193: 6, 14689: 0, 2415: 6, 4421: 0, 4447: 0, 9005: 0, 2094: 1000006, 5886: 0, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 0, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [4963, 14689, 4421, 4447, 9005, 5886, 4326, 4450, 4445, 13247, 6131, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 4963
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 4963
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 4963]
# the price of available nodes is: {2270: 0, 1755: 0, 4119: 1000000}
# the weights of available edges is: {(4963, 4119): 6, (4963, 2617): 6, (4963, 2330): 6, (4963, 1755): 6, (4963, 2270): 6}
#
# The new nodes chosen are: {2270: 0, 1755: 0, 4119: 1000000}
#
# The new prices of chosen are: {2270: 6, 1755: 6, 4119: 1000006}
#
# The new min node chosen is: [2270, 1755]
# The successor node is: 2270
# The path is: [1689, 5874, 4963]
# The current K node is: 4963
# The succ node is: 2270
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 4963, 2270]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 4963]
# the price of available nodes is: {2270: 1000000, 1755: 0, 4119: 1000000}
# the weights of available edges is: {(4963, 4119): 6, (4963, 2617): 6, (4963, 2330): 6, (4963, 1755): 6, (4963, 2270): 6}
#
# The new nodes chosen are: {1755: 0, 4119: 1000000}
#
# The new prices of chosen are: {1755: 6, 4119: 1000006}
#
# The new min node chosen is: [1755]
# The successor node is: 1755
# The path is: [1689, 5874, 4963]
# The current K node is: 4963
# The succ node is: 1755
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4963, 1755]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 4963]
# the price of available nodes is: {2270: 1000000, 1755: 1000000, 4119: 1000000}
# the weights of available edges is: {(4963, 4119): 6, (4963, 2617): 6, (4963, 2330): 6, (4963, 1755): 6, (4963, 2270): 6}
#
# The new nodes chosen are: {4119: 1000000}
#
# The new prices of chosen are: {4119: 1000006}
#
# The new min node chosen is: [4119]
# The successor node is: 4119
# The path is: [1689, 5874, 4963]
# The current K node is: 4963
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4963
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 0, 14689: 0, 2415: 0, 4421: 0, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 0, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 193: 0, 14689: 0, 2415: 0, 4421: 0, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 0, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 193: 6, 14689: 0, 2415: 6, 4421: 0, 4447: 0, 9005: 0, 2094: 1000006, 5886: 0, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 0, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [14689, 4421, 4447, 9005, 5886, 4326, 4450, 4445, 13247, 6131, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 14689
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 14689
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689]
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 0, 4483: 0, 4337: 0, 8061: 0, 2500: 0, 14131: 0, 6588: 0, 4835: 0, 364: 0, 1839: 0, 5778: 0}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 0, 4483: 0, 4337: 0, 8061: 0, 2500: 0, 14131: 0, 6588: 0, 4835: 0, 364: 0, 1839: 0, 5778: 0}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 0, 4483: 0, 4337: 0, 8061: 0, 2500: 6, 14131: 0, 6588: 0, 4835: 0, 364: 6, 1839: 6, 5778: 0}
#
# The new min node chosen is: [6391, 4483, 4337, 8061, 14131, 6588, 4835, 5778]
# The successor node is: 6391
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 6391
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 14689, 6391]
# the price of available nodes is: {4093: 1000000, 1220: 1000000, 4337: 0, 2500: 0, 2574: 0}
# the weights of available edges is: {(6391, 4093): 6, (6391, 2500): 6, (6391, 4337): 0, (6391, 1478): 6, (6391, 2574): 6, (6391, 1220): 6, (6391, 2115): 6, (6391, 9805): 0}
#
# The new nodes chosen are: {4093: 1000000, 1220: 1000000, 4337: 0, 2500: 0, 2574: 0}
#
# The new prices of chosen are: {4093: 1000006, 1220: 1000006, 4337: 0, 2500: 6, 2574: 6}
#
# The new min node chosen is: [4337]
# The successor node is: 4337
# The path is: [1689, 5874, 14689, 6391]
# The current K node is: 6391
# The succ node is: 4337
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 14689, 6391, 4337]
# the price of available nodes is: {1483: 1000000, 1856: 1000000, 4119: 1000000}
# the weights of available edges is: {(4337, 1856): 6, (4337, 810): 6, (4337, 2129): 6, (4337, 1483): 6, (4337, 1478): 6, (4337, 235): 6, (4337, 73): 6, (4337, 4119): 6}
#
# The new nodes chosen are: {1483: 1000000, 1856: 1000000, 4119: 1000000}
#
# The new prices of chosen are: {1483: 1000006, 1856: 1000006, 4119: 1000006}
#
# The new min node chosen is: [1483, 1856, 4119]
# The successor node is: 1483
# The path is: [1689, 5874, 14689, 6391, 4337]
# The current K node is: 4337
# The succ node is: 1483
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4337
# the price of available nodes is: {4093: 1000000, 1220: 1000000, 4337: 1000007, 2500: 0, 2574: 0}
# the weights of available edges is: {(6391, 4093): 6, (6391, 2500): 6, (6391, 4337): 0, (6391, 1478): 6, (6391, 2574): 6, (6391, 1220): 6, (6391, 2115): 6, (6391, 9805): 0}
#
# The new nodes chosen are: {4093: 1000000, 1220: 1000000, 4337: 1000007, 2500: 0, 2574: 0}
#
# The new prices of chosen are: {4093: 1000006, 1220: 1000006, 4337: 1000007, 2500: 6, 2574: 6}
#
# The new min node chosen is: [2500, 2574]
# The successor node is: 2500
# The path is: [1689, 5874, 14689, 6391]
# The current K node is: 6391
# The succ node is: 2500
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 6391, 2500]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 6391]
# the price of available nodes is: {4093: 1000000, 1220: 1000000, 4337: 1000007, 2500: 1000000, 2574: 0}
# the weights of available edges is: {(6391, 4093): 6, (6391, 2500): 6, (6391, 4337): 0, (6391, 1478): 6, (6391, 2574): 6, (6391, 1220): 6, (6391, 2115): 6, (6391, 9805): 0}
#
# The new nodes chosen are: {4093: 1000000, 1220: 1000000, 4337: 1000007, 2574: 0}
#
# The new prices of chosen are: {4093: 1000006, 1220: 1000006, 4337: 1000007, 2574: 6}
#
# The new min node chosen is: [2574]
# The successor node is: 2574
# The path is: [1689, 5874, 14689, 6391]
# The current K node is: 6391
# The succ node is: 2574
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 6391, 2574]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 6391]
# the price of available nodes is: {4093: 1000000, 1220: 1000000, 4337: 1000007, 2500: 1000000, 2574: 1000000}
# the weights of available edges is: {(6391, 4093): 6, (6391, 2500): 6, (6391, 4337): 0, (6391, 1478): 6, (6391, 2574): 6, (6391, 1220): 6, (6391, 2115): 6, (6391, 9805): 0}
#
# The new nodes chosen are: {4093: 1000000, 1220: 1000000, 4337: 1000007}
#
# The new prices of chosen are: {4093: 1000006, 1220: 1000006, 4337: 1000007}
#
# The new min node chosen is: [4093, 1220]
# The successor node is: 4093
# The path is: [1689, 5874, 14689, 6391]
# The current K node is: 6391
# The succ node is: 4093
#
#  Uphill- contract and update the price
#
# Removing the high price node: 6391
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 0, 4337: 1000007, 8061: 0, 2500: 1000000, 14131: 0, 6588: 0, 4835: 0, 364: 0, 1839: 0, 5778: 0}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 0, 4337: 1000007, 8061: 0, 14131: 0, 6588: 0, 4835: 0, 364: 0, 1839: 0, 5778: 0}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 0, 4337: 1000007, 8061: 0, 14131: 0, 6588: 0, 4835: 0, 364: 6, 1839: 6, 5778: 0}
#
# The new min node chosen is: [4483, 8061, 14131, 6588, 4835, 5778]
# The successor node is: 4483
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 4483
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 4483]
# the price of available nodes is: {2099: 1000000, 4119: 1000000, 364: 0, 2561: 0}
# the weights of available edges is: {(4483, 4119): 6, (4483, 2099): 6, (4483, 459): 6, (4483, 364): 6, (4483, 2561): 6, (4483, 810): 6}
#
# The new nodes chosen are: {2099: 1000000, 4119: 1000000, 364: 0, 2561: 0}
#
# The new prices of chosen are: {2099: 1000006, 4119: 1000006, 364: 6, 2561: 6}
#
# The new min node chosen is: [364, 2561]
# The successor node is: 364
# The path is: [1689, 5874, 14689, 4483]
# The current K node is: 4483
# The succ node is: 364
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 14689, 4483, 364]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 4483]
# the price of available nodes is: {2099: 1000000, 4119: 1000000, 364: 1000000, 2561: 0}
# the weights of available edges is: {(4483, 4119): 6, (4483, 2099): 6, (4483, 459): 6, (4483, 364): 6, (4483, 2561): 6, (4483, 810): 6}
#
# The new nodes chosen are: {2099: 1000000, 4119: 1000000, 2561: 0}
#
# The new prices of chosen are: {2099: 1000006, 4119: 1000006, 2561: 6}
#
# The new min node chosen is: [2561]
# The successor node is: 2561
# The path is: [1689, 5874, 14689, 4483]
# The current K node is: 4483
# The succ node is: 2561
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 4483, 2561]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 4483]
# the price of available nodes is: {2099: 1000000, 4119: 1000000, 364: 1000000, 2561: 1000000}
# the weights of available edges is: {(4483, 4119): 6, (4483, 2099): 6, (4483, 459): 6, (4483, 364): 6, (4483, 2561): 6, (4483, 810): 6}
#
# The new nodes chosen are: {2099: 1000000, 4119: 1000000}
#
# The new prices of chosen are: {2099: 1000006, 4119: 1000006}
#
# The new min node chosen is: [2099, 4119]
# The successor node is: 2099
# The path is: [1689, 5874, 14689, 4483]
# The current K node is: 4483
# The succ node is: 2099
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4483
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 0, 2500: 1000000, 14131: 0, 6588: 0, 4835: 0, 364: 1000000, 1839: 0, 5778: 0}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 0, 14131: 0, 6588: 0, 4835: 0, 1839: 0, 5778: 0}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 0, 14131: 0, 6588: 0, 4835: 0, 1839: 6, 5778: 0}
#
# The new min node chosen is: [8061, 14131, 6588, 4835, 5778]
# The successor node is: 8061
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 8061
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 8061]
# the price of available nodes is: {387: 1000000, 193: 0, 4119: 1000000, 770: 1000000, 1190: 0}
# the weights of available edges is: {(8061, 1893): 6, (8061, 1187): 6, (8061, 810): 6, (8061, 770): 6, (8061, 387): 6, (8061, 397): 6, (8061, 4119): 6, (8061, 1190): 6, (8061, 2282): 6, (8061, 1618): 6, (8061, 1793): 6, (8061, 1977): 6, (8061, 193): 6, (8061, 2733): 6, (8061, 3146): 6}
#
# The new nodes chosen are: {387: 1000000, 193: 0, 4119: 1000000, 770: 1000000, 1190: 0}
#
# The new prices of chosen are: {387: 1000006, 193: 6, 4119: 1000006, 770: 1000006, 1190: 6}
#
# The new min node chosen is: [193, 1190]
# The successor node is: 193
# The path is: [1689, 5874, 14689, 8061]
# The current K node is: 8061
# The succ node is: 193
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 14689, 8061, 193]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 8061]
# the price of available nodes is: {387: 1000000, 193: 1000000, 4119: 1000000, 770: 1000000, 1190: 0}
# the weights of available edges is: {(8061, 1893): 6, (8061, 1187): 6, (8061, 810): 6, (8061, 770): 6, (8061, 387): 6, (8061, 397): 6, (8061, 4119): 6, (8061, 1190): 6, (8061, 2282): 6, (8061, 1618): 6, (8061, 1793): 6, (8061, 1977): 6, (8061, 193): 6, (8061, 2733): 6, (8061, 3146): 6}
#
# The new nodes chosen are: {387: 1000000, 4119: 1000000, 770: 1000000, 1190: 0}
#
# The new prices of chosen are: {387: 1000006, 4119: 1000006, 770: 1000006, 1190: 6}
#
# The new min node chosen is: [1190]
# The successor node is: 1190
# The path is: [1689, 5874, 14689, 8061]
# The current K node is: 8061
# The succ node is: 1190
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 8061, 1190]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 8061]
# the price of available nodes is: {387: 1000000, 193: 1000000, 4119: 1000000, 770: 1000000, 1190: 1000000}
# the weights of available edges is: {(8061, 1893): 6, (8061, 1187): 6, (8061, 810): 6, (8061, 770): 6, (8061, 387): 6, (8061, 397): 6, (8061, 4119): 6, (8061, 1190): 6, (8061, 2282): 6, (8061, 1618): 6, (8061, 1793): 6, (8061, 1977): 6, (8061, 193): 6, (8061, 2733): 6, (8061, 3146): 6}
#
# The new nodes chosen are: {387: 1000000, 4119: 1000000, 770: 1000000}
#
# The new prices of chosen are: {387: 1000006, 4119: 1000006, 770: 1000006}
#
# The new min node chosen is: [387, 4119, 770]
# The successor node is: 387
# The path is: [1689, 5874, 14689, 8061]
# The current K node is: 8061
# The succ node is: 387
#
#  Uphill- contract and update the price
#
# Removing the high price node: 8061
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 2500: 1000000, 14131: 0, 6588: 0, 4835: 0, 364: 1000000, 1839: 0, 5778: 0}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 0, 6588: 0, 4835: 0, 1839: 0, 5778: 0}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 0, 6588: 0, 4835: 0, 1839: 6, 5778: 0}
#
# The new min node chosen is: [14131, 6588, 4835, 5778]
# The successor node is: 14131
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 14131
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 14131]
# the price of available nodes is: {2322: 1000000, 4088: 1000000}
# the weights of available edges is: {(14131, 4088): 6, (14131, 2967): 6, (14131, 2322): 6, (14131, 810): 6}
#
# The new nodes chosen are: {2322: 1000000, 4088: 1000000}
#
# The new prices of chosen are: {2322: 1000006, 4088: 1000006}
#
# The new min node chosen is: [2322, 4088]
# The successor node is: 2322
# The path is: [1689, 5874, 14689, 14131]
# The current K node is: 14131
# The succ node is: 2322
#
#  Uphill- contract and update the price
#
# Removing the high price node: 14131
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 2500: 1000000, 14131: 1000007, 6588: 0, 4835: 0, 364: 1000000, 1839: 0, 5778: 0}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 0, 4835: 0, 1839: 0, 5778: 0}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 0, 4835: 0, 1839: 6, 5778: 0}
#
# The new min node chosen is: [6588, 4835, 5778]
# The successor node is: 6588
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 6588
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 6588]
# the price of available nodes is: {4093: 1000000, 1930: 0, 7364: 0}
# the weights of available edges is: {(6588, 4093): 6, (6588, 7364): 0, (6588, 1930): 6, (6588, 810): 6}
#
# The new nodes chosen are: {4093: 1000000, 1930: 0, 7364: 0}
#
# The new prices of chosen are: {4093: 1000006, 1930: 6, 7364: 0}
#
# The new min node chosen is: [7364]
# The successor node is: 7364
# The path is: [1689, 5874, 14689, 6588]
# The current K node is: 6588
# The succ node is: 7364
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 14689, 6588, 7364]
# the price of available nodes is: {4097: 1000000, 4963: 1000007, 1856: 1000000, 6131: 0, 4483: 1000007, 4835: 0, 203: 1000000}
# the weights of available edges is: {(7364, 7598): 0, (7364, 1856): 6, (7364, 6131): 0, (7364, 2202): 6, (7364, 6928): 0, (7364, 7255): 0, (7364, 4963): 0, (7364, 4483): 0, (7364, 4769): 0, (7364, 203): 6, (7364, 4097): 6, (7364, 4835): 0, (7364, 7257): 0}
#
# The new nodes chosen are: {4097: 1000000, 4963: 1000007, 1856: 1000000, 6131: 0, 4483: 1000007, 4835: 0, 203: 1000000}
#
# The new prices of chosen are: {4097: 1000006, 4963: 1000007, 1856: 1000006, 6131: 0, 4483: 1000007, 4835: 0, 203: 1000006}
#
# The new min node chosen is: [6131, 4835]
# The successor node is: 6131
# The path is: [1689, 5874, 14689, 6588, 7364]
# The current K node is: 7364
# The succ node is: 6131
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 14689, 6588, 7364, 6131]
# the price of available nodes is: {4097: 1000000, 1755: 1000000, 203: 1000000}
# the weights of available edges is: {(6131, 203): 6, (6131, 810): 6, (6131, 790): 6, (6131, 1755): 6, (6131, 4097): 6}
#
# The new nodes chosen are: {4097: 1000000, 203: 1000000}
#
# The new prices of chosen are: {4097: 1000006, 203: 1000006}
#
# The new min node chosen is: [4097, 203]
# The successor node is: 4097
# The path is: [1689, 5874, 14689, 6588, 7364, 6131]
# The current K node is: 6131
# The succ node is: 4097
#
#  Uphill- contract and update the price
#
# Removing the high price node: 6131
# the price of available nodes is: {4097: 1000000, 4963: 1000007, 1856: 1000000, 6131: 1000007, 4483: 1000007, 4835: 0, 203: 1000000}
# the weights of available edges is: {(7364, 7598): 0, (7364, 1856): 6, (7364, 6131): 0, (7364, 2202): 6, (7364, 6928): 0, (7364, 7255): 0, (7364, 4963): 0, (7364, 4483): 0, (7364, 4769): 0, (7364, 203): 6, (7364, 4097): 6, (7364, 4835): 0, (7364, 7257): 0}
#
# The new nodes chosen are: {4097: 1000000, 4963: 1000007, 1856: 1000000, 6131: 1000007, 4483: 1000007, 4835: 0, 203: 1000000}
#
# The new prices of chosen are: {4097: 1000006, 4963: 1000007, 1856: 1000006, 6131: 1000007, 4483: 1000007, 4835: 0, 203: 1000006}
#
# The new min node chosen is: [4835]
# The successor node is: 4835
# The path is: [1689, 5874, 14689, 6588, 7364]
# The current K node is: 7364
# The succ node is: 4835
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 6588, 7364, 4835]
# the price of available nodes is: {387: 1000000, 2270: 1000000, 4119: 1000000}
# the weights of available edges is: {(4835, 99): 6, (4835, 2270): 6, (4835, 3749): 6, (4835, 4119): 6, (4835, 387): 6}
#
# The new nodes chosen are: {387: 1000000, 4119: 1000000}
#
# The new prices of chosen are: {387: 1000006, 4119: 1000006}
#
# The new min node chosen is: [387, 4119]
# The successor node is: 387
# The path is: [1689, 5874, 14689, 6588, 7364, 4835]
# The current K node is: 4835
# The succ node is: 387
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4835
# the price of available nodes is: {4097: 1000000, 4963: 1000007, 1856: 1000000, 6131: 1000007, 4483: 1000007, 4835: 1000007, 203: 1000000}
# the weights of available edges is: {(7364, 7598): 0, (7364, 1856): 6, (7364, 6131): 0, (7364, 2202): 6, (7364, 6928): 0, (7364, 7255): 0, (7364, 4963): 0, (7364, 4483): 0, (7364, 4769): 0, (7364, 203): 6, (7364, 4097): 6, (7364, 4835): 0, (7364, 7257): 0}
#
# The new nodes chosen are: {4097: 1000000, 4963: 1000007, 1856: 1000000, 6131: 1000007, 4483: 1000007, 4835: 1000007, 203: 1000000}
#
# The new prices of chosen are: {4097: 1000006, 4963: 1000007, 1856: 1000006, 6131: 1000007, 4483: 1000007, 4835: 1000007, 203: 1000006}
#
# The new min node chosen is: [4097, 1856, 203]
# The successor node is: 4097
# The path is: [1689, 5874, 14689, 6588, 7364]
# The current K node is: 7364
# The succ node is: 4097
#
#  Uphill- contract and update the price
#
# Removing the high price node: 7364
# the price of available nodes is: {4093: 1000000, 1930: 0, 7364: 1000007}
# the weights of available edges is: {(6588, 4093): 6, (6588, 7364): 0, (6588, 1930): 6, (6588, 810): 6}
#
# The new nodes chosen are: {4093: 1000000, 1930: 0, 7364: 1000007}
#
# The new prices of chosen are: {4093: 1000006, 1930: 6, 7364: 1000007}
#
# The new min node chosen is: [1930]
# The successor node is: 1930
# The path is: [1689, 5874, 14689, 6588]
# The current K node is: 6588
# The succ node is: 1930
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 6588, 1930]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689, 6588]
# the price of available nodes is: {4093: 1000000, 1930: 1000000, 7364: 1000007}
# the weights of available edges is: {(6588, 4093): 6, (6588, 7364): 0, (6588, 1930): 6, (6588, 810): 6}
#
# The new nodes chosen are: {4093: 1000000, 7364: 1000007}
#
# The new prices of chosen are: {4093: 1000006, 7364: 1000007}
#
# The new min node chosen is: [4093]
# The successor node is: 4093
# The path is: [1689, 5874, 14689, 6588]
# The current K node is: 6588
# The succ node is: 4093
#
#  Uphill- contract and update the price
#
# Removing the high price node: 6588
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 2500: 1000000, 14131: 1000007, 6588: 1000007, 4835: 1000007, 364: 1000000, 1839: 0, 5778: 0}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 1000007, 4835: 1000007, 1839: 0, 5778: 0}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 1000007, 4835: 1000007, 1839: 6, 5778: 0}
#
# The new min node chosen is: [5778]
# The successor node is: 5778
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 5778
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 5778]
# the price of available nodes is: {4093: 1000000, 1030: 1000000}
# the weights of available edges is: {(5778, 6928): 0, (5778, 1030): 6, (5778, 4093): 6, (5778, 2779): 6}
#
# The new nodes chosen are: {4093: 1000000, 1030: 1000000}
#
# The new prices of chosen are: {4093: 1000006, 1030: 1000006}
#
# The new min node chosen is: [4093, 1030]
# The successor node is: 4093
# The path is: [1689, 5874, 14689, 5778]
# The current K node is: 5778
# The succ node is: 4093
#
#  Uphill- contract and update the price
#
# Removing the high price node: 5778
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 2500: 1000000, 14131: 1000007, 6588: 1000007, 4835: 1000007, 364: 1000000, 1839: 0, 5778: 1000007}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 1000007, 4835: 1000007, 1839: 0, 5778: 1000007}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 1000007, 4835: 1000007, 1839: 6, 5778: 1000007}
#
# The new min node chosen is: [1839]
# The successor node is: 1839
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 1839
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 14689, 1839]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 14689]
# the price of available nodes is: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 2500: 1000000, 14131: 1000007, 6588: 1000007, 4835: 1000007, 364: 1000000, 1839: 1000000, 5778: 1000007}
# the weights of available edges is: {(14689, 6391): 0, (14689, 4483): 0, (14689, 4337): 0, (14689, 8061): 0, (14689, 2500): 6, (14689, 14131): 0, (14689, 6588): 0, (14689, 4835): 0, (14689, 364): 6, (14689, 1856): 6, (14689, 4093): 6, (14689, 1839): 6, (14689, 5778): 0}
#
# The new nodes chosen are: {4093: 1000000, 1856: 1000000, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 1000007, 4835: 1000007, 5778: 1000007}
#
# The new prices of chosen are: {4093: 1000006, 1856: 1000006, 6391: 1000007, 4483: 1000007, 4337: 1000007, 8061: 1000007, 14131: 1000007, 6588: 1000007, 4835: 1000007, 5778: 1000007}
#
# The new min node chosen is: [4093, 1856]
# The successor node is: 4093
# The path is: [1689, 5874, 14689]
# The current K node is: 14689
# The succ node is: 4093
#
#  Uphill- contract and update the price
#
# Removing the high price node: 14689
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 0, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 0, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 0, 4447: 0, 9005: 0, 2094: 1000006, 5886: 0, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [4421, 4447, 9005, 5886, 4326, 4450, 4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 4421
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 4421
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4421]
# the price of available nodes is: {2270: 1000000, 4119: 1000000, 655: 0, 2714: 0, 1548: 0}
# the weights of available edges is: {(4421, 655): 6, (4421, 2270): 6, (4421, 2714): 6, (4421, 1548): 6, (4421, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000, 655: 0, 2714: 0, 1548: 0}
#
# The new prices of chosen are: {4119: 1000006, 655: 6, 2714: 6, 1548: 6}
#
# The new min node chosen is: [655, 2714, 1548]
# The successor node is: 655
# The path is: [1689, 5874, 4421]
# The current K node is: 4421
# The succ node is: 655
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 4421, 655]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 4421]
# the price of available nodes is: {2270: 1000000, 4119: 1000000, 655: 1000000, 2714: 0, 1548: 0}
# the weights of available edges is: {(4421, 655): 6, (4421, 2270): 6, (4421, 2714): 6, (4421, 1548): 6, (4421, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000, 2714: 0, 1548: 0}
#
# The new prices of chosen are: {4119: 1000006, 2714: 6, 1548: 6}
#
# The new min node chosen is: [2714, 1548]
# The successor node is: 2714
# The path is: [1689, 5874, 4421]
# The current K node is: 4421
# The succ node is: 2714
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4421, 2714]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 4421]
# the price of available nodes is: {2270: 1000000, 4119: 1000000, 655: 1000000, 2714: 1000000, 1548: 0}
# the weights of available edges is: {(4421, 655): 6, (4421, 2270): 6, (4421, 2714): 6, (4421, 1548): 6, (4421, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000, 1548: 0}
#
# The new prices of chosen are: {4119: 1000006, 1548: 6}
#
# The new min node chosen is: [1548]
# The successor node is: 1548
# The path is: [1689, 5874, 4421]
# The current K node is: 4421
# The succ node is: 1548
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4421, 1548]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 4421]
# the price of available nodes is: {2270: 1000000, 4119: 1000000, 655: 1000000, 2714: 1000000, 1548: 1000000}
# the weights of available edges is: {(4421, 655): 6, (4421, 2270): 6, (4421, 2714): 6, (4421, 1548): 6, (4421, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000}
#
# The new prices of chosen are: {4119: 1000006}
#
# The new min node chosen is: [4119]
# The successor node is: 4119
# The path is: [1689, 5874, 4421]
# The current K node is: 4421
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4421
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 0, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 1000007, 4447: 0, 9005: 0, 2094: 1000006, 5886: 0, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [4447, 9005, 5886, 4326, 4450, 4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 4447
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 4447
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4447]
# the price of available nodes is: {4119: 1000000, 203: 1000000}
# the weights of available edges is: {(4447, 4119): 6, (4447, 203): 6}
#
# The new nodes chosen are: {4119: 1000000, 203: 1000000}
#
# The new prices of chosen are: {4119: 1000006, 203: 1000006}
#
# The new min node chosen is: [4119, 203]
# The successor node is: 4119
# The path is: [1689, 5874, 4447]
# The current K node is: 4447
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4447
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 0, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 1000007, 4447: 1000007, 9005: 0, 2094: 1000006, 5886: 0, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [9005, 5886, 4326, 4450, 4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 9005
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 9005
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 9005]
# the price of available nodes is: {4119: 1000000, 203: 1000000}
# the weights of available edges is: {(9005, 203): 6, (9005, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000, 203: 1000000}
#
# The new prices of chosen are: {4119: 1000006, 203: 1000006}
#
# The new min node chosen is: [4119, 203]
# The successor node is: 4119
# The path is: [1689, 5874, 9005]
# The current K node is: 9005
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 9005
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 0, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000006, 5886: 0, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [5886, 4326, 4450, 4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 5886
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 5886
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 5886]
# the price of available nodes is: {4097: 1000000, 1755: 1000000}
# the weights of available edges is: {(5886, 1755): 6, (5886, 3091): 6, (5886, 4097): 6}
#
# The new nodes chosen are: {4097: 1000000}
#
# The new prices of chosen are: {4097: 1000006}
#
# The new min node chosen is: [4097]
# The successor node is: 4097
# The path is: [1689, 5874, 5886]
# The current K node is: 5886
# The succ node is: 4097
#
#  Uphill- contract and update the price
#
# Removing the high price node: 5886
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 0, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000006, 5886: 1000007, 4326: 0, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [4326, 4450, 4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 4326
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 4326
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4326]
# the price of available nodes is: {4119: 1000000, 203: 1000000}
# the weights of available edges is: {(4326, 203): 6, (4326, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000, 203: 1000000}
#
# The new prices of chosen are: {4119: 1000006, 203: 1000006}
#
# The new min node chosen is: [4119, 203]
# The successor node is: 4119
# The path is: [1689, 5874, 4326]
# The current K node is: 4326
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4326
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 1000007, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 1000007, 4450: 0, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000006, 5886: 1000007, 4326: 1000007, 4450: 0, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [4450, 4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 4450
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 4450
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4450]
# the price of available nodes is: {1856: 1000000, 4119: 1000000, 203: 1000000}
# the weights of available edges is: {(4450, 4119): 6, (4450, 203): 6, (4450, 1856): 6}
#
# The new nodes chosen are: {1856: 1000000, 4119: 1000000, 203: 1000000}
#
# The new prices of chosen are: {1856: 1000006, 4119: 1000006, 203: 1000006}
#
# The new min node chosen is: [1856, 4119, 203]
# The successor node is: 1856
# The path is: [1689, 5874, 4450]
# The current K node is: 4450
# The succ node is: 1856
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4450
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 1000007, 4450: 1000007, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 1000007, 4450: 1000007, 472: 0, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# The new prices of chosen are: {4093: 1000006, 4963: 1000007, 14689: 1000007, 2415: 6, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000006, 5886: 1000007, 4326: 1000007, 4450: 1000007, 472: 6, 4445: 0, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000006, 7833: 0, 10968: 0, 7707: 0}
#
# The new min node chosen is: [4445, 13247, 1667, 12066, 7833, 10968, 7707]
# The successor node is: 4445
# The path is: [1689, 5874]
# The current K node is: 5874
# The succ node is: 4445
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5874, 4445]
# the price of available nodes is: {4119: 1000000, 2769: 0}
# the weights of available edges is: {(4445, 2769): 6, (4445, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000, 2769: 0}
#
# The new prices of chosen are: {4119: 1000006, 2769: 6}
#
# The new min node chosen is: [2769]
# The successor node is: 2769
# The path is: [1689, 5874, 4445]
# The current K node is: 4445
# The succ node is: 2769
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5874, 4445, 2769]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5874, 4445]
# the price of available nodes is: {4119: 1000000, 2769: 1000000}
# the weights of available edges is: {(4445, 2769): 6, (4445, 4119): 6}
#
# The new nodes chosen are: {4119: 1000000}
#
# The new prices of chosen are: {4119: 1000006}
#
# The new min node chosen is: [4119]
# The successor node is: 4119
# The path is: [1689, 5874, 4445]
# The current K node is: 4445
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4445
# the price of available nodes is: {4093: 1000000, 4963: 1000007, 193: 1000000, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 1000007, 4450: 1000007, 472: 0, 4445: 1000007, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
# the weights of available edges is: {(5874, 14689): 0, (5874, 2415): 6, (5874, 4421): 0, (5874, 4447): 0, (5874, 193): 6, (5874, 9005): 0, (5874, 2094): 6, (5874, 5886): 0, (5874, 4326): 0, (5874, 4450): 0, (5874, 472): 6, (5874, 4445): 0, (5874, 13247): 0, (5874, 6131): 0, (5874, 1667): 0, (5874, 12066): 0, (5874, 2322): 6, (5874, 7833): 0, (5874, 4093): 6, (5874, 10968): 0, (5874, 4963): 0, (5874, 7707): 0}
#
# The new nodes chosen are: {4093: 1000000, 4963: 1000007, 14689: 1000007, 2415: 0, 4421: 1000007, 4447: 1000007, 9005: 1000007, 2094: 1000000, 5886: 1000007, 4326: 1000007, 4450: 1000007, 472: 0, 4445: 1000007, 13247: 0, 6131: 1000007, 1667: 0, 12066: 0, 2322: 1000000, 7833: 0, 10968: 0, 7707: 0}
#
# ...
# The path is: [1689, 5705, 13752]
# The current K node is: 13752
# The succ node is: 1856
#
#  Uphill- contract and update the price
#
# Removing the high price node: 13752
# the price of available nodes is: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 0, 11517: 1000007, 14353: 0, 12028: 0, 4358: 0}
# the weights of available edges is: {(5705, 1493): 6, (5705, 11615): 0, (5705, 9635): 0, (5705, 4119): 6, (5705, 9944): 0, (5705, 12240): 0, (5705, 10060): 0, (5705, 13752): 0, (5705, 5295): 0, (5705, 11517): 0, (5705, 14353): 0, (5705, 12028): 0, (5705, 4358): 0}
#
# The new nodes chosen are: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 0, 11517: 1000007, 14353: 0, 12028: 0, 4358: 0}
#
# The new prices of chosen are: {9944: 1000007, 4119: 1000006, 1493: 1000006, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 0, 11517: 1000007, 14353: 0, 12028: 0, 4358: 0}
#
# The new min node chosen is: [5295, 14353, 12028, 4358]
# The successor node is: 5295
# The path is: [1689, 5705]
# The current K node is: 5705
# The succ node is: 5295
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5705, 5295]
# the price of available nodes is: {1856: 1000000, 4119: 1000000, 2415: 1000000, 203: 1000000, 1433: 1000000, 1896: 0}
# the weights of available edges is: {(5295, 1896): 6, (5295, 1433): 6, (5295, 2415): 6, (5295, 4119): 6, (5295, 2827): 6, (5295, 203): 6, (5295, 1856): 6}
#
# The new nodes chosen are: {1856: 1000000, 4119: 1000000, 203: 1000000, 1896: 0}
#
# The new prices of chosen are: {1856: 1000006, 4119: 1000006, 203: 1000006, 1896: 6}
#
# The new min node chosen is: [1896]
# The successor node is: 1896
# The path is: [1689, 5705, 5295]
# The current K node is: 5295
# The succ node is: 1896
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5705, 5295, 1896]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 5705, 5295]
# the price of available nodes is: {1856: 1000000, 4119: 1000000, 2415: 1000000, 203: 1000000, 1433: 1000000, 1896: 1000000}
# the weights of available edges is: {(5295, 1896): 6, (5295, 1433): 6, (5295, 2415): 6, (5295, 4119): 6, (5295, 2827): 6, (5295, 203): 6, (5295, 1856): 6}
#
# The new nodes chosen are: {1856: 1000000, 4119: 1000000, 203: 1000000}
#
# The new prices of chosen are: {1856: 1000006, 4119: 1000006, 203: 1000006}
#
# The new min node chosen is: [1856, 4119, 203]
# The successor node is: 1856
# The path is: [1689, 5705, 5295]
# The current K node is: 5295
# The succ node is: 1856
#
#  Uphill- contract and update the price
#
# Removing the high price node: 5295
# the price of available nodes is: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 0, 12028: 0, 4358: 0}
# the weights of available edges is: {(5705, 1493): 6, (5705, 11615): 0, (5705, 9635): 0, (5705, 4119): 6, (5705, 9944): 0, (5705, 12240): 0, (5705, 10060): 0, (5705, 13752): 0, (5705, 5295): 0, (5705, 11517): 0, (5705, 14353): 0, (5705, 12028): 0, (5705, 4358): 0}
#
# The new nodes chosen are: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 0, 12028: 0, 4358: 0}
#
# The new prices of chosen are: {9944: 1000007, 4119: 1000006, 1493: 1000006, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 0, 12028: 0, 4358: 0}
#
# The new min node chosen is: [14353, 12028, 4358]
# The successor node is: 14353
# The path is: [1689, 5705]
# The current K node is: 5705
# The succ node is: 14353
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5705, 14353]
# the price of available nodes is: {9635: 1000007, 12028: 0, 4088: 1000000}
# the weights of available edges is: {(14353, 14318): 0, (14353, 4088): 6, (14353, 915): 6, (14353, 672): 6, (14353, 13280): 0, (14353, 9635): 0, (14353, 12028): 0}
#
# The new nodes chosen are: {9635: 1000007, 12028: 0, 4088: 1000000}
#
# The new prices of chosen are: {9635: 1000007, 12028: 0, 4088: 1000006}
#
# The new min node chosen is: [12028]
# The successor node is: 12028
# The path is: [1689, 5705, 14353]
# The current K node is: 14353
# The succ node is: 12028
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 5705, 14353, 12028]
# the price of available nodes is: {2087: 1000000, 2270: 1000000, 4119: 1000000, 9635: 1000007, 5594: 1000000}
# the weights of available edges is: {(12028, 2270): 6, (12028, 915): 6, (12028, 5594): 0, (12028, 4119): 6, (12028, 14318): 0, (12028, 9635): 0, (12028, 2087): 6}
#
# The new nodes chosen are: {2087: 1000000, 4119: 1000000, 9635: 1000007, 5594: 1000000}
#
# The new prices of chosen are: {2087: 1000006, 4119: 1000006, 9635: 1000007, 5594: 1000000}
#
# The new min node chosen is: [5594]
# The successor node is: 5594
# The path is: [1689, 5705, 14353, 12028]
# The current K node is: 12028
# The succ node is: 5594
#
#  Uphill- contract and update the price
#
# Removing the high price node: 12028
# the price of available nodes is: {9635: 1000007, 12028: 1000001, 4088: 1000000}
# the weights of available edges is: {(14353, 14318): 0, (14353, 4088): 6, (14353, 915): 6, (14353, 672): 6, (14353, 13280): 0, (14353, 9635): 0, (14353, 12028): 0}
#
# The new nodes chosen are: {9635: 1000007, 12028: 1000001, 4088: 1000000}
#
# The new prices of chosen are: {9635: 1000007, 12028: 1000001, 4088: 1000006}
#
# The new min node chosen is: [12028]
# The successor node is: 12028
# The path is: [1689, 5705, 14353]
# The current K node is: 14353
# The succ node is: 12028
#
#  Uphill- contract and update the price
#
# Removing the high price node: 14353
# the price of available nodes is: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 1000002, 12028: 1000001, 4358: 0}
# the weights of available edges is: {(5705, 1493): 6, (5705, 11615): 0, (5705, 9635): 0, (5705, 4119): 6, (5705, 9944): 0, (5705, 12240): 0, (5705, 10060): 0, (5705, 13752): 0, (5705, 5295): 0, (5705, 11517): 0, (5705, 14353): 0, (5705, 12028): 0, (5705, 4358): 0}
#
# The new nodes chosen are: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 1000002, 12028: 1000001, 4358: 0}
#
# The new prices of chosen are: {9944: 1000007, 4119: 1000006, 1493: 1000006, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 1000002, 12028: 1000001, 4358: 0}
#
# The new min node chosen is: [4358]
# The successor node is: 4358
# The path is: [1689, 5705]
# The current K node is: 5705
# The succ node is: 4358
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 5705, 4358]
# the price of available nodes is: {387: 1000000, 9005: 1000007, 9635: 1000007, 12028: 1000001}
# the weights of available edges is: {(4358, 2733): 6, (4358, 9356): 0, (4358, 4953): 0, (4358, 9635): 0, (4358, 387): 6, (4358, 12028): 0, (4358, 915): 6, (4358, 4117): 6, (4358, 13280): 0, (4358, 9005): 0, (4358, 1820): 6}
#
# The new nodes chosen are: {387: 1000000, 9005: 1000007, 9635: 1000007, 12028: 1000001}
#
# The new prices of chosen are: {387: 1000006, 9005: 1000007, 9635: 1000007, 12028: 1000001}
#
# The new min node chosen is: [12028]
# The successor node is: 12028
# The path is: [1689, 5705, 4358]
# The current K node is: 4358
# The succ node is: 12028
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4358
# the price of available nodes is: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 1000002, 12028: 1000001, 4358: 1000002}
# the weights of available edges is: {(5705, 1493): 6, (5705, 11615): 0, (5705, 9635): 0, (5705, 4119): 6, (5705, 9944): 0, (5705, 12240): 0, (5705, 10060): 0, (5705, 13752): 0, (5705, 5295): 0, (5705, 11517): 0, (5705, 14353): 0, (5705, 12028): 0, (5705, 4358): 0}
#
# The new nodes chosen are: {9944: 1000007, 4119: 1000000, 1493: 1000000, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 1000002, 12028: 1000001, 4358: 1000002}
#
# The new prices of chosen are: {9944: 1000007, 4119: 1000006, 1493: 1000006, 11615: 1000007, 9635: 1000007, 12240: 1000007, 10060: 1000007, 13752: 1000007, 5295: 1000007, 11517: 1000007, 14353: 1000002, 12028: 1000001, 4358: 1000002}
#
# The new min node chosen is: [12028]
# The successor node is: 12028
# The path is: [1689, 5705]
# The current K node is: 5705
# The succ node is: 12028
#
#  Uphill- contract and update the price
#
# Removing the high price node: 5705
# the price of available nodes is: {9726: 1, 5874: 1000007, 5705: 1000002, 8804: 0, 2707: 0}
# the weights of available edges is: {(1689, 5874): 3, (1689, 5705): 3, (1689, 8804): 3, (1689, 9726): 3, (1689, 2707): 6}
#
# The new nodes chosen are: {9726: 1, 5874: 1000007, 5705: 1000002, 8804: 0, 2707: 0}
#
# The new prices of chosen are: {9726: 4, 5874: 1000010, 5705: 1000005, 8804: 3, 2707: 6}
#
# The new min node chosen is: [8804]
# The successor node is: 8804
# The path is: [1689]
# The current K node is: 1689
# The succ node is: 8804
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [1689, 8804]
# the price of available nodes is: {4119: 1000000, 4447: 1000007, 4326: 1000007, 4450: 1000007, 472: 1000000, 4445: 1000007, 7707: 1000000, 807: 0}
# the weights of available edges is: {(8804, 4450): 0, (8804, 472): 6, (8804, 807): 6, (8804, 4326): 0, (8804, 4447): 0, (8804, 4445): 0, (8804, 4119): 6, (8804, 7707): 0}
#
# The new nodes chosen are: {4119: 1000000, 4447: 1000007, 4326: 1000007, 4450: 1000007, 4445: 1000007, 807: 0}
#
# The new prices of chosen are: {4119: 1000006, 4447: 1000007, 4326: 1000007, 4450: 1000007, 4445: 1000007, 807: 6}
#
# The new min node chosen is: [807]
# The successor node is: 807
# The path is: [1689, 8804]
# The current K node is: 8804
# The succ node is: 807
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [1689, 8804, 807]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [1689, 8804]
# the price of available nodes is: {4119: 1000000, 4447: 1000007, 4326: 1000007, 4450: 1000007, 472: 1000000, 4445: 1000007, 7707: 1000000, 807: 1000000}
# the weights of available edges is: {(8804, 4450): 0, (8804, 472): 6, (8804, 807): 6, (8804, 4326): 0, (8804, 4447): 0, (8804, 4445): 0, (8804, 4119): 6, (8804, 7707): 0}
#
# The new nodes chosen are: {4119: 1000000, 4447: 1000007, 4326: 1000007, 4450: 1000007, 4445: 1000007}
#
# The new prices of chosen are: {4119: 1000006, 4447: 1000007, 4326: 1000007, 4450: 1000007, 4445: 1000007}
#
# The new min node chosen is: [4119]
# The successor node is: 4119
# The path is: [1689, 8804]
# The current K node is: 8804
# The succ node is: 4119
#
#  Uphill- contract and update the price
#
# Removing the high price node: 8804
# the price of available nodes is: {9726: 1, 5874: 1000007, 5705: 1000002, 8804: 1000007, 2707: 0}
# the weights of available edges is: {(1689, 5874): 3, (1689, 5705): 3, (1689, 8804): 3, (1689, 9726): 3, (1689, 2707): 6}
#
# The new nodes chosen are: {9726: 1, 5874: 1000007, 5705: 1000002, 8804: 1000007, 2707: 0}
#
# The new prices of chosen are: {9726: 4, 5874: 1000010, 5705: 1000005, 8804: 1000010, 2707: 6}
#
# The new min node chosen is: [9726]
# The successor node is: 9726
# The path is: [1689]
# The current K node is: 1689
# The succ node is: 9726
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [1689, 9726]
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 1, 2502: 1000000, 7421: 1000000, 3787: 0, 12700: 0, 1930: 1000000, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 1, 2502: 1000000, 7421: 1000000, 3787: 0, 12700: 0, 4107: 0}
#
# The new prices of chosen are: {12801: 1000000, 774: 6, 717: 1000006, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000006, 8680: 1000000, 1483: 1000006, 3778: 6, 9409: 1, 2502: 1000006, 7421: 1000000, 3787: 6, 12700: 0, 4107: 6}
#
# The new min node chosen is: [12700]
# The successor node is: 12700
# The path is: [1689, 9726]
# The current K node is: 9726
# The succ node is: 12700
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 9726, 12700]
# the price of available nodes is: {389: 1000000, 2502: 1000000, 4119: 1000000, 166: 1000000, 2561: 1000000}
# the weights of available edges is: {(12700, 389): 6, (12700, 4119): 6, (12700, 2234): 6, (12700, 2379): 6, (12700, 166): 6, (12700, 2502): 6, (12700, 2561): 6, (12700, 2333): 6}
#
# The new nodes chosen are: {389: 1000000, 2502: 1000000, 4119: 1000000, 166: 1000000}
#
# The new prices of chosen are: {389: 1000006, 2502: 1000006, 4119: 1000006, 166: 1000006}
#
# The new min node chosen is: [389, 2502, 4119, 166]
# The successor node is: 389
# The path is: [1689, 9726, 12700]
# The current K node is: 12700
# The succ node is: 389
#
#  Uphill- contract and update the price
#
# Removing the high price node: 12700
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 1, 2502: 1000000, 7421: 1000000, 3787: 0, 12700: 1000007, 1930: 1000000, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 1, 2502: 1000000, 7421: 1000000, 3787: 0, 12700: 1000007, 4107: 0}
#
# The new prices of chosen are: {12801: 1000000, 774: 6, 717: 1000006, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000006, 8680: 1000000, 1483: 1000006, 3778: 6, 9409: 1, 2502: 1000006, 7421: 1000000, 3787: 6, 12700: 1000007, 4107: 6}
#
# The new min node chosen is: [9409]
# The successor node is: 9409
# The path is: [1689, 9726]
# The current K node is: 9726
# The succ node is: 9409
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 9726, 9409]
# the price of available nodes is: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
# the weights of available edges is: {(9409, 7421): 0, (9409, 4126): 6, (9409, 14376): 0, (9409, 2502): 6, (9409, 13525): 0}
#
# The new nodes chosen are: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
#
# The new prices of chosen are: {2502: 1000006, 7421: 1000000, 14376: 0, 4126: 1000006}
#
# The new min node chosen is: [14376]
# The successor node is: 14376
# The path is: [1689, 9726, 9409]
# The current K node is: 9409
# The succ node is: 14376
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [1689, 9726, 9409, 14376]
# Path to target is: [1689, 9726, 9409, 14376]
# The number of steps 102

# %% [markdown]
# ## Run 4

# %%
# query = "if paper 'Clustering query refinements by user intent' cited work on Equations for part-of-speech tagging"
source = int("13629")

target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# initialize random price
#nodePrice = intial_price(0)

# %%
# strong = 'paper_cite_paper'
# medium= 'author_write_paper'
# edgeWeight= arc_weights_relation(strong, medium)

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {9726: 2, 4093: 1000000, 1483: 1000000, 1119: 1000000, 467: 0}
# the weights of available edges is: {(13629, 4093): 6, (13629, 1119): 6, (13629, 467): 6, (13629, 9726): 0, (13629, 1483): 6}
#
# The new nodes chosen are: {9726: 2, 4093: 1000000, 1483: 1000000, 1119: 1000000, 467: 0}
#
# The new prices of chosen are: {9726: 2, 4093: 1000006, 1483: 1000006, 1119: 1000006, 467: 6}
#
# The new min node chosen is: [9726]
# The successor node is: 9726
# The path is: [13629]
# The current K node is: 13629
# The succ node is: 9726
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [13629, 9726]
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 2, 2502: 1000000, 7421: 1000000, 3787: 0, 12700: 1000007, 1930: 1000000, 4107: 0}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 2, 2502: 1000000, 7421: 1000000, 3787: 0, 12700: 1000007, 1930: 1000000, 4107: 0}
#
# The new prices of chosen are: {12801: 1000000, 774: 6, 717: 1000006, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000006, 8680: 1000000, 1483: 1000006, 3778: 6, 9409: 2, 2502: 1000006, 7421: 1000000, 3787: 6, 12700: 1000007, 1930: 1000006, 4107: 6}
#
# The new min node chosen is: [9409]
# The successor node is: 9409
# The path is: [13629, 9726]
# The current K node is: 9726
# The succ node is: 9409
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [13629, 9726, 9409]
# the price of available nodes is: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
# the weights of available edges is: {(9409, 7421): 0, (9409, 4126): 6, (9409, 14376): 0, (9409, 2502): 6, (9409, 13525): 0}
#
# The new nodes chosen are: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
#
# The new prices of chosen are: {2502: 1000006, 7421: 1000000, 14376: 0, 4126: 1000006}
#
# The new min node chosen is: [14376]
# The successor node is: 14376
# The path is: [13629, 9726, 9409]
# The current K node is: 9409
# The succ node is: 14376
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [13629, 9726, 9409, 14376]
# Path to target is: [13629, 9726, 9409, 14376]
# The number of steps 3

# %% [markdown]
# ## Run 5

# %%
# if Mike perkowitz is author of Equations for part-of-speech tagging

source = int("6685")

target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# initialize random price
#nodePrice = intial_price(0)

# %%
# relation changes so change the arc weights
strong = 'author_write_paper'
medium= 'paper_cite_paper'
edgeWeight= arc_weights_relation(strong, medium)

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {14376: 0, 3043: 0, 4408: 1000000, 4411: 0, 4744: 0, 448: 0}
# the weights of available edges is: {(6685, 14376): 0, (6685, 3043): 6, (6685, 4408): 0, (6685, 4411): 0, (6685, 4744): 0, (6685, 448): 6}
#
# The new nodes chosen are: {14376: 0, 3043: 0, 4408: 1000000, 4411: 0, 4744: 0, 448: 0}
#
# The new prices of chosen are: {14376: 0, 3043: 6, 4408: 1000000, 4411: 0, 4744: 0, 448: 6}
#
# The new min node chosen is: [14376, 4411, 4744]
# The successor node is: 14376
# The path is: [6685]
# The current K node is: 6685
# The succ node is: 14376
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [6685, 14376]
# Path to target is: [6685, 14376]
# The number of steps 1

# %% [markdown]
# ## Run 6

# %%
# if author 'franck genet' cited work on Equations for part-of-speech tagging
source = int("7774")

target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# initialize random price
#nodePrice = intial_price(0)

# %%
# relation changes so change the arc weights
strong = 'paper_cite_paper'
medium= 'author_write_paper'
edgeWeight= arc_weights_relation(strong, medium)

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {6172: 1}
# the weights of available edges is: {(7774, 6172): 3}
#
# The new nodes chosen are: {6172: 1}
#
# The new prices of chosen are: {6172: 4}
#
# The new min node chosen is: [6172]
# The successor node is: 6172
# The path is: [7774]
# The current K node is: 7774
# The succ node is: 6172
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [7774, 6172]
# the price of available nodes is: {2087: 1000000, 14376: 0, 1302: 1000000, 5686: 0, 4126: 1000000}
# the weights of available edges is: {(6172, 2087): 6, (6172, 14376): 0, (6172, 1302): 6, (6172, 5686): 0, (6172, 4126): 6}
#
# The new nodes chosen are: {2087: 1000000, 14376: 0, 1302: 1000000, 5686: 0, 4126: 1000000}
#
# The new prices of chosen are: {2087: 1000006, 14376: 0, 1302: 1000006, 5686: 0, 4126: 1000006}
#
# The new min node chosen is: [14376, 5686]
# The successor node is: 14376
# The path is: [7774, 6172]
# The current K node is: 6172
# The succ node is: 14376
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [7774, 6172, 14376]
# Path to target is: [7774, 6172, 14376]
# The number of steps 2

# %% [markdown]
# ## Run 7

# %%
# query= if author 'yoram singer' cited work on Equations for part-of-speech tagging

# provide the source and destination
source = int("16078")

target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# initialize random price
#nodePrice = intial_price(0)
# edge weights do not change as relations are same

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 0, 10322: 0, 4958: 0, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 0, 10322: 0, 4958: 0, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 3, 10322: 3, 4958: 3, 8073: 3, 11057: 3, 6203: 3, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 3}
#
# The new min node chosen is: [12257, 10322, 4958, 8073, 11057, 6203, 5562, 11174, 8697, 6098]
# The successor node is: 12257
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 12257
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 12257]
# the price of available nodes is: {2343: 1000000, 4119: 1000000, 203: 1000000, 2440: 0, 7952: 0, 5594: 1000000}
# the weights of available edges is: {(12257, 2343): 6, (12257, 203): 6, (12257, 4119): 6, (12257, 2440): 6, (12257, 7952): 0, (12257, 5594): 0}
#
# The new nodes chosen are: {2343: 1000000, 4119: 1000000, 203: 1000000, 2440: 0, 7952: 0, 5594: 1000000}
#
# The new prices of chosen are: {2343: 1000006, 4119: 1000006, 203: 1000006, 2440: 6, 7952: 0, 5594: 1000000}
#
# The new min node chosen is: [7952]
# The successor node is: 7952
# The path is: [16078, 12257]
# The current K node is: 12257
# The succ node is: 7952
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 12257, 7952]
# the price of available nodes is: {1856: 1000000, 4119: 1000000, 2322: 1000000, 203: 1000000, 5594: 1000000, 2975: 1000000}
# the weights of available edges is: {(7952, 4119): 6, (7952, 2975): 6, (7952, 1856): 6, (7952, 5594): 0, (7952, 2683): 6, (7952, 898): 6, (7952, 2322): 6, (7952, 203): 6, (7952, 3131): 6, (7952, 9249): 0, (7952, 9972): 0, (7952, 1380): 6}
#
# The new nodes chosen are: {1856: 1000000, 4119: 1000000, 2322: 1000000, 203: 1000000, 5594: 1000000, 2975: 1000000}
#
# The new prices of chosen are: {1856: 1000006, 4119: 1000006, 2322: 1000006, 203: 1000006, 5594: 1000000, 2975: 1000006}
#
# The new min node chosen is: [5594]
# The successor node is: 5594
# The path is: [16078, 12257, 7952]
# The current K node is: 7952
# The succ node is: 5594
#
#  Uphill- contract and update the price
#
# Removing the high price node: 7952
# the price of available nodes is: {2343: 1000000, 4119: 1000000, 203: 1000000, 2440: 0, 7952: 1000001, 5594: 1000000}
# the weights of available edges is: {(12257, 2343): 6, (12257, 203): 6, (12257, 4119): 6, (12257, 2440): 6, (12257, 7952): 0, (12257, 5594): 0}
#
# The new nodes chosen are: {2343: 1000000, 4119: 1000000, 203: 1000000, 2440: 0, 7952: 1000001, 5594: 1000000}
#
# The new prices of chosen are: {2343: 1000006, 4119: 1000006, 203: 1000006, 2440: 6, 7952: 1000001, 5594: 1000000}
#
# The new min node chosen is: [2440]
# The successor node is: 2440
# The path is: [16078, 12257]
# The current K node is: 12257
# The succ node is: 2440
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 12257, 2440]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 12257]
# the price of available nodes is: {2343: 1000000, 4119: 1000000, 203: 1000000, 2440: 1000000, 7952: 1000001, 5594: 1000000}
# the weights of available edges is: {(12257, 2343): 6, (12257, 203): 6, (12257, 4119): 6, (12257, 2440): 6, (12257, 7952): 0, (12257, 5594): 0}
#
# The new nodes chosen are: {2343: 1000000, 4119: 1000000, 203: 1000000, 7952: 1000001, 5594: 1000000}
#
# The new prices of chosen are: {2343: 1000006, 4119: 1000006, 203: 1000006, 7952: 1000001, 5594: 1000000}
#
# The new min node chosen is: [5594]
# The successor node is: 5594
# The path is: [16078, 12257]
# The current K node is: 12257
# The succ node is: 5594
#
#  Uphill- contract and update the price
#
# Removing the high price node: 12257
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 0, 4958: 0, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 0, 4958: 0, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 3, 4958: 3, 8073: 3, 11057: 3, 6203: 3, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 3}
#
# The new min node chosen is: [10322, 4958, 8073, 11057, 6203, 5562, 11174, 8697, 6098]
# The successor node is: 10322
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 10322
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 10322]
# the price of available nodes is: {1493: 1000000, 2975: 1000000, 4088: 1000000}
# the weights of available edges is: {(10322, 2975): 6, (10322, 4088): 6, (10322, 1493): 6}
#
# The new nodes chosen are: {1493: 1000000, 2975: 1000000, 4088: 1000000}
#
# The new prices of chosen are: {1493: 1000006, 2975: 1000006, 4088: 1000006}
#
# The new min node chosen is: [1493, 2975, 4088]
# The successor node is: 1493
# The path is: [16078, 10322]
# The current K node is: 10322
# The succ node is: 1493
#
#  Uphill- contract and update the price
#
# Removing the high price node: 10322
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 0, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 0, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 3, 8073: 3, 11057: 3, 6203: 3, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 3}
#
# The new min node chosen is: [4958, 8073, 11057, 6203, 5562, 11174, 8697, 6098]
# The successor node is: 4958
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 4958
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 4958]
# the price of available nodes is: {2561: 1000000, 539: 0, 770: 1000000, 4134: 0, 2769: 1000000, 1433: 1000000, 4536: 0}
# the weights of available edges is: {(4958, 2561): 6, (4958, 539): 6, (4958, 770): 6, (4958, 4134): 6, (4958, 2769): 6, (4958, 1433): 6, (4958, 4536): 0}
#
# The new nodes chosen are: {2561: 1000000, 539: 0, 770: 1000000, 4134: 0, 2769: 1000000, 1433: 1000000, 4536: 0}
#
# The new prices of chosen are: {2561: 1000006, 539: 6, 770: 1000006, 4134: 6, 2769: 1000006, 1433: 1000006, 4536: 0}
#
# The new min node chosen is: [4536]
# The successor node is: 4536
# The path is: [16078, 4958]
# The current K node is: 4958
# The succ node is: 4536
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 4958, 4536]
# the price of available nodes is: {4132: 1000000}
# the weights of available edges is: {(4536, 4678): 0, (4536, 2364): 6, (4536, 1893): 6, (4536, 243): 6, (4536, 4132): 6, (4536, 790): 6, (4536, 4638): 0}
#
# The new nodes chosen are: {4132: 1000000}
#
# The new prices of chosen are: {4132: 1000006}
#
# The new min node chosen is: [4132]
# The successor node is: 4132
# The path is: [16078, 4958, 4536]
# The current K node is: 4536
# The succ node is: 4132
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4536
# the price of available nodes is: {2561: 1000000, 539: 0, 770: 1000000, 4134: 0, 2769: 1000000, 1433: 1000000, 4536: 1000007}
# the weights of available edges is: {(4958, 2561): 6, (4958, 539): 6, (4958, 770): 6, (4958, 4134): 6, (4958, 2769): 6, (4958, 1433): 6, (4958, 4536): 0}
#
# The new nodes chosen are: {2561: 1000000, 539: 0, 770: 1000000, 4134: 0, 2769: 1000000, 1433: 1000000, 4536: 1000007}
#
# The new prices of chosen are: {2561: 1000006, 539: 6, 770: 1000006, 4134: 6, 2769: 1000006, 1433: 1000006, 4536: 1000007}
#
# The new min node chosen is: [539, 4134]
# The successor node is: 539
# The path is: [16078, 4958]
# The current K node is: 4958
# The succ node is: 539
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 4958, 539]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 4958]
# the price of available nodes is: {2561: 1000000, 539: 1000000, 770: 1000000, 4134: 0, 2769: 1000000, 1433: 1000000, 4536: 1000007}
# the weights of available edges is: {(4958, 2561): 6, (4958, 539): 6, (4958, 770): 6, (4958, 4134): 6, (4958, 2769): 6, (4958, 1433): 6, (4958, 4536): 0}
#
# The new nodes chosen are: {2561: 1000000, 770: 1000000, 4134: 0, 2769: 1000000, 1433: 1000000, 4536: 1000007}
#
# The new prices of chosen are: {2561: 1000006, 770: 1000006, 4134: 6, 2769: 1000006, 1433: 1000006, 4536: 1000007}
#
# The new min node chosen is: [4134]
# The successor node is: 4134
# The path is: [16078, 4958]
# The current K node is: 4958
# The succ node is: 4134
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 4958, 4134]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 4958]
# the price of available nodes is: {2561: 1000000, 539: 1000000, 770: 1000000, 4134: 1000000, 2769: 1000000, 1433: 1000000, 4536: 1000007}
# the weights of available edges is: {(4958, 2561): 6, (4958, 539): 6, (4958, 770): 6, (4958, 4134): 6, (4958, 2769): 6, (4958, 1433): 6, (4958, 4536): 0}
#
# The new nodes chosen are: {2561: 1000000, 770: 1000000, 2769: 1000000, 1433: 1000000, 4536: 1000007}
#
# The new prices of chosen are: {2561: 1000006, 770: 1000006, 2769: 1000006, 1433: 1000006, 4536: 1000007}
#
# The new min node chosen is: [2561, 770, 2769, 1433]
# The successor node is: 2561
# The path is: [16078, 4958]
# The current K node is: 4958
# The succ node is: 2561
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4958
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 0, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 3, 11057: 3, 6203: 3, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 3}
#
# The new min node chosen is: [8073, 11057, 6203, 5562, 11174, 8697, 6098]
# The successor node is: 8073
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 8073
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 8073]
# the price of available nodes is: {730: 1000000, 4119: 1000000, 2404: 0, 8926: 0}
# the weights of available edges is: {(8073, 2404): 6, (8073, 8926): 0, (8073, 4119): 6, (8073, 730): 6}
#
# The new nodes chosen are: {730: 1000000, 4119: 1000000, 2404: 0, 8926: 0}
#
# The new prices of chosen are: {730: 1000006, 4119: 1000006, 2404: 6, 8926: 0}
#
# The new min node chosen is: [8926]
# The successor node is: 8926
# The path is: [16078, 8073]
# The current K node is: 8073
# The succ node is: 8926
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 8073, 8926]
# the price of available nodes is: {807: 1000000, 4088: 1000000}
# the weights of available edges is: {(8926, 1929): 6, (8926, 807): 6, (8926, 4088): 6}
#
# The new nodes chosen are: {807: 1000000, 4088: 1000000}
#
# The new prices of chosen are: {807: 1000006, 4088: 1000006}
#
# The new min node chosen is: [807, 4088]
# The successor node is: 807
# The path is: [16078, 8073, 8926]
# The current K node is: 8926
# The succ node is: 807
#
#  Uphill- contract and update the price
#
# Removing the high price node: 8926
# the price of available nodes is: {730: 1000000, 4119: 1000000, 2404: 0, 8926: 1000007}
# the weights of available edges is: {(8073, 2404): 6, (8073, 8926): 0, (8073, 4119): 6, (8073, 730): 6}
#
# The new nodes chosen are: {730: 1000000, 4119: 1000000, 2404: 0, 8926: 1000007}
#
# The new prices of chosen are: {730: 1000006, 4119: 1000006, 2404: 6, 8926: 1000007}
#
# The new min node chosen is: [2404]
# The successor node is: 2404
# The path is: [16078, 8073]
# The current K node is: 8073
# The succ node is: 2404
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 8073, 2404]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 8073]
# the price of available nodes is: {730: 1000000, 4119: 1000000, 2404: 1000000, 8926: 1000007}
# the weights of available edges is: {(8073, 2404): 6, (8073, 8926): 0, (8073, 4119): 6, (8073, 730): 6}
#
# The new nodes chosen are: {730: 1000000, 4119: 1000000, 8926: 1000007}
#
# The new prices of chosen are: {730: 1000006, 4119: 1000006, 8926: 1000007}
#
# The new min node chosen is: [730, 4119]
# The successor node is: 730
# The path is: [16078, 8073]
# The current K node is: 8073
# The succ node is: 730
#
#  Uphill- contract and update the price
#
# Removing the high price node: 8073
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 0, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 0}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 1000010, 11057: 3, 6203: 3, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 3}
#
# The new min node chosen is: [11057, 6203, 5562, 11174, 8697, 6098]
# The successor node is: 11057
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 11057
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 11057]
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 0, 10037: 0, 10621: 0, 4109: 0, 13813: 0, 584: 0, 2574: 1000000, 508: 0, 994: 0, 27: 0, 2116: 0, 129: 0, 8495: 0}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 0, 10037: 0, 10621: 0, 4109: 0, 13813: 0, 584: 0, 2574: 1000000, 508: 0, 994: 0, 27: 0, 2116: 0, 129: 0, 8495: 0}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 1286: 6, 6098: 0, 10037: 0, 10621: 0, 4109: 6, 13813: 0, 584: 6, 2574: 1000006, 508: 6, 994: 6, 27: 6, 2116: 6, 129: 6, 8495: 0}
#
# The new min node chosen is: [6098, 10037, 10621, 13813, 8495]
# The successor node is: 6098
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 6098
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 11057, 6098]
# the price of available nodes is: {2087: 1000000, 9944: 1000007, 4119: 1000000, 2975: 1000000, 4707: 0}
# the weights of available edges is: {(6098, 4707): 0, (6098, 2087): 6, (6098, 9944): 0, (6098, 1036): 6, (6098, 4119): 6, (6098, 4492): 0, (6098, 2975): 6, (6098, 1478): 6}
#
# The new nodes chosen are: {2087: 1000000, 9944: 1000007, 4119: 1000000, 2975: 1000000, 4707: 0}
#
# The new prices of chosen are: {2087: 1000006, 9944: 1000007, 4119: 1000006, 2975: 1000006, 4707: 0}
#
# The new min node chosen is: [4707]
# The successor node is: 4707
# The path is: [16078, 11057, 6098]
# The current K node is: 6098
# The succ node is: 4707
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 11057, 6098, 4707]
# the price of available nodes is: {5594: 1000000}
# the weights of available edges is: {(4707, 10547): 0, (4707, 3076): 6, (4707, 7868): 0, (4707, 1348): 0, (4707, 4935): 0, (4707, 5594): 0, (4707, 4117): 6, (4707, 8076): 0, (4707, 4383): 0, (4707, 6268): 0}
#
# The new nodes chosen are: {5594: 1000000}
#
# The new prices of chosen are: {5594: 1000000}
#
# The new min node chosen is: [5594]
# The successor node is: 5594
# The path is: [16078, 11057, 6098, 4707]
# The current K node is: 4707
# The succ node is: 5594
#
#  Uphill- contract and update the price
#
# Removing the high price node: 4707
# the price of available nodes is: {2087: 1000000, 9944: 1000007, 4119: 1000000, 2975: 1000000, 4707: 1000001}
# the weights of available edges is: {(6098, 4707): 0, (6098, 2087): 6, (6098, 9944): 0, (6098, 1036): 6, (6098, 4119): 6, (6098, 4492): 0, (6098, 2975): 6, (6098, 1478): 6}
#
# The new nodes chosen are: {2087: 1000000, 9944: 1000007, 4119: 1000000, 2975: 1000000, 4707: 1000001}
#
# The new prices of chosen are: {2087: 1000006, 9944: 1000007, 4119: 1000006, 2975: 1000006, 4707: 1000001}
#
# The new min node chosen is: [4707]
# The successor node is: 4707
# The path is: [16078, 11057, 6098]
# The current K node is: 6098
# The succ node is: 4707
#
#  Uphill- contract and update the price
#
# Removing the high price node: 6098
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 0, 10621: 0, 4109: 0, 13813: 0, 584: 0, 2574: 1000000, 508: 0, 994: 0, 27: 0, 2116: 0, 129: 0, 8495: 0}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 0, 10621: 0, 4109: 0, 13813: 0, 584: 0, 2574: 1000000, 508: 0, 994: 0, 27: 0, 2116: 0, 129: 0, 8495: 0}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 1286: 6, 6098: 1000002, 10037: 0, 10621: 0, 4109: 6, 13813: 0, 584: 6, 2574: 1000006, 508: 6, 994: 6, 27: 6, 2116: 6, 129: 6, 8495: 0}
#
# The new min node chosen is: [10037, 10621, 13813, 8495]
# The successor node is: 10037
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 10037
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 10037]
# the price of available nodes is: {9944: 1000007, 11517: 1000007, 203: 1000000, 4088: 1000000}
# the weights of available edges is: {(10037, 203): 6, (10037, 9944): 0, (10037, 11517): 0, (10037, 4088): 6, (10037, 14438): 0}
#
# The new nodes chosen are: {9944: 1000007, 11517: 1000007, 203: 1000000, 4088: 1000000}
#
# The new prices of chosen are: {9944: 1000007, 11517: 1000007, 203: 1000006, 4088: 1000006}
#
# The new min node chosen is: [203, 4088]
# The successor node is: 203
# The path is: [16078, 11057, 10037]
# The current K node is: 10037
# The succ node is: 203
#
#  Uphill- contract and update the price
#
# Removing the high price node: 10037
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 1000007, 10621: 0, 4109: 0, 13813: 0, 584: 0, 2574: 1000000, 508: 0, 994: 0, 27: 0, 2116: 0, 129: 0, 8495: 0}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 1000007, 10621: 0, 4109: 0, 13813: 0, 584: 0, 2574: 1000000, 508: 0, 994: 0, 27: 0, 2116: 0, 129: 0, 8495: 0}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 1286: 6, 6098: 1000002, 10037: 1000007, 10621: 0, 4109: 6, 13813: 0, 584: 6, 2574: 1000006, 508: 6, 994: 6, 27: 6, 2116: 6, 129: 6, 8495: 0}
#
# The new min node chosen is: [10621, 13813, 8495]
# The successor node is: 10621
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 10621
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 10621]
# the price of available nodes is: {1755: 1000000, 4109: 0, 508: 0, 994: 0, 129: 0, 656: 0}
# the weights of available edges is: {(10621, 466): 6, (10621, 656): 6, (10621, 1755): 6, (10621, 4109): 6, (10621, 2551): 6, (10621, 1524): 6, (10621, 129): 6, (10621, 508): 6, (10621, 3739): 6, (10621, 3770): 6, (10621, 994): 6, (10621, 824): 6}
#
# The new nodes chosen are: {1755: 1000000, 4109: 0, 508: 0, 994: 0, 129: 0, 656: 0}
#
# The new prices of chosen are: {1755: 1000006, 4109: 6, 508: 6, 994: 6, 129: 6, 656: 6}
#
# The new min node chosen is: [4109, 508, 994, 129, 656]
# The successor node is: 4109
# The path is: [16078, 11057, 10621]
# The current K node is: 10621
# The succ node is: 4109
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 11057, 10621, 4109]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057, 10621]
# the price of available nodes is: {1755: 1000000, 4109: 1000000, 508: 0, 994: 0, 129: 0, 656: 0}
# the weights of available edges is: {(10621, 466): 6, (10621, 656): 6, (10621, 1755): 6, (10621, 4109): 6, (10621, 2551): 6, (10621, 1524): 6, (10621, 129): 6, (10621, 508): 6, (10621, 3739): 6, (10621, 3770): 6, (10621, 994): 6, (10621, 824): 6}
#
# The new nodes chosen are: {1755: 1000000, 508: 0, 994: 0, 129: 0, 656: 0}
#
# The new prices of chosen are: {1755: 1000006, 508: 6, 994: 6, 129: 6, 656: 6}
#
# The new min node chosen is: [508, 994, 129, 656]
# The successor node is: 508
# The path is: [16078, 11057, 10621]
# The current K node is: 10621
# The succ node is: 508
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 10621, 508]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057, 10621]
# the price of available nodes is: {1755: 1000000, 4109: 1000000, 508: 1000000, 994: 0, 129: 0, 656: 0}
# the weights of available edges is: {(10621, 466): 6, (10621, 656): 6, (10621, 1755): 6, (10621, 4109): 6, (10621, 2551): 6, (10621, 1524): 6, (10621, 129): 6, (10621, 508): 6, (10621, 3739): 6, (10621, 3770): 6, (10621, 994): 6, (10621, 824): 6}
#
# The new nodes chosen are: {1755: 1000000, 994: 0, 129: 0, 656: 0}
#
# The new prices of chosen are: {1755: 1000006, 994: 6, 129: 6, 656: 6}
#
# The new min node chosen is: [994, 129, 656]
# The successor node is: 994
# The path is: [16078, 11057, 10621]
# The current K node is: 10621
# The succ node is: 994
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 10621, 994]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057, 10621]
# the price of available nodes is: {1755: 1000000, 4109: 1000000, 508: 1000000, 994: 1000000, 129: 0, 656: 0}
# the weights of available edges is: {(10621, 466): 6, (10621, 656): 6, (10621, 1755): 6, (10621, 4109): 6, (10621, 2551): 6, (10621, 1524): 6, (10621, 129): 6, (10621, 508): 6, (10621, 3739): 6, (10621, 3770): 6, (10621, 994): 6, (10621, 824): 6}
#
# The new nodes chosen are: {1755: 1000000, 129: 0, 656: 0}
#
# The new prices of chosen are: {1755: 1000006, 129: 6, 656: 6}
#
# The new min node chosen is: [129, 656]
# The successor node is: 129
# The path is: [16078, 11057, 10621]
# The current K node is: 10621
# The succ node is: 129
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 10621, 129]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057, 10621]
# the price of available nodes is: {1755: 1000000, 4109: 1000000, 508: 1000000, 994: 1000000, 129: 1000000, 656: 0}
# the weights of available edges is: {(10621, 466): 6, (10621, 656): 6, (10621, 1755): 6, (10621, 4109): 6, (10621, 2551): 6, (10621, 1524): 6, (10621, 129): 6, (10621, 508): 6, (10621, 3739): 6, (10621, 3770): 6, (10621, 994): 6, (10621, 824): 6}
#
# The new nodes chosen are: {1755: 1000000, 656: 0}
#
# The new prices of chosen are: {1755: 1000006, 656: 6}
#
# The new min node chosen is: [656]
# The successor node is: 656
# The path is: [16078, 11057, 10621]
# The current K node is: 10621
# The succ node is: 656
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 10621, 656]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057, 10621]
# the price of available nodes is: {1755: 1000000, 4109: 1000000, 508: 1000000, 994: 1000000, 129: 1000000, 656: 1000000}
# the weights of available edges is: {(10621, 466): 6, (10621, 656): 6, (10621, 1755): 6, (10621, 4109): 6, (10621, 2551): 6, (10621, 1524): 6, (10621, 129): 6, (10621, 508): 6, (10621, 3739): 6, (10621, 3770): 6, (10621, 994): 6, (10621, 824): 6}
#
# The new nodes chosen are: {1755: 1000000}
#
# The new prices of chosen are: {1755: 1000006}
#
# The new min node chosen is: [1755]
# The successor node is: 1755
# The path is: [16078, 11057, 10621]
# The current K node is: 10621
# The succ node is: 1755
#
#  Uphill- contract and update the price
#
# Removing the high price node: 10621
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 1000007, 10621: 1000007, 4109: 1000000, 13813: 0, 584: 0, 2574: 1000000, 508: 1000000, 994: 1000000, 27: 0, 2116: 0, 129: 1000000, 8495: 0}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 1000007, 10621: 1000007, 13813: 0, 584: 0, 2574: 1000000, 27: 0, 2116: 0, 8495: 0}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 1286: 6, 6098: 1000002, 10037: 1000007, 10621: 1000007, 13813: 0, 584: 6, 2574: 1000006, 27: 6, 2116: 6, 8495: 0}
#
# The new min node chosen is: [13813, 8495]
# The successor node is: 13813
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 13813
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 13813]
# the price of available nodes is: {4109: 1000000, 994: 1000000}
# the weights of available edges is: {(13813, 994): 6, (13813, 13749): 0, (13813, 95): 6, (13813, 4109): 6, (13813, 14384): 0, (13813, 1158): 6, (13813, 15005): 0, (13813, 824): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 1000007, 10621: 1000007, 4109: 1000000, 13813: 1000000, 584: 0, 2574: 1000000, 508: 1000000, 994: 1000000, 27: 0, 2116: 0, 129: 1000000, 8495: 0}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 1286: 0, 6098: 1000002, 10037: 1000007, 10621: 1000007, 584: 0, 2574: 1000000, 27: 0, 2116: 0, 8495: 0}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 1286: 6, 6098: 1000002, 10037: 1000007, 10621: 1000007, 584: 6, 2574: 1000006, 27: 6, 2116: 6, 8495: 0}
#
# The new min node chosen is: [8495]
# The successor node is: 8495
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 8495
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 8495]
# the price of available nodes is: {1286: 0, 4088: 1000000, 994: 1000000}
# the weights of available edges is: {(8495, 8814): 0, (8495, 4088): 6, (8495, 11290): 0, (8495, 994): 6, (8495, 4): 6, (8495, 1286): 6}
#
# The new nodes chosen are: {1286: 0, 4088: 1000000}
#
# The new prices of chosen are: {1286: 6, 4088: 1000006}
#
# The new min node chosen is: [1286]
# The successor node is: 1286
# The path is: [16078, 11057, 8495]
# The current K node is: 8495
# The succ node is: 1286
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 11057, 8495, 1286]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057, 8495]
# the price of available nodes is: {1286: 1000000, 4088: 1000000, 994: 1000000}
# the weights of available edges is: {(8495, 8814): 0, (8495, 4088): 6, (8495, 11290): 0, (8495, 994): 6, (8495, 4): 6, (8495, 1286): 6}
#
# The new nodes chosen are: {4088: 1000000}
#
# The new prices of chosen are: {4088: 1000006}
#
# The new min node chosen is: [4088]
# The successor node is: 4088
# The path is: [16078, 11057, 8495]
# The current K node is: 8495
# The succ node is: 4088
#
#  Uphill- contract and update the price
#
# Removing the high price node: 8495
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 1000000, 6098: 1000002, 10037: 1000007, 10621: 1000007, 4109: 1000000, 13813: 1000000, 584: 0, 2574: 1000000, 508: 1000000, 994: 1000000, 27: 0, 2116: 0, 129: 1000000, 8495: 1000007}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 584: 0, 2574: 1000000, 27: 0, 2116: 0, 8495: 1000007}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 584: 6, 2574: 1000006, 27: 6, 2116: 6, 8495: 1000007}
#
# The new min node chosen is: [584, 27, 2116]
# The successor node is: 584
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 584
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 584]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057]
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 1000000, 6098: 1000002, 10037: 1000007, 10621: 1000007, 4109: 1000000, 13813: 1000000, 584: 1000000, 2574: 1000000, 508: 1000000, 994: 1000000, 27: 0, 2116: 0, 129: 1000000, 8495: 1000007}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 2574: 1000000, 27: 0, 2116: 0, 8495: 1000007}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 2574: 1000006, 27: 6, 2116: 6, 8495: 1000007}
#
# The new min node chosen is: [27, 2116]
# The successor node is: 27
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 27
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 27]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057]
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 1000000, 6098: 1000002, 10037: 1000007, 10621: 1000007, 4109: 1000000, 13813: 1000000, 584: 1000000, 2574: 1000000, 508: 1000000, 994: 1000000, 27: 1000000, 2116: 0, 129: 1000000, 8495: 1000007}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 2574: 1000000, 2116: 0, 8495: 1000007}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 2574: 1000006, 2116: 6, 8495: 1000007}
#
# The new min node chosen is: [2116]
# The successor node is: 2116
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 2116
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 11057, 2116]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 11057]
# the price of available nodes is: {1856: 1000000, 9944: 1000007, 1286: 1000000, 6098: 1000002, 10037: 1000007, 10621: 1000007, 4109: 1000000, 13813: 1000000, 584: 1000000, 2574: 1000000, 508: 1000000, 994: 1000000, 27: 1000000, 2116: 1000000, 129: 1000000, 8495: 1000007}
# the weights of available edges is: {(11057, 9944): 0, (11057, 10037): 0, (11057, 10621): 0, (11057, 6098): 0, (11057, 1286): 6, (11057, 4109): 6, (11057, 13813): 0, (11057, 584): 6, (11057, 2574): 6, (11057, 1856): 6, (11057, 508): 6, (11057, 994): 6, (11057, 27): 6, (11057, 2116): 6, (11057, 129): 6, (11057, 8495): 0}
#
# The new nodes chosen are: {1856: 1000000, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 2574: 1000000, 8495: 1000007}
#
# The new prices of chosen are: {1856: 1000006, 9944: 1000007, 6098: 1000002, 10037: 1000007, 10621: 1000007, 2574: 1000006, 8495: 1000007}
#
# The new min node chosen is: [6098]
# The successor node is: 6098
# The path is: [16078, 11057]
# The current K node is: 11057
# The succ node is: 6098
#
#  Uphill- contract and update the price
#
# Removing the high price node: 11057
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 0, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 1000010, 11057: 1000006, 6203: 3, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 1000005}
#
# The new min node chosen is: [6203, 5562, 11174, 8697]
# The successor node is: 6203
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 6203
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 6203]
# the price of available nodes is: {2110: 1000000, 4119: 1000000, 4483: 1000007, 4835: 1000007, 2975: 1000000, 1896: 1000000, 4707: 1000001, 7364: 1000007}
# the weights of available edges is: {(6203, 4835): 0, (6203, 1896): 6, (6203, 4119): 6, (6203, 2110): 6, (6203, 4707): 0, (6203, 7364): 0, (6203, 4483): 0, (6203, 2975): 6}
#
# The new nodes chosen are: {2110: 1000000, 4119: 1000000, 4483: 1000007, 4835: 1000007, 2975: 1000000, 1896: 1000000, 4707: 1000001, 7364: 1000007}
#
# The new prices of chosen are: {2110: 1000006, 4119: 1000006, 4483: 1000007, 4835: 1000007, 2975: 1000006, 1896: 1000006, 4707: 1000001, 7364: 1000007}
#
# The new min node chosen is: [4707]
# The successor node is: 4707
# The path is: [16078, 6203]
# The current K node is: 6203
# The succ node is: 4707
#
#  Uphill- contract and update the price
#
# Removing the high price node: 6203
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 0, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 1000010, 11057: 1000006, 6203: 1000005, 4227: 6, 12802: 1000003, 5562: 3, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 1000005}
#
# The new min node chosen is: [5562, 11174, 8697]
# The successor node is: 5562
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 5562
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 5562]
# the price of available nodes is: {1286: 1000000, 4119: 1000000, 12257: 1000001, 2795: 0, 12782: 0, 2370: 0}
# the weights of available edges is: {(5562, 2795): 6, (5562, 12257): 0, (5562, 4119): 6, (5562, 12782): 0, (5562, 2370): 6, (5562, 1286): 6}
#
# The new nodes chosen are: {4119: 1000000, 12257: 1000001, 2795: 0, 12782: 0, 2370: 0}
#
# The new prices of chosen are: {4119: 1000006, 12257: 1000001, 2795: 6, 12782: 0, 2370: 6}
#
# The new min node chosen is: [12782]
# The successor node is: 12782
# The path is: [16078, 5562]
# The current K node is: 5562
# The succ node is: 12782
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 5562, 12782]
# the price of available nodes is: {1639: 1000000, 2110: 1000000, 4119: 1000000, 2415: 1000000, 2975: 1000000}
# the weights of available edges is: {(12782, 2415): 6, (12782, 2975): 6, (12782, 2110): 6, (12782, 4119): 6, (12782, 1639): 6}
#
# The new nodes chosen are: {1639: 1000000, 2110: 1000000, 4119: 1000000, 2415: 1000000, 2975: 1000000}
#
# The new prices of chosen are: {1639: 1000006, 2110: 1000006, 4119: 1000006, 2415: 1000006, 2975: 1000006}
#
# The new min node chosen is: [1639, 2110, 4119, 2415, 2975]
# The successor node is: 1639
# The path is: [16078, 5562, 12782]
# The current K node is: 12782
# The succ node is: 1639
#
#  Uphill- contract and update the price
#
# Removing the high price node: 12782
# the price of available nodes is: {1286: 1000000, 4119: 1000000, 12257: 1000001, 2795: 0, 12782: 1000007, 2370: 0}
# the weights of available edges is: {(5562, 2795): 6, (5562, 12257): 0, (5562, 4119): 6, (5562, 12782): 0, (5562, 2370): 6, (5562, 1286): 6}
#
# The new nodes chosen are: {4119: 1000000, 12257: 1000001, 2795: 0, 12782: 1000007, 2370: 0}
#
# The new prices of chosen are: {4119: 1000006, 12257: 1000001, 2795: 6, 12782: 1000007, 2370: 6}
#
# The new min node chosen is: [2795, 2370]
# The successor node is: 2795
# The path is: [16078, 5562]
# The current K node is: 5562
# The succ node is: 2795
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 5562, 2795]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 5562]
# the price of available nodes is: {1286: 1000000, 4119: 1000000, 12257: 1000001, 2795: 1000000, 12782: 1000007, 2370: 0}
# the weights of available edges is: {(5562, 2795): 6, (5562, 12257): 0, (5562, 4119): 6, (5562, 12782): 0, (5562, 2370): 6, (5562, 1286): 6}
#
# The new nodes chosen are: {4119: 1000000, 12257: 1000001, 12782: 1000007, 2370: 0}
#
# The new prices of chosen are: {4119: 1000006, 12257: 1000001, 12782: 1000007, 2370: 6}
#
# The new min node chosen is: [2370]
# The successor node is: 2370
# The path is: [16078, 5562]
# The current K node is: 5562
# The succ node is: 2370
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 5562, 2370]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [16078, 5562]
# the price of available nodes is: {1286: 1000000, 4119: 1000000, 12257: 1000001, 2795: 1000000, 12782: 1000007, 2370: 1000000}
# the weights of available edges is: {(5562, 2795): 6, (5562, 12257): 0, (5562, 4119): 6, (5562, 12782): 0, (5562, 2370): 6, (5562, 1286): 6}
#
# The new nodes chosen are: {4119: 1000000, 12257: 1000001, 12782: 1000007}
#
# The new prices of chosen are: {4119: 1000006, 12257: 1000001, 12782: 1000007}
#
# The new min node chosen is: [12257]
# The successor node is: 12257
# The path is: [16078, 5562]
# The current K node is: 5562
# The succ node is: 12257
#
#  Uphill- contract and update the price
#
# Removing the high price node: 5562
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 1000002, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 1000002, 11174: 0, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 1000010, 11057: 1000006, 6203: 1000005, 4227: 6, 12802: 1000003, 5562: 1000005, 11174: 3, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 1000005}
#
# The new min node chosen is: [11174, 8697]
# The successor node is: 11174
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 11174
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 11174]
# the price of available nodes is: {1639: 1000000, 4119: 1000000, 2769: 1000000, 11848: 0}
# the weights of available edges is: {(11174, 4119): 6, (11174, 11848): 0, (11174, 1639): 6, (11174, 2769): 6}
#
# The new nodes chosen are: {1639: 1000000, 4119: 1000000, 2769: 1000000, 11848: 0}
#
# The new prices of chosen are: {1639: 1000006, 4119: 1000006, 2769: 1000006, 11848: 0}
#
# The new min node chosen is: [11848]
# The successor node is: 11848
# The path is: [16078, 11174]
# The current K node is: 11174
# The succ node is: 11848
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [16078, 11174, 11848]
# the price of available nodes is: {1302: 1000000, 203: 1000000}
# the weights of available edges is: {(11848, 4396): 0, (11848, 790): 6, (11848, 6123): 0, (11848, 203): 6, (11848, 4117): 6, (11848, 4703): 0, (11848, 1302): 6}
#
# The new nodes chosen are: {1302: 1000000, 203: 1000000}
#
# The new prices of chosen are: {1302: 1000006, 203: 1000006}
#
# The new min node chosen is: [1302, 203]
# The successor node is: 1302
# The path is: [16078, 11174, 11848]
# The current K node is: 11848
# The succ node is: 1302
#
#  Uphill- contract and update the price
#
# Removing the high price node: 11848
# the price of available nodes is: {1639: 1000000, 4119: 1000000, 2769: 1000000, 11848: 1000007}
# the weights of available edges is: {(11174, 4119): 6, (11174, 11848): 0, (11174, 1639): 6, (11174, 2769): 6}
#
# The new nodes chosen are: {1639: 1000000, 4119: 1000000, 2769: 1000000, 11848: 1000007}
#
# The new prices of chosen are: {1639: 1000006, 4119: 1000006, 2769: 1000006, 11848: 1000007}
#
# The new min node chosen is: [1639, 4119, 2769]
# The successor node is: 1639
# The path is: [16078, 11174]
# The current K node is: 11174
# The succ node is: 1639
#
#  Uphill- contract and update the price
#
# Removing the high price node: 11174
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 1000002, 11174: 1000007, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 1000002, 11174: 1000007, 8697: 0, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 1000010, 11057: 1000006, 6203: 1000005, 4227: 6, 12802: 1000003, 5562: 1000005, 11174: 1000010, 8697: 3, 1474: 6, 2980: 6, 4272: 6, 6098: 1000005}
#
# The new min node chosen is: [8697]
# The successor node is: 8697
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 8697
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 8697]
# the price of available nodes is: {2975: 1000000, 4088: 1000000}
# the weights of available edges is: {(8697, 4088): 6, (8697, 2975): 6}
#
# The new nodes chosen are: {2975: 1000000, 4088: 1000000}
#
# The new prices of chosen are: {2975: 1000006, 4088: 1000006}
#
# The new min node chosen is: [2975, 4088]
# The successor node is: 2975
# The path is: [16078, 8697]
# The current K node is: 8697
# The succ node is: 2975
#
#  Uphill- contract and update the price
#
# Removing the high price node: 8697
# the price of available nodes is: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 1000002, 11174: 1000007, 8697: 1000007, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
# the weights of available edges is: {(16078, 12257): 3, (16078, 10322): 3, (16078, 4958): 3, (16078, 8073): 3, (16078, 11057): 3, (16078, 6203): 3, (16078, 4227): 6, (16078, 12802): 3, (16078, 5562): 3, (16078, 11174): 3, (16078, 6680): 3, (16078, 8697): 3, (16078, 1474): 6, (16078, 9409): 3, (16078, 2980): 6, (16078, 4272): 6, (16078, 6098): 3}
#
# The new nodes chosen are: {6680: 1000000, 9409: 3, 12257: 1000001, 10322: 1000007, 4958: 1000007, 8073: 1000007, 11057: 1000003, 6203: 1000002, 4227: 0, 12802: 1000000, 5562: 1000002, 11174: 1000007, 8697: 1000007, 1474: 0, 2980: 0, 4272: 0, 6098: 1000002}
#
# The new prices of chosen are: {6680: 1000003, 9409: 6, 12257: 1000004, 10322: 1000010, 4958: 1000010, 8073: 1000010, 11057: 1000006, 6203: 1000005, 4227: 6, 12802: 1000003, 5562: 1000005, 11174: 1000010, 8697: 1000010, 1474: 6, 2980: 6, 4272: 6, 6098: 1000005}
#
# The new min node chosen is: [9409, 4227, 1474, 2980, 4272]
# The successor node is: 9409
# The path is: [16078]
# The current K node is: 16078
# The succ node is: 9409
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [16078, 9409]
# the price of available nodes is: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
# the weights of available edges is: {(9409, 7421): 0, (9409, 4126): 6, (9409, 14376): 0, (9409, 2502): 6, (9409, 13525): 0}
#
# The new nodes chosen are: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
#
# The new prices of chosen are: {2502: 1000006, 7421: 1000000, 14376: 0, 4126: 1000006}
#
# The new min node chosen is: [14376]
# The successor node is: 14376
# The path is: [16078, 9409]
# The current K node is: 9409
# The succ node is: 14376
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [16078, 9409, 14376]
# Path to target is: [16078, 9409, 14376]
# The number of steps 56

# %% [markdown]
# ## Run 8

# %%
# if author 'eepeng lim' cited work on Equations for part-of-speech tagging

# provide the source and destination
source = int("11699")

target= int("14376")


# keep a track of current nodes Path
Path=[]
Path.append(source)

# create a list of high price nodes
highpriceNode =[]

# initialize random price
#nodePrice = intial_price(0)
# edge weights do not change as relations are same

# %%
Pathfound=update_price_single(Path)
# Out:
# the price of available nodes is: {9726: 3, 7000: 0, 9478: 0, 2003: 0, 2636: 0, 11213: 0}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 3, 7000: 0, 9478: 0, 2003: 0, 2636: 0, 11213: 0}
#
# The new prices of chosen are: {9726: 6, 7000: 3, 9478: 3, 2003: 6, 2636: 6, 11213: 3}
#
# The new min node chosen is: [7000, 9478, 11213]
# The successor node is: 7000
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 7000
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 7000]
# the price of available nodes is: {4097: 1000000, 1256: 0, 358: 0, 309: 0, 2498: 0, 2315: 0}
# the weights of available edges is: {(7000, 358): 6, (7000, 4097): 6, (7000, 309): 6, (7000, 1256): 6, (7000, 2498): 6, (7000, 2315): 6}
#
# The new nodes chosen are: {4097: 1000000, 1256: 0, 358: 0, 309: 0, 2498: 0, 2315: 0}
#
# The new prices of chosen are: {4097: 1000006, 1256: 6, 358: 6, 309: 6, 2498: 6, 2315: 6}
#
# The new min node chosen is: [1256, 358, 309, 2498, 2315]
# The successor node is: 1256
# The path is: [11699, 7000]
# The current K node is: 7000
# The succ node is: 1256
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11699, 7000, 1256]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 7000]
# the price of available nodes is: {4097: 1000000, 1256: 1000000, 358: 0, 309: 0, 2498: 0, 2315: 0}
# the weights of available edges is: {(7000, 358): 6, (7000, 4097): 6, (7000, 309): 6, (7000, 1256): 6, (7000, 2498): 6, (7000, 2315): 6}
#
# The new nodes chosen are: {4097: 1000000, 358: 0, 309: 0, 2498: 0, 2315: 0}
#
# The new prices of chosen are: {4097: 1000006, 358: 6, 309: 6, 2498: 6, 2315: 6}
#
# The new min node chosen is: [358, 309, 2498, 2315]
# The successor node is: 358
# The path is: [11699, 7000]
# The current K node is: 7000
# The succ node is: 358
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 7000, 358]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 7000]
# the price of available nodes is: {4097: 1000000, 1256: 1000000, 358: 1000000, 309: 0, 2498: 0, 2315: 0}
# the weights of available edges is: {(7000, 358): 6, (7000, 4097): 6, (7000, 309): 6, (7000, 1256): 6, (7000, 2498): 6, (7000, 2315): 6}
#
# The new nodes chosen are: {4097: 1000000, 309: 0, 2498: 0, 2315: 0}
#
# The new prices of chosen are: {4097: 1000006, 309: 6, 2498: 6, 2315: 6}
#
# The new min node chosen is: [309, 2498, 2315]
# The successor node is: 309
# The path is: [11699, 7000]
# The current K node is: 7000
# The succ node is: 309
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 7000, 309]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 7000]
# the price of available nodes is: {4097: 1000000, 1256: 1000000, 358: 1000000, 309: 1000000, 2498: 0, 2315: 0}
# the weights of available edges is: {(7000, 358): 6, (7000, 4097): 6, (7000, 309): 6, (7000, 1256): 6, (7000, 2498): 6, (7000, 2315): 6}
#
# The new nodes chosen are: {4097: 1000000, 2498: 0, 2315: 0}
#
# The new prices of chosen are: {4097: 1000006, 2498: 6, 2315: 6}
#
# The new min node chosen is: [2498, 2315]
# The successor node is: 2498
# The path is: [11699, 7000]
# The current K node is: 7000
# The succ node is: 2498
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 7000, 2498]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 7000]
# the price of available nodes is: {4097: 1000000, 1256: 1000000, 358: 1000000, 309: 1000000, 2498: 1000000, 2315: 0}
# the weights of available edges is: {(7000, 358): 6, (7000, 4097): 6, (7000, 309): 6, (7000, 1256): 6, (7000, 2498): 6, (7000, 2315): 6}
#
# The new nodes chosen are: {4097: 1000000, 2315: 0}
#
# The new prices of chosen are: {4097: 1000006, 2315: 6}
#
# The new min node chosen is: [2315]
# The successor node is: 2315
# The path is: [11699, 7000]
# The current K node is: 7000
# The succ node is: 2315
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 7000, 2315]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 7000]
# the price of available nodes is: {4097: 1000000, 1256: 1000000, 358: 1000000, 309: 1000000, 2498: 1000000, 2315: 1000000}
# the weights of available edges is: {(7000, 358): 6, (7000, 4097): 6, (7000, 309): 6, (7000, 1256): 6, (7000, 2498): 6, (7000, 2315): 6}
#
# The new nodes chosen are: {4097: 1000000}
#
# The new prices of chosen are: {4097: 1000006}
#
# The new min node chosen is: [4097]
# The successor node is: 4097
# The path is: [11699, 7000]
# The current K node is: 7000
# The succ node is: 4097
#
#  Uphill- contract and update the price
#
# Removing the high price node: 7000
# the price of available nodes is: {9726: 3, 7000: 1000007, 9478: 0, 2003: 0, 2636: 0, 11213: 0}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 3, 7000: 1000007, 9478: 0, 2003: 0, 2636: 0, 11213: 0}
#
# The new prices of chosen are: {9726: 6, 7000: 1000010, 9478: 3, 2003: 6, 2636: 6, 11213: 3}
#
# The new min node chosen is: [9478, 11213]
# The successor node is: 9478
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 9478
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 0, 1485: 0, 1212: 0, 1964: 0, 12416: 0, 1010: 0, 656: 1000000, 2399: 0, 2826: 0, 1716: 0, 5500: 0}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 4107: 0, 1485: 0, 1212: 0, 1964: 0, 12416: 0, 1010: 0, 656: 1000000, 2399: 0, 2826: 0, 1716: 0, 5500: 0}
#
# The new prices of chosen are: {717: 1000006, 4107: 6, 1485: 6, 1212: 6, 1964: 6, 12416: 0, 1010: 6, 656: 1000006, 2399: 6, 2826: 6, 1716: 6, 5500: 0}
#
# The new min node chosen is: [12416, 5500]
# The successor node is: 12416
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 12416
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11699, 9478, 12416]
# the price of available nodes is: {4093: 1000000, 3787: 0, 1212: 0, 2399: 0}
# the weights of available edges is: {(12416, 1212): 6, (12416, 2399): 6, (12416, 4093): 6, (12416, 3787): 6}
#
# The new nodes chosen are: {4093: 1000000, 3787: 0, 1212: 0, 2399: 0}
#
# The new prices of chosen are: {4093: 1000006, 3787: 6, 1212: 6, 2399: 6}
#
# The new min node chosen is: [3787, 1212, 2399]
# The successor node is: 3787
# The path is: [11699, 9478, 12416]
# The current K node is: 12416
# The succ node is: 3787
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11699, 9478, 12416, 3787]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478, 12416]
# the price of available nodes is: {4093: 1000000, 3787: 1000000, 1212: 0, 2399: 0}
# the weights of available edges is: {(12416, 1212): 6, (12416, 2399): 6, (12416, 4093): 6, (12416, 3787): 6}
#
# The new nodes chosen are: {4093: 1000000, 1212: 0, 2399: 0}
#
# The new prices of chosen are: {4093: 1000006, 1212: 6, 2399: 6}
#
# The new min node chosen is: [1212, 2399]
# The successor node is: 1212
# The path is: [11699, 9478, 12416]
# The current K node is: 12416
# The succ node is: 1212
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 12416, 1212]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478, 12416]
# the price of available nodes is: {4093: 1000000, 3787: 1000000, 1212: 1000000, 2399: 0}
# the weights of available edges is: {(12416, 1212): 6, (12416, 2399): 6, (12416, 4093): 6, (12416, 3787): 6}
#
# The new nodes chosen are: {4093: 1000000, 2399: 0}
#
# The new prices of chosen are: {4093: 1000006, 2399: 6}
#
# The new min node chosen is: [2399]
# The successor node is: 2399
# The path is: [11699, 9478, 12416]
# The current K node is: 12416
# The succ node is: 2399
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 12416, 2399]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478, 12416]
# the price of available nodes is: {4093: 1000000, 3787: 1000000, 1212: 1000000, 2399: 1000000}
# the weights of available edges is: {(12416, 1212): 6, (12416, 2399): 6, (12416, 4093): 6, (12416, 3787): 6}
#
# The new nodes chosen are: {4093: 1000000}
#
# The new prices of chosen are: {4093: 1000006}
#
# The new min node chosen is: [4093]
# The successor node is: 4093
# The path is: [11699, 9478, 12416]
# The current K node is: 12416
# The succ node is: 4093
#
#  Uphill- contract and update the price
#
# Removing the high price node: 12416
# the price of available nodes is: {717: 1000000, 4107: 0, 1485: 0, 1212: 1000000, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2399: 1000000, 2826: 0, 1716: 0, 5500: 0}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 4107: 0, 1485: 0, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2826: 0, 1716: 0, 5500: 0}
#
# The new prices of chosen are: {717: 1000006, 4107: 6, 1485: 6, 1964: 6, 12416: 1000007, 1010: 6, 656: 1000006, 2826: 6, 1716: 6, 5500: 0}
#
# The new min node chosen is: [5500]
# The successor node is: 5500
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 5500
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 5500]
# the price of available nodes is: {}
# the weights of available edges is: {(5500, 1005): 6, (5500, 4114): 6}
#
# The new nodes chosen are: {}
#
# The new prices of chosen are: {}
# the price of available nodes is: {717: 1000000, 4107: 0, 1485: 0, 1212: 1000000, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2399: 1000000, 2826: 0, 1716: 0, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 4107: 0, 1485: 0, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2826: 0, 1716: 0}
#
# The new prices of chosen are: {717: 1000006, 4107: 6, 1485: 6, 1964: 6, 12416: 1000007, 1010: 6, 656: 1000006, 2826: 6, 1716: 6}
#
# The new min node chosen is: [4107, 1485, 1964, 1010, 2826, 1716]
# The successor node is: 4107
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 4107
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 4107]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 1000000, 1485: 0, 1212: 1000000, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2399: 1000000, 2826: 0, 1716: 0, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 1485: 0, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2826: 0, 1716: 0}
#
# The new prices of chosen are: {717: 1000006, 1485: 6, 1964: 6, 12416: 1000007, 1010: 6, 656: 1000006, 2826: 6, 1716: 6}
#
# The new min node chosen is: [1485, 1964, 1010, 2826, 1716]
# The successor node is: 1485
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 1485
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 1485]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 1000000, 1485: 1000000, 1212: 1000000, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2399: 1000000, 2826: 0, 1716: 0, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 1964: 0, 12416: 1000007, 1010: 0, 656: 1000000, 2826: 0, 1716: 0}
#
# The new prices of chosen are: {717: 1000006, 1964: 6, 12416: 1000007, 1010: 6, 656: 1000006, 2826: 6, 1716: 6}
#
# The new min node chosen is: [1964, 1010, 2826, 1716]
# The successor node is: 1964
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 1964
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 1964]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 1000000, 1485: 1000000, 1212: 1000000, 1964: 1000000, 12416: 1000007, 1010: 0, 656: 1000000, 2399: 1000000, 2826: 0, 1716: 0, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 12416: 1000007, 1010: 0, 656: 1000000, 2826: 0, 1716: 0}
#
# The new prices of chosen are: {717: 1000006, 12416: 1000007, 1010: 6, 656: 1000006, 2826: 6, 1716: 6}
#
# The new min node chosen is: [1010, 2826, 1716]
# The successor node is: 1010
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 1010
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 1010]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 1000000, 1485: 1000000, 1212: 1000000, 1964: 1000000, 12416: 1000007, 1010: 1000000, 656: 1000000, 2399: 1000000, 2826: 0, 1716: 0, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 12416: 1000007, 656: 1000000, 2826: 0, 1716: 0}
#
# The new prices of chosen are: {717: 1000006, 12416: 1000007, 656: 1000006, 2826: 6, 1716: 6}
#
# The new min node chosen is: [2826, 1716]
# The successor node is: 2826
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 2826
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 2826]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 1000000, 1485: 1000000, 1212: 1000000, 1964: 1000000, 12416: 1000007, 1010: 1000000, 656: 1000000, 2399: 1000000, 2826: 1000000, 1716: 0, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 12416: 1000007, 656: 1000000, 1716: 0}
#
# The new prices of chosen are: {717: 1000006, 12416: 1000007, 656: 1000006, 1716: 6}
#
# The new min node chosen is: [1716]
# The successor node is: 1716
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 1716
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9478, 1716]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 9478]
# the price of available nodes is: {717: 1000000, 4107: 1000000, 1485: 1000000, 1212: 1000000, 1964: 1000000, 12416: 1000007, 1010: 1000000, 656: 1000000, 2399: 1000000, 2826: 1000000, 1716: 1000000, 5500: 1000000}
# the weights of available edges is: {(9478, 1485): 6, (9478, 1212): 6, (9478, 1964): 6, (9478, 717): 6, (9478, 12416): 0, (9478, 1010): 6, (9478, 656): 6, (9478, 4107): 6, (9478, 2399): 6, (9478, 2826): 6, (9478, 1716): 6, (9478, 5500): 0}
#
# The new nodes chosen are: {717: 1000000, 12416: 1000007, 656: 1000000}
#
# The new prices of chosen are: {717: 1000006, 12416: 1000007, 656: 1000006}
#
# The new min node chosen is: [717, 656]
# The successor node is: 717
# The path is: [11699, 9478]
# The current K node is: 9478
# The succ node is: 717
#
#  Uphill- contract and update the price
#
# Removing the high price node: 9478
# the price of available nodes is: {9726: 3, 7000: 1000007, 9478: 1000007, 2003: 0, 2636: 0, 11213: 0}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 3, 7000: 1000007, 9478: 1000007, 2003: 0, 2636: 0, 11213: 0}
#
# The new prices of chosen are: {9726: 6, 7000: 1000010, 9478: 1000010, 2003: 6, 2636: 6, 11213: 3}
#
# The new min node chosen is: [11213]
# The successor node is: 11213
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 11213
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 11213]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1107: 0, 1190: 1000000, 104: 0, 12606: 0, 206: 0, 2382: 0, 332: 0, 3153: 0}
# the weights of available edges is: {(11213, 1107): 6, (11213, 1190): 6, (11213, 104): 6, (11213, 12606): 0, (11213, 4107): 6, (11213, 206): 6, (11213, 2382): 6, (11213, 656): 6, (11213, 332): 6, (11213, 3153): 6}
#
# The new nodes chosen are: {656: 1000000, 1107: 0, 1190: 1000000, 104: 0, 12606: 0, 206: 0, 2382: 0, 332: 0, 3153: 0}
#
# The new prices of chosen are: {656: 1000006, 1107: 6, 1190: 1000006, 104: 6, 12606: 0, 206: 6, 2382: 6, 332: 6, 3153: 6}
#
# The new min node chosen is: [12606]
# The successor node is: 12606
# The path is: [11699, 11213]
# The current K node is: 11213
# The succ node is: 12606
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11699, 11213, 12606]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1190: 1000000, 104: 0, 206: 0}
# the weights of available edges is: {(12606, 206): 6, (12606, 2113): 6, (12606, 656): 6, (12606, 664): 6, (12606, 3085): 6, (12606, 4107): 6, (12606, 104): 6, (12606, 2718): 6, (12606, 2623): 6, (12606, 1190): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000, 104: 0, 206: 0}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006, 104: 6, 206: 6}
#
# The new min node chosen is: [104, 206]
# The successor node is: 104
# The path is: [11699, 11213, 12606]
# The current K node is: 12606
# The succ node is: 104
#
# same level Case 1 - Extend to succ node and update the price of k to pred node
# The updated Path is: [11699, 11213, 12606, 104]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 11213, 12606]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1190: 1000000, 104: 1000000, 206: 0}
# the weights of available edges is: {(12606, 206): 6, (12606, 2113): 6, (12606, 656): 6, (12606, 664): 6, (12606, 3085): 6, (12606, 4107): 6, (12606, 104): 6, (12606, 2718): 6, (12606, 2623): 6, (12606, 1190): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000, 206: 0}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006, 206: 6}
#
# The new min node chosen is: [206]
# The successor node is: 206
# The path is: [11699, 11213, 12606]
# The current K node is: 12606
# The succ node is: 206
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 11213, 12606, 206]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 11213, 12606]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1190: 1000000, 104: 1000000, 206: 1000000}
# the weights of available edges is: {(12606, 206): 6, (12606, 2113): 6, (12606, 656): 6, (12606, 664): 6, (12606, 3085): 6, (12606, 4107): 6, (12606, 104): 6, (12606, 2718): 6, (12606, 2623): 6, (12606, 1190): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006}
#
# The new min node chosen is: [656, 1190]
# The successor node is: 656
# The path is: [11699, 11213, 12606]
# The current K node is: 12606
# The succ node is: 656
#
#  Uphill- contract and update the price
#
# Removing the high price node: 12606
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1107: 0, 1190: 1000000, 104: 1000000, 12606: 1000007, 206: 1000000, 2382: 0, 332: 0, 3153: 0}
# the weights of available edges is: {(11213, 1107): 6, (11213, 1190): 6, (11213, 104): 6, (11213, 12606): 0, (11213, 4107): 6, (11213, 206): 6, (11213, 2382): 6, (11213, 656): 6, (11213, 332): 6, (11213, 3153): 6}
#
# The new nodes chosen are: {656: 1000000, 1107: 0, 1190: 1000000, 12606: 1000007, 2382: 0, 332: 0, 3153: 0}
#
# The new prices of chosen are: {656: 1000006, 1107: 6, 1190: 1000006, 12606: 1000007, 2382: 6, 332: 6, 3153: 6}
#
# The new min node chosen is: [1107, 2382, 332, 3153]
# The successor node is: 1107
# The path is: [11699, 11213]
# The current K node is: 11213
# The succ node is: 1107
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 11213, 1107]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 11213]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1107: 1000000, 1190: 1000000, 104: 1000000, 12606: 1000007, 206: 1000000, 2382: 0, 332: 0, 3153: 0}
# the weights of available edges is: {(11213, 1107): 6, (11213, 1190): 6, (11213, 104): 6, (11213, 12606): 0, (11213, 4107): 6, (11213, 206): 6, (11213, 2382): 6, (11213, 656): 6, (11213, 332): 6, (11213, 3153): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000, 12606: 1000007, 2382: 0, 332: 0, 3153: 0}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006, 12606: 1000007, 2382: 6, 332: 6, 3153: 6}
#
# The new min node chosen is: [2382, 332, 3153]
# The successor node is: 2382
# The path is: [11699, 11213]
# The current K node is: 11213
# The succ node is: 2382
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 11213, 2382]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 11213]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1107: 1000000, 1190: 1000000, 104: 1000000, 12606: 1000007, 206: 1000000, 2382: 1000000, 332: 0, 3153: 0}
# the weights of available edges is: {(11213, 1107): 6, (11213, 1190): 6, (11213, 104): 6, (11213, 12606): 0, (11213, 4107): 6, (11213, 206): 6, (11213, 2382): 6, (11213, 656): 6, (11213, 332): 6, (11213, 3153): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000, 12606: 1000007, 332: 0, 3153: 0}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006, 12606: 1000007, 332: 6, 3153: 6}
#
# The new min node chosen is: [332, 3153]
# The successor node is: 332
# The path is: [11699, 11213]
# The current K node is: 11213
# The succ node is: 332
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 11213, 332]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 11213]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1107: 1000000, 1190: 1000000, 104: 1000000, 12606: 1000007, 206: 1000000, 2382: 1000000, 332: 1000000, 3153: 0}
# the weights of available edges is: {(11213, 1107): 6, (11213, 1190): 6, (11213, 104): 6, (11213, 12606): 0, (11213, 4107): 6, (11213, 206): 6, (11213, 2382): 6, (11213, 656): 6, (11213, 332): 6, (11213, 3153): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000, 12606: 1000007, 3153: 0}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006, 12606: 1000007, 3153: 6}
#
# The new min node chosen is: [3153]
# The successor node is: 3153
# The path is: [11699, 11213]
# The current K node is: 11213
# The succ node is: 3153
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 11213, 3153]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699, 11213]
# the price of available nodes is: {4107: 1000000, 656: 1000000, 1107: 1000000, 1190: 1000000, 104: 1000000, 12606: 1000007, 206: 1000000, 2382: 1000000, 332: 1000000, 3153: 1000000}
# the weights of available edges is: {(11213, 1107): 6, (11213, 1190): 6, (11213, 104): 6, (11213, 12606): 0, (11213, 4107): 6, (11213, 206): 6, (11213, 2382): 6, (11213, 656): 6, (11213, 332): 6, (11213, 3153): 6}
#
# The new nodes chosen are: {656: 1000000, 1190: 1000000, 12606: 1000007}
#
# The new prices of chosen are: {656: 1000006, 1190: 1000006, 12606: 1000007}
#
# The new min node chosen is: [656, 1190]
# The successor node is: 656
# The path is: [11699, 11213]
# The current K node is: 11213
# The succ node is: 656
#
#  Uphill- contract and update the price
#
# Removing the high price node: 11213
# the price of available nodes is: {9726: 3, 7000: 1000007, 9478: 1000007, 2003: 0, 2636: 0, 11213: 1000007}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 3, 7000: 1000007, 9478: 1000007, 2003: 0, 2636: 0, 11213: 1000007}
#
# The new prices of chosen are: {9726: 6, 7000: 1000010, 9478: 1000010, 2003: 6, 2636: 6, 11213: 1000010}
#
# The new min node chosen is: [9726, 2003, 2636]
# The successor node is: 9726
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 9726
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 9726]
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 4, 2502: 1000000, 7421: 1000000, 3787: 1000000, 12700: 1000007, 1930: 1000000, 4107: 1000000}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 4, 2502: 1000000, 7421: 1000000, 12700: 1000007, 1930: 1000000}
#
# The new prices of chosen are: {12801: 1000000, 774: 6, 717: 1000006, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000006, 8680: 1000000, 1483: 1000006, 3778: 6, 9409: 4, 2502: 1000006, 7421: 1000000, 12700: 1000007, 1930: 1000006}
#
# The new min node chosen is: [9409]
# The successor node is: 9409
# The path is: [11699, 9726]
# The current K node is: 9726
# The succ node is: 9409
#
#  Uphill- contract and update the price
#
# Removing the high price node: 9726
# the price of available nodes is: {9726: 5, 7000: 1000007, 9478: 1000007, 2003: 0, 2636: 0, 11213: 1000007}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 5, 7000: 1000007, 9478: 1000007, 2003: 0, 2636: 0, 11213: 1000007}
#
# The new prices of chosen are: {9726: 8, 7000: 1000010, 9478: 1000010, 2003: 6, 2636: 6, 11213: 1000010}
#
# The new min node chosen is: [2003, 2636]
# The successor node is: 2003
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 2003
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 2003]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699]
# the price of available nodes is: {9726: 5, 7000: 1000007, 9478: 1000007, 2003: 1000000, 2636: 0, 11213: 1000007}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 5, 7000: 1000007, 9478: 1000007, 2636: 0, 11213: 1000007}
#
# The new prices of chosen are: {9726: 8, 7000: 1000010, 9478: 1000010, 2636: 6, 11213: 1000010}
#
# The new min node chosen is: [2636]
# The successor node is: 2636
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 2636
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 2636]
# Terminal node reached, set the price to infinity and contract - remove the node
# The new path is [11699]
# the price of available nodes is: {9726: 5, 7000: 1000007, 9478: 1000007, 2003: 1000000, 2636: 1000000, 11213: 1000007}
# the weights of available edges is: {(11699, 7000): 3, (11699, 9478): 3, (11699, 2003): 6, (11699, 2636): 6, (11699, 9726): 3, (11699, 11213): 3}
#
# The new nodes chosen are: {9726: 5, 7000: 1000007, 9478: 1000007, 11213: 1000007}
#
# The new prices of chosen are: {9726: 8, 7000: 1000010, 9478: 1000010, 11213: 1000010}
#
# The new min node chosen is: [9726]
# The successor node is: 9726
# The path is: [11699]
# The current K node is: 11699
# The succ node is: 9726
# Downhill Extend path to succ node and update the price of k
#
# The latest path is: [11699, 9726]
# the price of available nodes is: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 4, 2502: 1000000, 7421: 1000000, 3787: 1000000, 12700: 1000007, 1930: 1000000, 4107: 1000000}
# the weights of available edges is: {(9726, 12801): 0, (9726, 774): 6, (9726, 717): 6, (9726, 13914): 0, (9726, 5201): 0, (9726, 8043): 0, (9726, 389): 6, (9726, 8680): 0, (9726, 1483): 6, (9726, 3778): 6, (9726, 9409): 0, (9726, 2502): 6, (9726, 7421): 0, (9726, 3787): 6, (9726, 12700): 0, (9726, 1930): 6, (9726, 4107): 6}
#
# The new nodes chosen are: {12801: 1000000, 774: 0, 717: 1000000, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000000, 8680: 1000000, 1483: 1000000, 3778: 0, 9409: 4, 2502: 1000000, 7421: 1000000, 12700: 1000007, 1930: 1000000}
#
# The new prices of chosen are: {12801: 1000000, 774: 6, 717: 1000006, 13914: 1000000, 5201: 1000000, 8043: 1000000, 389: 1000006, 8680: 1000000, 1483: 1000006, 3778: 6, 9409: 4, 2502: 1000006, 7421: 1000000, 12700: 1000007, 1930: 1000006}
#
# The new min node chosen is: [9409]
# The successor node is: 9409
# The path is: [11699, 9726]
# The current K node is: 9726
# The succ node is: 9409
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9726, 9409]
# the price of available nodes is: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
# the weights of available edges is: {(9409, 7421): 0, (9409, 4126): 6, (9409, 14376): 0, (9409, 2502): 6, (9409, 13525): 0}
#
# The new nodes chosen are: {2502: 1000000, 7421: 1000000, 14376: 0, 4126: 1000000}
#
# The new prices of chosen are: {2502: 1000006, 7421: 1000000, 14376: 0, 4126: 1000006}
#
# The new min node chosen is: [14376]
# The successor node is: 14376
# The path is: [11699, 9726, 9409]
# The current K node is: 9409
# The succ node is: 14376
# Downhill Extend path to succ node and set the price of k to pred node
#
# The latest path is: [11699, 9726, 9409, 14376]
# Path to target is: [11699, 9726, 9409, 14376]
# The number of steps 38
